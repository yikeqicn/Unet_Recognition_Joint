# %%
experiment=None

# %%
#Imports
from comet_ml import Experiment
experiment = Experiment(api_key="YkPEmantOag1R1VOJmXz11hmt", parse_args=False, project_name='SegNet_Recognition_Joint')
# Out:
# COMET INFO: old comet version (1.0.44) detected. current: 2.0.2 please update your comet lib with command: `pip install --no-cache-dir --upgrade comet_ml`
# COMET WARNING: Failing to collect the installed os packages
# COMET INFO: Experiment is live on comet.ml https://www.comet.ml/yikeqicn/segnet-recognition-joint/8d3c210f650b41fa919270d5212b31de

# %%
#from datasets import IRSPRT#RecgArtPrintNoIntsectHVBW
import pytesseract as pyt
from os.path import join, basename, dirname
import tensorflow as tf
import shutil
import os
import sys
import argparse
from glob import glob
import cv2
import numpy as np
import os
import time
from PIL import Image
import editdistance

from torch.utils.data import DataLoader, ConcatDataset, random_split#, SequentialSampler #yike: add SequentialSampler
import torch
import torchvision
import torchvision.transforms as transforms
#from datasets import IRS #ArtPrintNoIntsectLBW,ArtPrintNoIntsectLBW_biameyd_siameyd,ArtPrintNoIntsectLBW_bpr_spr,ArtPrintNoIntsectLBW_biameyd_sprt
############from Model_Unet_github import *
from utils_seg import *
import utils_recg

############from recognition.Model import RecgModel, DecoderType
#from recognition.utils import log_image

home = os.environ['HOME']

# %%
# Unet
from __future__ import print_function, division, absolute_import, unicode_literals
import tensorflow as tf

import cv2

import os, sys
import numpy as np
import math
from datetime import datetime
import time
from PIL import Image
from math import ceil
from collections import OrderedDict
import logging
from utils_seg import get_image_summary, log_images, _variable_with_weight_decay, _variable_on_cpu, _add_loss_summaries, \
    _activation_summary, print_hist_summery, get_hist, per_class_acc, writeImage

# Recognition
from glob import glob
import numpy as np
import sys
import tensorflow as tf
from os.path import join
from Densenet4htr import Densenet4htr
import utils_recg  # dangerous


# model layers
def weight_variable(shape, stddev=0.1, name="weight"):
    shape = np.array(shape)
    # print(shape)
    # print(stddev)
    initial = tf.truncated_normal(shape, stddev=stddev)
    return tf.Variable(initial, name=name)


def weight_variable_devonc(shape, stddev=0.1, name="weight_devonc"):
    shape = np.array(shape)
    return tf.Variable(tf.truncated_normal(shape, stddev=stddev), name=name)


def bias_variable(shape, name="bias"):
    initial = tf.constant(0.1, shape=shape)
    return tf.Variable(initial, name=name)


def conv2d(x, W, b, keep_prob_):
    with tf.name_scope("conv2d"):
        conv_2d = tf.nn.conv2d(x, W, strides=[1, 1, 1, 1], padding='SAME')  # 'VALID'
        conv_2d_b = tf.nn.bias_add(conv_2d, b)
        return tf.nn.dropout(conv_2d_b, keep_prob_)


def deconv2d(x, W, stride):
    with tf.name_scope("deconv2d"):
        x_shape = tf.shape(x)
        output_shape = tf.stack([x_shape[0], x_shape[1] * 2, x_shape[2] * 2, x_shape[3] // 2])
        return tf.nn.conv2d_transpose(x, W, output_shape, strides=[1, stride, stride, 1], padding='SAME',
                                      name="conv2d_transpose")  # 'VALID'


def max_pool(x, n):
    return tf.nn.max_pool(x, ksize=[1, n, n, 1], strides=[1, n, n, 1], padding='SAME')  # 'VALID'


def crop_and_concat(x1, x2):
    with tf.name_scope("crop_and_concat"):
        x1_shape = tf.shape(x1)
        x2_shape = tf.shape(x2)
        # offsets for the top left corner of the crop
        offsets = [0, (x1_shape[1] - x2_shape[1]) // 2, (x1_shape[2] - x2_shape[2]) // 2, 0]
        size = [-1, x2_shape[1], x2_shape[2], -1]
        x1_crop = tf.slice(x1, offsets, size)
        return tf.concat([x1_crop, x2], 3)


def pixel_wise_softmax(output_map):
    with tf.name_scope("pixel_wise_softmax"):
        max_axis = tf.reduce_max(output_map, axis=3, keepdims=True)
        exponential_map = tf.exp(output_map - max_axis)
        normalize = tf.reduce_sum(exponential_map, axis=3, keepdims=True)
        return exponential_map / normalize


def cross_entropy(y_, output_map):
    return -tf.reduce_mean(y_ * tf.log(tf.clip_by_value(output_map, 1e-10, 1.0)), name="cross_entropy")


# unet setting
def create_conv_net(x, keep_prob, channels, n_class, layers=3, features_root=16, filter_size=3, pool_size=2,
                    summaries=True):
    """
    Creates a new convolutional unet for the given parametrization.
    :param x: input tensor, shape [?,nx,ny,channels]
    :param keep_prob: dropout probability tensor
    :param channels: number of channels in the input image
    :param n_class: number of output labels
    :param layers: number of layers in the net
    :param features_root: number of features in the first layer
    :param filter_size: size of the convolution filter
    :param pool_size: size of the max pooling operation
    :param summaries: Flag if summaries should be created
    """

    logging.info(
        "Layers {layers}, features {features}, filter size {filter_size}x{filter_size}, pool size: {pool_size}x{pool_size}".format(
            layers=layers,
            features=features_root,
            filter_size=filter_size,
            pool_size=pool_size))

    # Placeholder for the input image
    with tf.name_scope("preprocessing"):
        nx = tf.shape(x)[1]
        ny = tf.shape(x)[2]
        # nx=32
        # ny=128
        # channels=1
        x_image = tf.reshape(x, tf.stack([-1, nx, ny, channels]))
        in_node = x_image
        batch_size = tf.shape(x_image)[0]

    weights = []
    biases = []
    convs = []
    pools = OrderedDict()
    deconv = OrderedDict()
    dw_h_convs = OrderedDict()
    up_h_convs = OrderedDict()

    in_size = 1000  # ?????????????????????
    size = in_size
    # down layers
    for layer in range(0, layers):
        with tf.name_scope("down_conv_{}".format(str(layer))):
            features = 2 ** layer * features_root
            stddev = np.sqrt(2 / (filter_size ** 2 * features))
            if layer == 0:
                w1 = weight_variable([filter_size, filter_size, channels, features], stddev, name="w1")
            else:
                w1 = weight_variable([filter_size, filter_size, features // 2, features], stddev, name="w1")

            w2 = weight_variable([filter_size, filter_size, features, features], stddev, name="w2")
            b1 = bias_variable([features], name="b1")
            b2 = bias_variable([features], name="b2")

            conv1 = conv2d(in_node, w1, b1, keep_prob)
            print(str(layer) + ' conv1: ' + str(conv1.get_shape()))
            tmp_h_conv = tf.nn.relu(conv1)
            conv2 = conv2d(tmp_h_conv, w2, b2, keep_prob)
            print(str(layer) + ' conv2: ' + str(conv2.get_shape()))
            dw_h_convs[layer] = tf.nn.relu(conv2)

            weights.append((w1, w2))
            biases.append((b1, b2))
            convs.append((conv1, conv2))

            size -= 2 * 2 * (filter_size // 2)  # valid conv
            if layer < layers - 1:
                pools[layer] = max_pool(dw_h_convs[layer], pool_size)
                in_node = pools[layer]
                size /= pool_size

    in_node = dw_h_convs[layers - 1]

    # up layers
    for layer in range(layers - 2, -1, -1):
        with tf.name_scope("up_conv_{}".format(str(layer))):
            features = 2 ** (layer + 1) * features_root
            stddev = np.sqrt(2 / (filter_size ** 2 * features))

            wd = weight_variable_devonc([pool_size, pool_size, features // 2, features], stddev, name="wd")
            bd = bias_variable([features // 2], name="bd")
            h_deconv = tf.nn.relu(deconv2d(in_node, wd, pool_size) + bd)
            print(str(layer) + ' h_deconv: ' + str(h_deconv.get_shape()))
            h_deconv_concat = crop_and_concat(dw_h_convs[layer], h_deconv)
            print(str(layer) + ' h_deconv_concat: ' + str(h_deconv_concat.get_shape()))
            deconv[layer] = h_deconv_concat

            w1 = weight_variable([filter_size, filter_size, features, features // 2], stddev, name="w1")
            w2 = weight_variable([filter_size, filter_size, features // 2, features // 2], stddev, name="w2")
            b1 = bias_variable([features // 2], name="b1")
            b2 = bias_variable([features // 2], name="b2")

            conv1 = conv2d(h_deconv_concat, w1, b1, keep_prob)
            h_conv = tf.nn.relu(conv1)
            print(str(layer) + ' h_conv1_post_deconv: ' + str(h_conv.get_shape()))
            conv2 = conv2d(h_conv, w2, b2, keep_prob)
            in_node = tf.nn.relu(conv2)
            up_h_convs[layer] = in_node
            print(str(layer) + ' h_conv2_post_deconv: ' + str(in_node.get_shape()))

            weights.append((w1, w2))
            biases.append((b1, b2))
            convs.append((conv1, conv2))

            size *= pool_size
            size -= 2 * 2 * (filter_size // 2)  # valid conv

    # Output Map
    with tf.name_scope("output_map"):
        weight = weight_variable([1, 1, features_root, n_class], stddev)
        bias = bias_variable([n_class], name="bias")
        conv = conv2d(in_node, weight, bias, tf.constant(1.0))
        print(str(layer) + ' outmap: ' + str(conv.get_shape()))

        # output_map = tf.nn.relu(conv)
        output_map = conv  # no activation, to be consistant with other models and leverage previous loss/prediction structures yike !!!!
        up_h_convs["out"] = output_map

    if summaries:
        with tf.name_scope("summaries"):
            for i, (c1, c2) in enumerate(convs):
                tf.summary.image('summary_conv_%02d_01' % i, get_image_summary(c1))
                tf.summary.image('summary_conv_%02d_02' % i, get_image_summary(c2))

            for k in pools.keys():
                tf.summary.image('summary_pool_%02d' % k, get_image_summary(pools[k]))

            for k in deconv.keys():
                tf.summary.image('summary_deconv_concat_%02d' % k, get_image_summary(deconv[k]))

            for k in dw_h_convs.keys():
                tf.summary.histogram("dw_convolution_%02d" % k + '/activations', dw_h_convs[k])

            for k in up_h_convs.keys():
                tf.summary.histogram("up_convolution_%s" % k + '/activations', up_h_convs[k])

    variables = []
    for w1, w2 in weights:
        variables.append(w1)
        variables.append(w2)

    for b1, b2 in biases:
        variables.append(b1)
        variables.append(b2)

    return output_map, variables, int(in_size - size)


class DecoderType:
    BestPath = 0
    BeamSearch = 1
    WordBeamSearch = 2


class Model:
    # model constants
    # batchSize = 50 #qyk
    # imgSize = (128, 32)
    # imgSize = (192, 48) #qyk
    maxTextLen = 32  # qyk?
    MOVING_AVERAGE_DECAY = 0.9999  # The decay to use for the moving average.
    NUM_EPOCHS_PER_DECAY = 350.0  # Epochs after which learning rate decays.
    LEARNING_RATE_DECAY_FACTOR = 0.1  # Learning rate decay factor.

    def __init__(self, args, charList, loss_beta, loss_weight, decoderType=DecoderType.BestPath, experiment=None,
                 mustRestore_seg=False, mustRestore_recg=False, joint=False):  # !!!!!!!!!!!!!!!!!!!!!!!!
        '''
        loss_betaxsegloss+(1-loss_beta)xrecgloss
        loss_weight: used in segnet training
        joint: False -> train recognition only, True -> train segmentation with recognition frozen
        '''
        self.loss_beta = loss_beta  # !!!!!!!!!!!!!!!!!!!!!!!!!!!!
        self.args = args
        self.experiment = experiment
        self.lrInit = args.lrInit
        # self.mustRestore_recg= mustRestore_recg
        ###################################
        "init segnet model parameters:"
        ###################################
        self.mustRestore_seg = mustRestore_seg
        ###model hyperparameters###
        self.num_classes = args.num_class
        # self.FilePaths = FilePaths
        self.batch_size_seg = args.batch_size_seg  # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        self.loss_weight = loss_weight

        ###########################################################################
        "init recognition model parameters: add CNN, RNN and CTC and initialize TF"
        ###########################################################################
        self.charList = charList
        self.decoderType = decoderType
        self.mustRestore_recg = mustRestore_recg
        # self.FilePaths = FilePaths
        self.batchsize_recg = args.batchsize_recg  # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
        # self.lrInit = args.lrInit #!!!!!!!!!!!!!!!!!!!!!!!!
        # self.args = args #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

        ############################################################################
        """Graph Set Up"""
        ############################################################################
        tf.reset_default_graph()  # yike reset default graph  #!!!!!!!!!!!!!!!!!!!!!还要吗？????????
        with tf.name_scope('graph_segmentation'):
            # self.loss_segmentation, output = YIKE_FUNCTION_HERE()

            ###input### -- try to only set up graph once, combine train and test, by yike
            # tf.reset_default_graph() # yike reset default graph
            self.input_images_seg = tf.placeholder(tf.float32, shape=[None, self.args.image_h, self.args.image_w,
                                                                      self.args.image_c])  # try my best to make runtime batch_size flexible #!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            self.input_labels_seg = tf.placeholder(tf.int64, shape=[None, self.args.image_h, self.args.image_w,
                                                                    1])  # !!!!!!!!!!!!!!!!!!!!!
            self.phase_train = tf.placeholder(tf.bool, name='phase_train')

            ###graph### -- combine
            self.logit_seg = self.setup_graph(self.input_images_seg,
                                              self.phase_train)  # !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
            self.loss_seg = self.cal_loss(self.logit_seg, self.input_labels_seg)*500 # make it to same level as recg loss
            self.pred_seg = tf.argmax(self.logit_seg, axis=3)

            input_images_2d_seg = tf.squeeze(self.input_images_seg, [3])  # to 2d images, channel=1
            self.output_clean_seg = tf.to_float(self.pred_seg) * (255 - input_images_2d_seg) + input_images_2d_seg

            print('clean output from seg: ' + str(self.output_clean_seg.get_shape()))

        with tf.name_scope('graph_recognition'):
            # assume the input has been resized to 32x128
            if joint:
                self.input_images_recg = tf.transpose(self.output_clean_seg, perm=(0, 2, 1))
            else:
                self.input_images_recg = tf.placeholder(tf.float32, shape=(None, args.image_w, args.image_h))
            print('recg input: ' + str(self.input_images_recg.get_shape()))
            # CNN
            if args.nondensenet:
                cnnOut4d = self.setupCNN(self.input_images_recg)
            else:  # use densenet by default
                cnnOut4d = self.setupCNNdensenet(self.input_images_recg, args)

            # RNN
            rnnOut3d = self.setupRNN(cnnOut4d)

            # CTC
            (self.ctcloss, self.decoder) = self.setupCTC(rnnOut3d)

            # Explicit regularizers
            self.loss_recg = self.ctcloss + args.wdec * self.setupWdec(args)

        # combine losses
        self.loss_total = (1 - loss_beta) * self.loss_recg + loss_beta * self.loss_seg
        print(self.loss_total)
        # optimizer for NN parameters
        self.batchesTrained = args.batchesTrained  # only for recognition training
        self.learning_rate = tf.placeholder(tf.float32, shape=[])  # for recognition and segmentation
        self.global_step = tf.Variable(0, trainable=False)  # for segmentation training

        self.var_list_train_seg = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "graph_segmentation") #TRAINABLE_
        self.obj_list_savable_seg= tf.get_collection(tf.GraphKeys.VARIABLES, "graph_segmentation")
        self.train_op_seg = self.train_op_seg_prepare(total_loss=self.loss_total, lr=self.learning_rate,
                                                      global_step=self.global_step, var_list=self.var_list_train_seg)
        # self.learning_rate self.loss_total
        ## optimizer for recognition only

        self.var_list_train_recg = tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES, "graph_recognition")#TRAINABLE_
        self.obj_list_savable_recg= tf.get_collection(tf.GraphKeys.VARIABLES, "graph_recognition")
        if args.optimizer == 'rmsprop':
            self.optimizer = tf.train.RMSPropOptimizer(self.learning_rate).minimize(self.loss_recg,
                                                                                    var_list=self.var_list_train_recg)
        elif args.optimizer == 'adam':
            self.optimizer = tf.train.AdamOptimizer(self.learning_rate).minimize(self.loss_recg,
                                                                                 var_list=self.var_list_train_recg)
        elif args.optimizer == 'momentum':
            self.optimizer = tf.train.MomentumOptimizer(self.learning_rate, .9).minimize(self.loss_recg,
                                                                                         var_list=self.var_list_train_recg)

        # self.global_step,var_list=self.var_list_train_seg)  # !!!!!!!!!!!!!!!!!!!!!!!!!!
        # above: loss need to change to total loss
        ###session and saver###
        (self.sess, self.saver_seg, self.saver_recg) = self.initTF()  # tobe changed!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!

    ############################################################
    #####               Segnet Functions             ###########
    ############################################################ Not Adjusted !!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!!
    ### 1. loss factory ###

    def weighted_loss(self, logits, labels):  # num_classes, head=None):
        """ median-frequency re-weighting """
        with tf.name_scope('loss'):
            # print('w_llll')
            logits = tf.reshape(logits, (-1, self.num_classes))
            # print(logits.get_shape())
            epsilon = tf.constant(value=1e-10)

            logits = logits + epsilon

            # consturct one-hot label array
            label_flat = tf.reshape(labels, (-1, 1))
            # print(label_flat.get_shape())

            # should be [batch ,num_classes]
            labels = tf.reshape(tf.one_hot(label_flat, depth=self.num_classes), (-1, self.num_classes))
            # print(labels.get_shape())

            softmax = tf.nn.softmax(logits)
            # print(softmax.get_shape())
            #        print(epsilon.get_shape())

            #        print((labels * tf.log(softmax + epsilon)).get_shape())
            #        print(head.shape)
            #        print(tf.multiply(labels * tf.log(softmax + epsilon), head))

            cross_entropy = -tf.reduce_sum(tf.multiply(labels * tf.log(softmax + epsilon), self.loss_weight),
                                           axis=[1])
            #        print(cross_entropy.get_shape()) # yike head -> self.loss_weight

            cross_entropy_mean = tf.reduce_mean(cross_entropy, name='cross_entropy')
            #        print(cross_entropy_mean.get_shape())
            tf.add_to_collection('losses', cross_entropy_mean)

            loss = tf.add_n(tf.get_collection('losses'), name='total_loss_seg')
            print('loss_seg: ' + str(loss.get_shape()))

        return loss

    def cal_loss(self, logits, labels):
        labels = tf.cast(labels, tf.int32)
        return self.weighted_loss(logits, labels)

        # self.weighted_loss(logits, labels, num_classes=NUM_CLASSES, head=loss_weight)

        ###2. train optimizer factory ##

    def train_op_seg_prepare(self, total_loss, lr, global_step, var_list):
        # all of them are tensor
        # total_sample = 274 yike: ok to comment out?
        # num_batches_per_epoch = 274/1 yike: ok to comment out?

        loss_averages_op = _add_loss_summaries(total_loss)
        # Compute gradients.
        with tf.control_dependencies([loss_averages_op]):
            # print('try...')
            opt = tf.train.AdamOptimizer(lr)
            print('toto_loss_shape: ' + str(total_loss))
            opt.compute_gradients(total_loss, var_list=var_list)  # add list of variables
            grads = opt.compute_gradients(total_loss, var_list=var_list)  # !!!!!!!
            # print(grads)
            apply_gradient_op = opt.apply_gradients(grads, global_step=global_step)

            # Add histograms for trainable variables.
            #######for var in tf.trainable_variables():
            ######tf.summary.histogram(var.op.name, var)

            # Add histograms for gradients.
            #####for grad, var in grads:
            #####if grad is not None:
            #####tf.summary.histogram(var.op.name + '/gradients', grad)

            # Track the moving averages of all trainable variables.
            variable_averages = tf.train.ExponentialMovingAverage(Model.MOVING_AVERAGE_DECAY, global_step)
            variables_averages_op = variable_averages.apply(var_list=var_list)  # tf.trainable_variables()

            with tf.control_dependencies([apply_gradient_op, variables_averages_op]):
                train_op_seg = tf.no_op(name='train_op_seg_prepare')

        return train_op_seg

        ###3. graph factory ###

    def setup_graph(self, images, phase_train):
        # previous inference() labels,inference, batch_size -- in order to get batch_size at running time
        # rather than using fixed batch_size in graph set up, revise it in inference:
        # batchsize=tf.shape(images)[0] # yike !!!
        print('GGG')
        input_shape = images.get_shape().as_list()
        print(input_shape)

        #       create_conv_net(x, keep_prob, channels, n_class, layers=3, features_root=16, filter_size=3, pool_size=2,
        #                    summaries=True)

        logit, _, __ = create_conv_net(x=images, keep_prob=0.8, channels=input_shape[3], n_class=self.num_classes,
                                       layers=3, features_root=32, filter_size=3)
        print(logit.get_shape())
        """
         Start Classify 

        # output predicted class number (6)
        with tf.variable_scope('conv_classifier') as scope:
          kernel = _variable_with_weight_decay('weights',
                                            shape=[1, 1, 64, self.num_classes],
                                            initializer=msra_initializer(1, 64),
                                            wd=0.0005)
          conv = tf.nn.conv2d(conv_decode1, kernel, [1, 1, 1, 1], padding='SAME')
          print('cv')
          print(conv.get_shape())
          biases = _variable_on_cpu('biases', [self.num_classes], tf.constant_initializer(0.0))
          print(biases.get_shape())
          logit= tf.nn.bias_add(conv, biases, name=scope.name)
          #conv_classifier = tf.nn.bias_add(conv, biases, name=scope.name)
          #print(conv_classifier.get_shape())
          #logit = conv_classifier
          #print('LLL')
          #print(labels)
          #print(conv_classifier)

          #loss = cal_loss(conv_classifier, labels)
          print(logit.get_shape())
          """
        return logit  # loss

    ############################################################################
    ###                 Recognition Functions                                ###
    ############################################################################
    def setupCNN(self, cnnIn3d):
        "vanilla cnn from original github repo"
        cnnIn4d = tf.expand_dims(input=cnnIn3d, axis=3)

        # list of parameters for the layers
        kernelVals = [5, 5, 3, 3, 3]
        featureVals = [1, 32, 64, 128, 128, 256]
        strideVals = poolVals = [(2, 2), (2, 2), (1, 2), (1, 2), (1, 2)]
        numLayers = len(strideVals)

        # create layers
        pool = cnnIn4d  # input to first CNN layer
        for i in range(numLayers):
            kernel = tf.Variable(
                tf.truncated_normal([kernelVals[i], kernelVals[i], featureVals[i], featureVals[i + 1]], stddev=0.1))
            conv = tf.nn.conv2d(pool, kernel, padding='SAME', strides=(1, 1, 1, 1))
            relu = tf.nn.relu(conv)
            pool = tf.nn.max_pool(relu, (1, poolVals[i][0], poolVals[i][1], 1),
                                  (1, strideVals[i][0], strideVals[i][1], 1),
                                  'VALID')

        self.is_training = tf.placeholder(tf.bool, shape=[])  # dummy placeholder to prevent error, no effect
        return pool

    def setupCNNdensenet(self, cnnIn3d, args):
        "ADDED BY RONNY: densenet cnn"
        print('shape of cnn input: ' + str(cnnIn3d.get_shape().as_list()))
        cnnIn4d = tf.expand_dims(input=cnnIn3d, axis=3)
        net = Densenet4htr(cnnIn4d, **vars(args))
        self.is_training = net.is_training
        print('shape of cnn output: ' + str(net.output.get_shape().as_list()))
        return net.output

    def setupRNN(self, rnnIn4d):
        "create RNN layers and return output of these layers"
        rnnIn3d = tf.squeeze(rnnIn4d, axis=[2])

        # basic cells which is used to build RNN
        numHidden = self.args.rnndim
        cells = [tf.contrib.rnn.LSTMCell(num_units=numHidden, state_is_tuple=True) for _ in range(2)]  # 2 layers

        # stack basic cells
        stacked = tf.contrib.rnn.MultiRNNCell(cells, state_is_tuple=True)

        # bidirectional RNN
        # BxTxF -> BxTx2H
        ((fw, bw), _) = tf.nn.bidirectional_dynamic_rnn(cell_fw=stacked, cell_bw=stacked, inputs=rnnIn3d,
                                                        dtype=rnnIn3d.dtype, scope="graph_recognition/bidirectional_rnn")

        # BxTxH + BxTxH -> BxTx2H -> BxTx1X2H
        concat = tf.expand_dims(tf.concat([fw, bw], 2), 2)

        # project output to chars (including blank): BxTx1x2H -> BxTx1xC -> BxTxC
        kernel = tf.Variable(tf.truncated_normal([1, 1, numHidden * 2, len(self.charList) + 1], stddev=0.1))
        logits = tf.squeeze(tf.nn.atrous_conv2d(value=concat, filters=kernel, rate=1, padding='SAME'), axis=[2])
        # with tf.variable_scope('logits'):
        #   logits = tf.squeeze(tf.layers.conv2d(concat, len(self.charList)+1, 1, use_bias=True), axis=[2]) # FIXED BY RONNY
        return logits

    def setupCTC(self, ctcIn3d):
        "create CTC loss and decoder and return them"
        # BxTxC -> TxBxC
        ctcIn3dTBC = tf.transpose(ctcIn3d, [1, 0, 2])
        # ground truth text as sparse tensor
        self.gtTexts = tf.SparseTensor(tf.placeholder(tf.int64, shape=[None, 2]),
                                       tf.placeholder(tf.int32, [None]),
                                       tf.placeholder(tf.int64, [2]))
        # calc loss for batch
        self.seqLen = tf.placeholder(tf.int32, [None])

        loss = tf.nn.ctc_loss(labels=self.gtTexts, inputs=ctcIn3dTBC, sequence_length=self.seqLen,
                              ctc_merge_repeated=True)  # , ignore_longer_outputs_than_inputs=True) #qyk

        # decoder: either best path decoding or beam search decoding
        if self.decoderType == DecoderType.BestPath:
            decoder = tf.nn.ctc_greedy_decoder(inputs=ctcIn3dTBC, sequence_length=self.seqLen)
        elif self.decoderType == DecoderType.BeamSearch:
            decoder = tf.nn.ctc_beam_search_decoder(inputs=ctcIn3dTBC, sequence_length=self.seqLen, beam_width=50,
                                                    merge_repeated=False)
        elif self.decoderType == DecoderType.WordBeamSearch:
            # import compiled word beam search operation (see https://github.com/githubharald/CTCWordBeamSearch)
            word_beam_search_module = tf.load_op_library('TFWordBeamSearch.so')

            # prepare information about language (dictionary, characters in dataset, characters forming words)
            chars = str().join(self.charList)
            wordChars = open('wordCharList.txt').read().splitlines()[0]
            corpus = open(self.FilePaths.fnCorpus).read()

            # decode using the "Words" mode of word beam search
            decoder = word_beam_search_module.word_beam_search(tf.nn.softmax(ctcIn3dTBC, dim=2), 50, 'Words', 0.0,
                                                               corpus.encode('utf8'), chars.encode('utf8'),
                                                               wordChars.encode('utf8'))

        # return a CTC operation to compute the loss and a CTC operation to decode the RNN output
        return (tf.reduce_mean(loss), decoder)

    def setupWdec(self, args):
        """L2 weight decay loss."""
        costs = []
        for var in tf.trainable_variables():  # all weights count toward weight decay except batchnorm and biases
            if var.op.name.find(r'BatchNorm') == -1 & var.op.name.find(r'bias:0') == -1:
                costs.append(tf.nn.l2_loss(var))
        return tf.add_n(costs)

    def toSparse(self, texts):
        "put ground truth texts into sparse tensor for ctc_loss"
        indices = []
        values = []
        shape = [len(texts), 0]  # last entry must be max(labelList[i])

        # go over all texts
        for (batchElement, text) in enumerate(texts):
            # convert to string of label (i.e. class-ids)
            labelStr = [self.charList.index(c) for c in text]
            # sparse tensor must have size of max. label-string
            if len(labelStr) > shape[1]:
                shape[1] = len(labelStr)
            # put each label into sparse tensor
            for (i, label) in enumerate(labelStr):
                indices.append([batchElement, i])
                values.append(label)

        return (indices, values, shape)

    def decoderOutputToText(self, ctcOutput):
        "extract texts from output of CTC decoder"
        bt_size = ctcOutput[1].shape[0]  # yike !!!!!!
        # contains string of labels for each batch element
        encodedLabelStrs = [[] for i in range(bt_size)]  # yike self.batchsize !!!!!!!

        # word beam search: label strings terminated by blank
        if self.decoderType == DecoderType.WordBeamSearch:
            blank = len(self.charList)
            for b in range(bt_size):  # yike self.batchsize !!!!!!!
                for label in ctcOutput[b]:
                    if label == blank:
                        break
                    encodedLabelStrs[b].append(label)

        # TF decoders: label strings are contained in sparse tensor
        else:
            # ctc returns tuple, first element is SparseTensor
            decoded = ctcOutput[0][0]

            # go over all indices and save mapping: batch -> values
            idxDict = {b: [] for b in range(bt_size)}  # yike self.batchsize !!!!!
            for (idx, idx2d) in enumerate(decoded.indices):
                label = decoded.values[idx]
                batchElement = idx2d[0]  # index according to [b,t]
                encodedLabelStrs[batchElement].append(label)

        # map labels to chars for all batch elements
        return [str().join([self.charList[c] for c in labelStr]) for labelStr in encodedLabelStrs]

    #########################################################
    ####             Initialize TF (Both)                ####
    #########################################################

    def initTF(self):
        "initialize TF"
        print('Python: ' + sys.version)
        print('Tensorflow: ' + tf.__version__)

        sess = tf.Session(
            config=tf.ConfigProto(allow_soft_placement=True, gpu_options=tf.GPUOptions(allow_growth=True)))

        #####################################
        ##        SegNet Initiation        ##
        #####################################

        saver_seg = tf.train.Saver(var_list=self.obj_list_savable_seg, max_to_keep=1)  # saver saves model to file

        sess.run(tf.global_variables_initializer())
        print('Ran global_variables_initializer first')
        # Restore from saved model in current checkpoint directory
        latestSnapshot_seg = tf.train.latest_checkpoint(self.args.ckptpath_seg)  # is there a saved model?
        if self.mustRestore_seg and not latestSnapshot_seg:  # if model must be restored (for inference), there must be a snapshot
            raise Exception('No saved model found in: ' + self.args.ckptpath_seg)

        if latestSnapshot_seg:  # load saved model if available
            saver_seg.restore(sess, latestSnapshot_seg)
            print('Init with stored values from ' + latestSnapshot_seg)
        else:
            # sess.run(tf.global_variables_initializer())
            # print('Ran global_variables_initializer')
            sess.run(tf.initializers.variables(var_list=self.var_list_train_seg, name='init_seg'))
            print('Ran initializers.variables on segnet trainable variables')

        '''
            # initialize params from other model (transfer learning)
        if self.args.transfer:
            utils.maybe_download(source_url=self.args.urlTransferFrom,
                                 filename=join(self.args.ckptpath_seg, 'transferFrom'),
                                 target_directory=None,
                                 filetype='folder',
                                 force=True)
            saverTransfer = tf.train.Saver(
                tf.trainable_variables()[:-1])  # load all variables except from logit (classification) layer
            saverTransfer.restore(sess, glob(join(self.args.ckptpath_seg, 'transferFrom', 'model*'))[0].split('.')[0])
            print('Loaded variable values (except logit layer) from ' + self.args.urlTransferFrom)
        '''
        #############################################
        ###         Recognition Initialization    ###
        #############################################
        saver_recg = tf.train.Saver(var_list=self.obj_list_savable_recg, max_to_keep=1)

        latestSnapshot_recg = tf.train.latest_checkpoint(self.args.ckptpath_recg)  # is there a saved model?
        if self.mustRestore_recg and not latestSnapshot_recg:  # if model must be restored (for inference), there must be a snapshot
            raise Exception('No saved model found in: ' + self.args.ckptpath_recg)

        if latestSnapshot_recg:  # load saved model if available
            saver_recg.restore(sess, latestSnapshot_recg)
            print('Init with stored values from ' + latestSnapshot_recg)
        else:
            sess.run(tf.initializers.variables(var_list=self.var_list_train_recg, name='init_recg'))
            print('Ran initializers.variables on recognition trainable variables')
        # +++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
        # initialize params from other model (transfer learning)
        """
        if self.args.transfer:
            utils.maybe_download(source_url=self.args.urlTransferFrom,
                                 filename=join(self.args.ckptpath_recg, 'transferFrom'),
                                 target_directory=None,
                                 filetype='folder',
                                 force=True)
            saverTransfer = tf.train.Saver(
                tf.trainable_variables()[:-1])  # load all variables except from logit (classification) layer
            saverTransfer.restore(sess, glob(join(self.args.ckptpath_recg, 'transferFrom', 'model*'))[0].split('.')[0])
            print('Loaded variable values (except logit layer) from ' + self.args.urlTransferFrom)
        """

        return (sess, saver_seg, saver_recg)
    #######################################################
    #####         Training, Inference and Save        #####
    #######################################################

    #######################SegNet##########################
    def saveSeg(self, epoch):
       "save model to file"
       self.saver_seg.save(self.sess, join(self.args.ckptpath_seg, 'model'), global_step=epoch)
    def trainBatchSeg(self, images, labels, labels_recg): # added labels_recg!!!!!!!!!!!!!!!!
        "feed a batch into the NN to train it"

        # sparse = self.toSparse(labels)
        # lrnrate = self.lrInit if self.batchesTrained < self.args.lrDrop1 else (
        # self.lrInit*1e-1 if self.batchesTrained < self.args.lrDrop2 else self.lrInit*1e-2)  # decay learning rate
        bt_size=len(images)
        train_step = self.global_step.eval(session=self.sess)
        sparse = self.toSparse(labels_recg) # added !!!!!!!!!!!!!!!!!!!!!!!!!!!!
        """ fix lr """  ## To Ronny, change the schedule?
        # lr = self.lrInit
        lr = self.lrInit if train_step < self.args.lrDrop1 else (
            self.lrInit * 1e-1 if train_step < self.args.lrDrop2 else self.lrInit * 1e-2)  # yike
        (_, lossValTotal,lossValSeg) = self.sess.run([self.train_op_seg, self.loss_total,self.loss_seg],
                                     {self.input_images_seg: images,
                                      #self.input_images_recg: images, # added !!!!!!!!!!!!!!!
                                      self.input_labels_seg: labels,
                                      self.gtTexts:sparse, # added !!!!!!!!!!!!!!!!!!!!!!!!!!!
                                      self.seqLen: [Model.maxTextLen]*bt_size, #* self.batchsize_seg, #added!!!!!!!!!!!!!!!!!!!!!!
                                      self.learning_rate: lr,
                                      self.phase_train: True,
                                      self.is_training: False})
        # self.batchesTrained += 1
        return lossValTotal,lossValSeg

    def inferBatchSeg(self, imgs):  # modify to compatible to torch. previous def inferBatch(self, batch)
        "feed a batch into the NN to recngnize the texts"

        bt_size = len(imgs)  # yike !!!!!!!!

        pred = self.sess.run(self.pred_seg, feed_dict=
        {self.input_images_seg: imgs,  # check in, comment out in formal run
         # self.input_labels: labels,
         self.phase_train: False,
         self.is_training: False})  # yike self.batchsize!!!!!!!!!
        return pred
    def imageCleanSeg(self, imgs):
        bt_size = len(imgs)
        cleaneds=self.sess.run(self.output_clean_seg, feed_dict={self.input_images_seg: imgs, self.phase_train: False, self.is_training:False})
        return cleaneds
    def trainSeg(self, loader, validateloader=None, testloader=None):
        "train NN"
        epoch = 0  # number of training epochs since start
        best_accuracy = 0.0
        step = 0
        while True:
            epoch += 1;
            print('Epoch:', epoch, ' Training...')
            # train
            counter = 0
            # step = 0
            for idx, (images, labels, labels_recg) in enumerate(loader):
                images = images.numpy()
                labels = labels.numpy()
                #labels_recg=labels_recg.numpy()
                loss_value_total,loss_value_seg = self.trainBatchSeg(images, labels, labels_recg)
                assert not np.isnan(loss_value_total), 'Model diverged with loss = NaN'
                step += 1

                if idx % 100 == 0:
                    print('TRAIN: Batch:', idx / len(loader), 'Loss_Total:', loss_value_total)
                    print('TRAIN: Batch:', idx / len(loader), 'Loss_Seg:', loss_value_seg)
                    self.experiment.log_metric('train/loss_total', loss_value_total, step)
                    self.experiment.log_metric('train/loss_seg', loss_value_seg, step)#!!!!!!!!!!!!!!!!!!!!!!!
                    
                    logits = self.sess.run(self.logit_seg,
                                           feed_dict={self.input_images_seg: images,  # check in, comment out in formal run
                                                      # self.input_labels: labels,
                                                      # self.learning_rate: lr,
                                                      self.phase_train: False,
                                                      self.is_training:False})
                    train_acc, train_acc_classes = per_class_acc(logits, labels)  # check in, comment out in formal run

            # train log:
            if self.experiment is not None:
                self.experiment.log_metric('train/acc', train_acc, step)
                self.experiment.log_metric('train/cap_0', train_acc_classes[0], step)
                self.experiment.log_metric('train/cap_1', train_acc_classes[1], step)

            # validate:
            if validateloader != None:
                avg_batch_loss_seg,avg_batch_loss_total, acc_total, cap_0, cap_1 = self.validateSeg(validateloader, epoch)
            else:
                avg_batch_loss_seg,avg_batch_loss_total, acc_total, cap_0, cap_1 = self.validateSeg(loader, epoch)
            if self.experiment is not None:
                self.experiment.log_metric('valid/acc', acc_total, step)
                self.experiment.log_metric('valid/cap_0', cap_0, step)
                self.experiment.log_metric('valid/cap_1', cap_1, step)
                self.experiment.log_metric('valid/loss_seg', avg_batch_loss_seg, step)
                self.experiment.log_metric('valid/loss_total', avg_batch_loss_total, step)
                
            # test:
            if testloader != None:
                acc_total, cap_0, cap_1 = self.validateSeg(testloader, epoch, is_testing=True)
                if self.experiment is not None:
                    self.experiment.log_metric('test/acc', acc_total, step)
                    self.experiment.log_metric('test/cap_0', cap_0, step)
                    self.experiment.log_metric('test/cap_1', cap_1, step)

            # log best metrics
            if acc_total > best_accuracy:  # if best validation accuracy so far, save model parameters
                print('Character error rate improved, save model')
                best_accuracy = acc_total
                noImprovementSince = 0
                self.saveSeg(epoch)
                open(join(self.args.ckptpath_seg, 'accuracy.txt'), 'w').write(
                    'Validation accuracy, class 0, class 1 capture rates of saved model: %f%%, %f%% and %f%% ' % (
                    acc_total * 100.0, cap_0 * 100.0, cap_1 * 100.0))
                if self.experiment is not None:
                    self.experiment.log_metric('best/acc', acc_total, step)
                    self.experiment.log_metric('best/cap_0', cap_0, step)
                    self.experiment.log_metric('best/cap_1', cap_1, step)
            else:
                print('Character error rate not improved')
                noImprovementSince += 1

            # stop training
            if epoch >= self.args.max_epoch: print('Done with training at epoch', epoch,'sigoptObservation=' + str(best_accuracy)); break

    def validateSeg(self, loader, epoch, is_testing=False):
        "validate NN"
        if not is_testing:
            print('Validating NN')
        else:
            print('Testing NN')
        total_val_loss_seg = 0.0
        total_val_loss_total= 0.0
        # num_batches=len(loader)
        hist = np.zeros((self.num_classes, self.num_classes))

        image_upload_count = 0
        for idx, (images, labels, labels_recg) in enumerate(loader):
            
            images = images.numpy()
            labels = labels.numpy()
            bt_size=len(images)            
            sparse=self.toSparse(labels_recg) #added!!!!!!!!!!!!!!!!!!!!!!!!
            #labels_recg=labels_recg.numpy() #added!!!!!!!!!!!!!!!!!!!!!!!!
            #sparse=self.toSparse()
            val_loss_total, val_loss_seg, val_logit = self.sess.run([self.loss_total,self.loss_seg, self.logit_seg], feed_dict=
            {self.input_images_seg: images,  # check in, comment out in formal run
             self.input_labels_seg: labels,
             self.gtTexts:sparse,
             self.seqLen: [Model.maxTextLen] * bt_size,#self.batchsize_recg, #changed!!!!!!!!!!!!!!!!!!!
             self.phase_train: False,
             self.is_training:False})  # self.loss,val_loss,

            total_val_loss_seg += val_loss_seg
            total_val_loss_total += val_loss_total#!!!!!!!!!!!!!!!!!!!!!!!
            
            hist += get_hist(val_logit, labels)
            # val_loss=total_val_loss / len(validateloader)*batch_size

            if epoch == self.args.max_epoch and image_upload_count < 1000 and self.experiment is not None:  # decide how many images to upload
                pred = val_logit.argmax(3)
                images = np.squeeze(images, axis=3)
                image_upload_count = log_images(images, pred, image_upload_count, self.experiment,
                                                self.args.ckptpath_seg)

        avg_batch_loss_seg = total_val_loss_seg / idx
        avg_batch_loss_total = total_val_loss_total / idx
        
        cls_sample_nums = hist.sum(1).astype(float)
        capture_array = np.diag(hist)
        acc_total = capture_array.sum() / hist.sum()
        capture_rate_ls = []
        for cls in range(self.num_classes):
            if cls_sample_nums[cls] == 0:
                capture_rate = 0.0
            else:
                capture_rate = capture_array[cls] / cls_sample_nums[cls]
            capture_rate_ls.append(capture_rate)
        # iu = np.diag(hist) / (hist.sum(1) + hist.sum(0) - np.diag(hist))
        # mean_iu=np.nanmean(iu)
        print('VALID: Total accuracy: %f%%. Class 0 capture: %f%%. Class 1 capture: %f%%' % (
            acc_total * 100.0, capture_rate_ls[0] * 100.0, capture_rate_ls[1] * 100.0))
        return avg_batch_loss_seg,avg_batch_loss_total, acc_total, capture_rate_ls[0], capture_rate_ls[1]

            ##################Recognition##########################

    def trainBatchRecg(self, images, labels): #!!!!!!!!!!!!!!!!

        "feed a batch into the NN to train it"
        sparse = self.toSparse(labels)
        bt_size=len(images)#!!!!!!!!!!!!!!!!!!!!
        lrnrate = self.lrInit if self.batchesTrained < self.args.lrDrop1 else (self.lrInit * 1e-1 if self.batchesTrained < self.args.lrDrop2 else self.lrInit * 1e-2)  # decay learning rate
        (_, lossVal) = self.sess.run([self.optimizer, self.loss_recg],
                                    {self.input_images_recg: images,
                                     self.gtTexts: sparse,
                                     self.seqLen: [Model.maxTextLen]*bt_size,# * self.batchsize_recg,
                                     self.learning_rate: lrnrate,
                                     self.is_training: True})
        self.batchesTrained += 1
        return lossVal

    def inferBatchRecg(self, imgs):  # modify to compatible to torch. previous def inferBatch(self, batch)
        "feed a batch into the NN to recngnize the texts"
        '''if batch to infer less than args.batchsize, error'''

        bt_size = len(imgs)  # yike !!!!!!!!

        decoded = self.sess.run(self.decoder,
                                {self.input_images_recg: imgs, self.seqLen: [Model.maxTextLen] * bt_size,
                                 self.is_training: False})  # yike self.batchsize!!!!!!!!!
        return self.decoderOutputToText(decoded)  # previous batch.imgs

    def saveRecg(self, epoch):
        "save model to file"
        self.saver_recg.save(self.sess, join(self.args.ckptpath_recg, 'model'), global_step=epoch)

    def trainRecg(self, loader, validateloader=None, testloader=None):  # model

        "train NN"
        epoch = 0  # number of training epochs since start
        bestCharErrorRate = bestWordErrorRate = float('inf')  # best valdiation character error rate

        while True:
            epoch += 1;
            print('Epoch:', epoch, ' Training...')

            # train
            counter = 0
            step = 0

            for idx, (images, labels) in enumerate(loader):

                # convert torchtensor to numpy
                images = images.numpy()

                # train batch
                # try:
                loss = self.trainBatchRecg(images, labels)
                # except:
                #  print(labels)
                step += 1

                # save training status
                if np.mod(idx, 110) == 0:
                    print('TRAIN: Batch:', idx / len(loader), 'Loss:', loss)
                    if self.experiment is not None:
                        self.experiment.log_metric('train/loss', loss, step)

                # log images
                if epoch == 1 and counter < 5:
                    text = labels[counter]
                    utils_recg.log_image(self.experiment, images[counter], text, 'train', self.args.ckptpath_recg, counter, epoch)
                    counter += 1
                # for debug
                # if idx >2:
                #  break

            # validate
            if validateloader != None:
                charErrorRate, wordAccuracy = self.validateRecg(validateloader, epoch)  # yike !!!!!!!!!!!!
            else:  # yike !!!!!!!!!!!!!
                charErrorRate, wordAccuracy = self.validateRecg(loader, epoch)
            if self.experiment is not None:
                self.experiment.log_metric('valid/cer', charErrorRate, step)
                self.experiment.log_metric('valid/wer', 1 - wordAccuracy, step)

            # test
            if testloader != None:
                charErrorRate, wordAccuracy = self.validateRecg(testloader, epoch, is_testing=True)
                if self.experiment is not None:
                    self.experiment.log_metric('test/cer', charErrorRate, step)
                    self.experiment.log_metric('test/wer', 1 - wordAccuracy, step)

            # log best metrics
            if charErrorRate < bestCharErrorRate:  # if best validation accuracy so far, save model parameters
                print('Character error rate improved, save model')
                bestCharErrorRate = charErrorRate
                noImprovementSince = 0
                self.saveRecg(epoch)
                open(join(args.ckptpath_recg, 'accuracy.txt'), 'w').write(
                    'Validation character error rate of saved model: %f%%' % (charErrorRate * 100.0))
            else:
                print('Character error rate not improved')
                noImprovementSince += 1
            if 1 - wordAccuracy < bestWordErrorRate:
                bestWordErrorRate = 1 - wordAccuracy
            if self.experiment is not None:
                self.experiment.log_metric('best/cer', bestCharErrorRate, step)
                self.experiment.log_metric('best/wer', bestWordErrorRate, step)

            # stop training
            if epoch >= args.epochEnd: print('Done with training at epoch', epoch,
                                         'sigoptObservation=' + str(bestCharErrorRate)); break

    def validateRecg(self, loader, epoch, is_testing=False):
        "validate NN"
        if not is_testing: print('Validating NN')
        else: print('Testing NN')
        #loader.validationSet() # comment out by yike. see row 141
        numCharErr, numCharTotal, numWordOK, numWordTotal = 0, 0, 0, 0
        plt.figure(figsize=(6,2))
        counter = 0
        '''
        yike: convert to troch dataloader, test
        '''
        for idx, (images, labels) in enumerate(loader):
            if np.mod(idx,10)==0:
                print(str(idx*50*8))
            images=images.numpy()
            recognized=self.inferBatchRecg(images)

            for i in range(len(recognized)):
                numWordOK += 1 if labels[i] == recognized[i] else 0 #batch.gtTexts[i]
                numWordTotal += 1
                dist = editdistance.eval(recognized[i], labels[i])# batch.gtTexts[i])
                numCharErr += dist
                numCharTotal += len(labels[i]) #batch.gtTexts[i]

                if is_testing and epoch==self.args.epochEnd and self.experiment is not None: #batch.gtTexts[i]
                    text = ' '.join(['[OK]' if dist == 0 else '[ERR:%d]' % dist, '"' + labels[i] + '"', '->', '"' + recognized[i] + '"'])
                    utils_recg.log_image(self.experiment, images[i], text, 'test-'+('ok' if dist==0 else 'err'), self.args.ckptpath_recg, counter, epoch)
                    counter += 1 # previous batch.imgs[i]

            if epoch==1 and counter<5 and not is_testing and self.experiment is not None: # log images
                text = ' '.join(['[OK]' if dist == 0 else '[ERR:%d]' % dist, '"' + labels[i] + '"', '->', '"' + recognized[i] + '"'])
                utils_recg.log_image(self.experiment, images[i], text, 'valid', args.ckptpath_recg, counter, epoch) #batch.gtTexts[i]
                counter += 1 #batch.imgs[i]


        # print validation result
        charErrorRate = numCharErr / numCharTotal
        wordAccuracy = numWordOK / numWordTotal
        print('VALID: Character error rate: %f%%. Word accuracy: %f%%.' % (charErrorRate * 100.0, wordAccuracy * 100.0))
        return charErrorRate, wordAccuracy

# %%
#model=Model(args, charList="", loss_beta=0.6,loss_weight=[.5,.5], decoderType=DecoderType.BestPath,experiment=None,mustRestore_seg=False,mustRestore_recg=False)

# %% [markdown]
# # Segment Parameters

# %%
#General Settings
parser = argparse.ArgumentParser()

# system basics
#parser.add_argument("-name", default='segnet_unet_hvbw_all_combine_100_epoches', type=str, help="name of the log") #debug model_intersect # segnet_no_intersect_1conv_64_channels_30epoch_unet_github
parser.add_argument("-name_seg", default='debug_seg_what_ever', type=str, help="name of the log") #debug model_intersect # segnet_no_intersect_1conv_64_channels_30epoch_unet_github
#segnet_binary_100epoch_unet_github
parser.add_argument("-gpu", default='1', type=str, help="gpu numbers")

parser.add_argument("-train", default=True, help="train the NN", action="store_true")
parser.add_argument("-validate", help="validate the NN", action="store_true")

parser.add_argument("-transfer",default=False, help="test the NN", action="store_true")

parser.add_argument("-test",default=False, help="test the NN", action="store_true")

# image and logistic parameters 
parser.add_argument("-image_h", default=32, type=int, help='image height') #('image_h', "360", """ image height """) 32
parser.add_argument("-image_w", default=128, type=int, help='image width')#('image_w', "480", """ image width """)128
#parser.add_argument("-image_h", default=360, type=int, help='image height') 
#parser.add_argument("-image_w", default=480, type=int, help='image width')

parser.add_argument("-image_c", default=1, type=int, help='image channel')#('image_c', "3", """ image channel (RGB) """)
parser.add_argument("-num_class", default=2, type=int, help='total class number')

# training hyperparam
parser.add_argument("-batch_size_seg", default=10, type=int, help='batch_size')
parser.add_argument("-lrInit", default=1e-3, type=int, help='initial lr')
parser.add_argument("-lrDrop1", default=10, type=int, help='step to drop lr by 10 first time') # not sure
parser.add_argument("-lrDrop2", default=1000, type=int, help='step to drop lr by 10 sexond time') # not sure
parser.add_argument('-max_epoch',default=100, type=int,help='max epoch numbers')



# file paths
parser.add_argument('-ckpt_root', default="/root/ckpt", type=str,help= "dir to store ckpt") # log_dir !!!!!
parser.add_argument('-data_root', default="/root/datasets", type=str, help=" root to any data folder ")
parser.add_argument('-urlTranferFrom', default="", type=str, help=" archived model url ")


#args = parser.parse_args()
# Out:
# _StoreAction(option_strings=['-urlTranferFrom'], dest='urlTranferFrom', nargs=None, const=None, default='', type=<class 'str'>, choices=None, help=' archived model url ', metavar=None)

# %% [markdown]
# # Recognition Parameters

# %%
# Recognition Model
# basic operations
parser.add_argument("-name_recg", default="recg_new_five_datasets", type=str, help="name of the log") #'dense_128_32_noartifact_beamsearch_5_datasets'
#parser.add_argument("-gpu", default='-1', type=str, help="gpu numbers")
#parser.add_argument("-train", help="train the NN", action="store_true")
#parser.add_argument("-validate", help="validate the NN", action="store_true")
#parser.add_argument("-transfer", action="store_true")
#actually not effective:
parser.add_argument("-batchesTrained", default=0, type=int, help='number of batches already trained (for lr schedule)') 
# beam search
parser.add_argument("-beamsearch", help="use beam search instead of best path decoding",default=True, action="store_true")
parser.add_argument("-wordbeamsearch", help="use word beam search instead of best path decoding", action="store_true")
# training hyperparam
parser.add_argument("-batchsize_recg", default=10, type=int, help='batch size') # actually not effective in infrerence
#parser.add_argument("-lrInit", default=1e-2, type=float, help='initial learning rate') # actually not effective
parser.add_argument("-optimizer", default='rmsprop', help="adam, rmsprop, momentum") # actually not effective
parser.add_argument("-wdec", default=1e-4, type=float, help='weight decay') # acctually not effective
#parser.add_argument("-lrDrop1", default=10, type=int, help='step to drop lr by 10 first time')
#parser.add_argument("-lrDrop2", default=1000, type=int, help='step to drop lr by 10 sexond time')
parser.add_argument("-epochEnd", default=40, type=int, help='end after this many epochs')
# trainset hyperparam
#parser.add_argument("-noncustom", help="noncustom (original) augmentation technique", action="store_true")
#parser.add_argument("-noartifact", help="dont insert artifcats", action="store_true")
#parser.add_argument("-iam", help='use iam dataset', action='store_true')
# densenet hyperparam
parser.add_argument("-nondensenet", help="use noncustom (original) vanilla cnn", action="store_true")
parser.add_argument("-growth_rate", default=12, type=int, help='growth rate (k)')
parser.add_argument("-layers_per_block", default=18, type=int, help='number of layers per block')
parser.add_argument("-total_blocks", default=5, type=int, help='nuber of densenet blocks')
parser.add_argument("-keep_prob", default=1, type=float, help='keep probability in dropout')
parser.add_argument("-reduction", default=0.4, type=float, help='reduction factor in 1x1 conv in transition layers')
parser.add_argument("-bc_mode", default=True, type=bool, help="bottleneck and compresssion mode")
# rnn,  hyperparams
parser.add_argument("-rnndim", default=256, type=int, help='rnn dimenstionality') #256
parser.add_argument("-rnnsteps", default=32, type=int, help='number of desired time steps (image slices) to feed rnn')
# img size
parser.add_argument("-imgsize", default=[128,32], type=int, nargs='+') #qyk default 128,32 // use segnet definition
# testset crop
#parser.add_argument("-crop_r1", default=3, type=int)
#parser.add_argument("-crop_r2", default=28, type=int)
#parser.add_argument("-crop_c1", default=10, type=int)
#parser.add_argument("-crop_c2", default=115, type=int)
# filepaths
parser.add_argument("-dataroot", default='/root/datasets', type=str)
#######parser.add_argument("-ckptroot", default='/root/ckpt', type=str)##############
#parser.add_argument("-urlTransferFrom", default=None, type=str)

args = parser.parse_known_args()[0]

### SegNet
home = os.environ['HOME']
#name = args.name
#ckptroot = join(home, 'ckpt')
#args.ckptpath = join(ckptroot, name)
#os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu

####args = parser.parse_known_args()[0]

name_seg = args.name_seg
name_recg=args.name_recg

os.environ['CUDA_VISIBLE_DEVICES'] = args.gpu

ckptroot = args.ckpt_root
args.ckptpath_seg = join(ckptroot, name_seg)
args.ckptpath_recg = join(ckptroot, name_recg)
if args.name_seg=='debug_seg_': shutil.rmtree(args.ckptpath_seg, ignore_errors=True)
if args.name_recg=='debug_recg_': shutil.rmtree(args.ckptpath_recg, ignore_errors=True)

os.makedirs(args.ckptpath_seg, exist_ok=True)
os.makedirs(args.ckptpath_recg, exist_ok=True)

#recg_name=args.recg_name
#args.regckptpath=join(ckptroot,recg_name)

# %% [markdown]
# # Train Recognition

# %%
experiment.set_name('recg_new_five_datasets')
experiment.log_parameters(vars(args))

# %%
from datasets_recg import *

# %%
decoderType = DecoderType.BestPath
if args.beamsearch:
    decoderType = DecoderType.BeamSearch
elif args.wordbeamsearch:
    decoderType = DecoderType.WordBeamSearch
if args.train or args.validate:

    # load training data, create TF model
    # loader = DataLoader(FilePaths.fnTrain, args.batchsize, args.imgsize, Model.maxTextLen, args)
    # testloader = DataLoader(FilePaths.fnTest, args.batchsize, args.imgsize, Model.maxTextLen, args, is_test=True)

    # tnansforms#
    transform_train = transforms.Compose([
        # lambda img: (np.zeros([args.imgsize[1], args.imgsize[0]]) if img is None or np.min(img.shape) <= 1 else cv2.resize(img, (args.imgsize[1],args.imgsize[0]), interpolation=cv2.INTER_CUBIC)),
        # lambda img: np.zeros([args.imgsize[1], args.imgsize[0]]) if (img is None or np.min(img.shape) <= 1) else cv2.resize(img, (args.imgsize[1],args.imgsize[0]), interpolation=cv2.INTER_CUBIC)
        transforms.Lambda(
            lambda img: cv2.resize(img, (args.imgsize[0], args.imgsize[1]), interpolation=cv2.INTER_CUBIC)),
        # (img, (32,128), interpolation=cv2.INTER_CUBIC),
        #transforms.Lambda(lambda img: add_artifacts(img, args)),
        # transforms.Lambda(lambda img: img_normalize(img)),
        transforms.Lambda(lambda img: cv2.transpose(img))
        # lambda img: cv2.resize(img, (args.imgsize[1], args.imgsize[0]), interpolation=cv2.INTER_CUBIC),
    ])

    # yike: to use torch.transform.classes, please convert numpy to PIL first. i.e.transforms.Resize(size=(args.imgsize[1], args.imgsize[0]), interpolation=PIL.Image.BICUBIC)

    # instantiate datasets
    iam = IAM(args.dataroot, transform=transform_train)
    eydigits = EyDigitStrings(args.dataroot, transform=transform_train)
    #printed = PRT(args.dataroot, transform=transform_train)  # yike todo
    printed =PRT_WORD(args.dataroot,transform=transform_train)
    irs = IRS(args.dataroot,transform=transform_train) #yike todo
    freal=REAL(args.dataroot,transform=transform_train)

    # tst=irs.__getitem__(1)
    # print(type(tst[0]))
    # print(tst[0].shape)
    # cv2.imshow('tst',tst[0])
    # cv2.imwrite('/root/Engagements/test/tst1.jpg', tst[0])
    # concatenate datasets
    concat =  ConcatDataset([iam, eydigits,irs,printed,freal]) # concatenate the multiple datasets yike notice!!!!
    print(len(concat))
    # concat= printed
    # concat=eydigits
    idxTrain = int(.9 * len(concat))
    trainset, testset = random_split(concat, [idxTrain, len(concat) - idxTrain])
    print(str(len(trainset) / 50))
    print(str(len(testset) / 50))
    trainloader = DataLoader(trainset, batch_size=args.batchsize_recg, shuffle=True, drop_last=True, num_workers=4)
    validateloader = DataLoader(trainset, batch_size=args.batchsize_recg * 8, shuffle=False, drop_last=False, num_workers=2)
    testloader = DataLoader(testset, batch_size=args.batchsize_recg * 8, shuffle=False, drop_last=False,
                            num_workers=2)  # yike: feel not right
    # testloader=DataLoader(testset, batch_size=args.batchsize,shuffle=False, num_workers=2) # yike: all test data included, no sampling. validation is not training. , sampler=SequentialSampler

    # save characters of model for inference mode
    charlist = list(set.union(set(iam.charList),set(eydigits.charList),set(irs.charList),set(printed.charList),set(freal.charList))) # yike notice !!!!
    #charlist = list(set(printed.charList))
    charlist.sort()
    # charlist=eydigits.charList
    open(join(args.ckptpath_recg, 'charList.txt'), 'w').write(str().join(charlist))

    # # save words contained in dataset into file
    # open(FilePaths.fnCorpus, 'w').write(str(' ').join(loader.trainWords + loader.validationWords))

    # execute training or validation
    if args.train:
        model = Model(args, charList=charlist, loss_beta=0.6,loss_weight=[.5,.5], decoderType=DecoderType.BeamSearch,experiment=experiment,mustRestore_seg=False,mustRestore_recg=False, joint=False)  # yike: pay notice here, add mustRestore if wanna continue with pretrained model !!!!!!!!!
        model.trainRecg(trainloader, validateloader, testloader)  # yike added validateloader !!!!!!!!!!
    elif args.validate:
        #model = Model(args, charlist, decoderType, mustRestore=True)
        model = Model(args, charList=charlist, loss_beta=0.6,loss_weight=[.5,.5], decoderType=DecoderType.BeamSearch,experiment=experiment,mustRestore_seg=False,mustRestore_recg=True, joint=False)
        model.validateRecg(testloader)

# infer text on test image
else:
    print(open(join(args.ckptpath_recg, 'accuracy.txt')).read())
    #model = Model(args, open(join(args.ckptpath, 'charList.txt')).read(), decoderType, mustRestore=True)
    model = Model(args, charList=open(join(args.ckptpath_recg, 'charList.txt')).read(), loss_beta=0.6,loss_weight=[.5,.5], decoderType=DecoderType.BeamSearch,experiment=experiment,mustRestore_seg=False,mustRestore_recg=True, joint=False)
    infer(model, FilePaths.fnInfer)
# Out:
# /root/datasets/iam_handwriting already exists, skipping download

# %% [markdown]
# # Train Segmentation

# %%
experiment.set_name('debug')
experiment.log_parameters(vars(args))

# %%
from datasets_seg import *

# %%
def checkArgs():
    if args.test:
        print('The model is set to Testing')
        print("Check point file: %s"%args.ckptpath_seg)
        #print("CamVid testing dir: %s"%FLAGS.test_dir)
    elif args.transfer:
        print('The model is set to transfer learn from ckpt')
        print("Check point file: %s"%args.ckptpath_seg)
        #print("CamVid Image dir: %s"%FLAGS.image_dir)
        #print("CamVid Val dir: %s"%FLAGS.val_dir)
    else:
        print('The model is set to Training')
        print("Max training Iteration: %d"%args.max_epoch)
        print("Initial lr: %f"%args.lrInit)
        print("First Drop Steps: %i"%args.lrDrop1)
        print("Second Drop Steps: %i"%args.lrDrop2)
        print("Data root: %s"%args.data_root)
        print("Check point file: %s"%args.ckptpath_seg)
        #print("CamVid Val dir: %s"%FLAGS.val_dir)

    print("Batch Size: %d"%args.batch_size_seg)

# %%
checkArgs()
if args.train:
    transform_train = transforms.Compose([
        transforms.Lambda(lambda img: cv2.resize(img, (args.image_w, args.image_h), interpolation=cv2.INTER_CUBIC)),
        transforms.Lambda(lambda img: np.expand_dims(img, 3)),
        # transforms.Lambda(lambda img: add_artifacts(img,args)),
        # transforms.Lambda(lambda img: cv2.transpose(img))
    ])
    # arprint=ArtPrint(args.data_root, transform=transform_train)
    arprint = ArtPrintNoIntsectBinary(args.data_root, transform=transform_train)
    concat = arprint
    idxTrain = int(len(arprint) * 0.9)
    trainset, testset = random_split(concat, [idxTrain, len(concat) - idxTrain])
    trainloader = DataLoader(trainset, batch_size=args.batch_size_seg, shuffle=True, drop_last=True, num_workers=4)
    testloader = DataLoader(testset, batch_size=args.batch_size_seg, shuffle=False, drop_last=False, num_workers=2)

    # weight gen
    ##pos_perc = sum(map(lambda x: np.sum(cv2.imread(x[1], cv2.IMREAD_GRAYSCALE)), trainset.dataset.samples)) / (
    ##            args.image_h * args.image_w * len(trainset.dataset.samples))
    ##neg_perc = 1 - pos_perc
    ##weight = np.array([pos_perc, neg_perc])  # just reverse
    weight=np.array([0.1,0.9])
    print(weight)
    #model = Model(args, experiment, loss_weight=weight, mustRestore=False)
    model = Model(args, charList=open(join(args.ckptpath_recg, 'charList.txt')).read(), loss_beta=0.5,loss_weight=weight, decoderType=DecoderType.BeamSearch,experiment=experiment,mustRestore_seg=False,mustRestore_recg=True,joint=True)
    model.trainSeg(loader=trainloader, validateloader=testloader)

else:
    pass  # for no
# Out:
# The model is set to Training
# Max training Iteration: 100
# Initial lr: 0.001000
# First Drop Steps: 10
# Second Drop Steps: 1000
# Data root: /root/datasets
# Check point file: /root/ckpt/debug_seg
# Batch Size: 10
# /root/datasets/artifact_images_no_intersect already exists, skipping download
# [0.1 0.9]
# GGG
# [None, 32, 128, 1]
# 0 conv1: (?, ?, ?, 32)
# 0 conv2: (?, ?, ?, 32)
# 1 conv1: (?, ?, ?, 64)
# 1 conv2: (?, ?, ?, 64)
# 2 conv1: (?, ?, ?, 128)
# 2 conv2: (?, ?, ?, 128)
# 1 h_deconv: (?, ?, ?, 64)
# 1 h_deconv_concat: (?, ?, ?, ?)
# 1 h_conv1_post_deconv: (?, ?, ?, 64)
# 1 h_conv2_post_deconv: (?, ?, ?, 64)
# 0 h_deconv: (?, ?, ?, 32)
# 0 h_deconv_concat: (?, ?, ?, ?)
# 0 h_conv1_post_deconv: (?, ?, ?, 32)
# 0 h_conv2_post_deconv: (?, ?, ?, 32)
# 0 outmap: (?, ?, ?, 2)
# (?, ?, ?, 2)
# loss_seg: ()
# clean output from seg: (?, 32, 128)
# recg input: (?, 128, 32)
# shape of cnn input: [None, 128, 32]
# Build Densenet4htr model with 5 blocks, 9 bottleneck layers and 9 composite layers each.
# Depth: 96
# Reduction at transition layers: 0.4
# densenet feature extractor graph built in (sec): 6.272006273269653
# Total training params: 1.0M
# shape of cnn output: [None, 32, 1, 178]
# Tensor("add:0", shape=(), dtype=float32)
# INFO:tensorflow:Summary name graph_segmentation/loss/cross_entropy (raw) is illegal; using graph_segmentation/loss/cross_entropy__raw_ instead.
# INFO:tensorflow:Summary name graph_segmentation/loss/cross_entropy (raw) is illegal; using graph_segmentation/loss/cross_entropy__raw_ instead.
# INFO:tensorflow:Summary name add (raw) is illegal; using add__raw_ instead.
# INFO:tensorflow:Summary name add (raw) is illegal; using add__raw_ instead.
# COMET ERROR: Failed to extract parameters from Estimator.init()
# toto_loss_shape: Tensor("add:0", shape=(), dtype=float32)
# COMET ERROR: Failed to extract parameters from Estimator.init()
# Python: 3.5.2 (default, Nov 12 2018, 13:43:14)
# [GCC 5.4.0 20160609]
# Tensorflow: 1.12.0-rc0
# Ran global_variables_initializer first
# Ran initializers.variables on segnet trainable variables
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1557: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# WARNING:tensorflow:From /usr/local/lib/python3.5/dist-packages/tensorflow/python/training/saver.py:1557: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from /root/ckpt/debug_recg/model-1
# INFO:tensorflow:Restoring parameters from /root/ckpt/debug_recg/model-1
# Init with stored values from /root/ckpt/debug_recg/model-1
# Epoch: 1  Training...
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# TRAIN: Batch: 0.0 Loss_Total: 69.04067
# TRAIN: Batch: 0.0 Loss_Seg: 119.83568
# accuracy = 0.790549
# mean IU  = 0.429998
#     class # 0 capture rate = 0.835037
#     class # 1 capture rate = 0.225753
# TRAIN: Batch: 0.003908998514580564 Loss_Total: 21.510185
# TRAIN: Batch: 0.003908998514580564 Loss_Seg: 27.185595
# accuracy = 0.861262
# mean IU  = 0.549289
#     class # 0 capture rate = 0.866055
#     class # 1 capture rate = 0.782237
# TRAIN: Batch: 0.007817997029161129 Loss_Total: 17.741007
# TRAIN: Batch: 0.007817997029161129 Loss_Seg: 22.68701
# accuracy = 0.901792
# mean IU  = 0.630465
#     class # 0 capture rate = 0.906639
#     class # 1 capture rate = 0.834958
# TRAIN: Batch: 0.011726995543741693 Loss_Total: 18.125402
# TRAIN: Batch: 0.011726995543741693 Loss_Seg: 22.558826
# accuracy = 0.859930
# mean IU  = 0.575830
#     class # 0 capture rate = 0.854794
#     class # 1 capture rate = 0.934470
# TRAIN: Batch: 0.015635994058322257 Loss_Total: 12.916971
# TRAIN: Batch: 0.015635994058322257 Loss_Seg: 13.756218
# accuracy = 0.929607
# mean IU  = 0.633690
#     class # 0 capture rate = 0.930230
#     class # 1 capture rate = 0.914567
# TRAIN: Batch: 0.019544992572902823 Loss_Total: 16.809547
# TRAIN: Batch: 0.019544992572902823 Loss_Seg: 13.622722
# accuracy = 0.929948
# mean IU  = 0.666396
#     class # 0 capture rate = 0.930740
#     class # 1 capture rate = 0.915618
# TRAIN: Batch: 0.023453991087483386 Loss_Total: 14.697517
# TRAIN: Batch: 0.023453991087483386 Loss_Seg: 14.835626
# accuracy = 0.935734
# mean IU  = 0.695401
#     class # 0 capture rate = 0.937942
#     class # 1 capture rate = 0.901414
# TRAIN: Batch: 0.02736298960206395 Loss_Total: 13.507683
# TRAIN: Batch: 0.02736298960206395 Loss_Seg: 13.844747
# accuracy = 0.924183
# mean IU  = 0.667831
#     class # 0 capture rate = 0.923218
#     class # 1 capture rate = 0.940026
# TRAIN: Batch: 0.031271988116644514 Loss_Total: 13.111177
# TRAIN: Batch: 0.031271988116644514 Loss_Seg: 15.270302
# accuracy = 0.943647
# mean IU  = 0.672515
#     class # 0 capture rate = 0.948273
#     class # 1 capture rate = 0.845696
# TRAIN: Batch: 0.035180986631225084 Loss_Total: 12.527312
# TRAIN: Batch: 0.035180986631225084 Loss_Seg: 14.036578
# accuracy = 0.912811
# mean IU  = 0.651500
#     class # 0 capture rate = 0.910413
#     class # 1 capture rate = 0.950366
# TRAIN: Batch: 0.039089985145805646 Loss_Total: 11.313669
# TRAIN: Batch: 0.039089985145805646 Loss_Seg: 11.249839
# accuracy = 0.956219
# mean IU  = 0.733175
#     class # 0 capture rate = 0.959240
#     class # 1 capture rate = 0.900096
# TRAIN: Batch: 0.04299898366038621 Loss_Total: 10.824783
# TRAIN: Batch: 0.04299898366038621 Loss_Seg: 10.823709
# accuracy = 0.959074
# mean IU  = 0.734023
#     class # 0 capture rate = 0.961589
#     class # 1 capture rate = 0.908147
# TRAIN: Batch: 0.04690798217496677 Loss_Total: 14.508962
# TRAIN: Batch: 0.04690798217496677 Loss_Seg: 15.587601
# accuracy = 0.932461
# mean IU  = 0.675451
#     class # 0 capture rate = 0.936487
#     class # 1 capture rate = 0.865780
# TRAIN: Batch: 0.05081698068954734 Loss_Total: 11.45956
# TRAIN: Batch: 0.05081698068954734 Loss_Seg: 12.039717
# accuracy = 0.945792
# mean IU  = 0.706735
#     class # 0 capture rate = 0.946521
#     class # 1 capture rate = 0.932388
# TRAIN: Batch: 0.0547259792041279 Loss_Total: 13.30666
# TRAIN: Batch: 0.0547259792041279 Loss_Seg: 13.41785
# accuracy = 0.929902
# mean IU  = 0.691892
#     class # 0 capture rate = 0.929003
#     class # 1 capture rate = 0.943301
# TRAIN: Batch: 0.058634977718708466 Loss_Total: 16.020103
# TRAIN: Batch: 0.058634977718708466 Loss_Seg: 19.058723
# accuracy = 0.916909
# mean IU  = 0.680628
#     class # 0 capture rate = 0.918902
#     class # 1 capture rate = 0.892766
# TRAIN: Batch: 0.06254397623328903 Loss_Total: 13.803257
# TRAIN: Batch: 0.06254397623328903 Loss_Seg: 13.990331
# accuracy = 0.938413
# mean IU  = 0.705543
#     class # 0 capture rate = 0.940157
#     class # 1 capture rate = 0.911765
# TRAIN: Batch: 0.0664529747478696 Loss_Total: 12.423037
# TRAIN: Batch: 0.0664529747478696 Loss_Seg: 12.762872
# accuracy = 0.942651
# mean IU  = 0.707645
#     class # 0 capture rate = 0.944513
#     class # 1 capture rate = 0.911891
# TRAIN: Batch: 0.07036197326245017 Loss_Total: 11.2107525
# TRAIN: Batch: 0.07036197326245017 Loss_Seg: 12.321178
# accuracy = 0.944131
# mean IU  = 0.689850
#     class # 0 capture rate = 0.944819
#     class # 1 capture rate = 0.930136
# TRAIN: Batch: 0.07427097177703072 Loss_Total: 10.802042
# TRAIN: Batch: 0.07427097177703072 Loss_Seg: 13.388422
# accuracy = 0.934178
# mean IU  = 0.676650
#     class # 0 capture rate = 0.935649
#     class # 1 capture rate = 0.907919
# TRAIN: Batch: 0.07817997029161129 Loss_Total: 10.555035
# TRAIN: Batch: 0.07817997029161129 Loss_Seg: 11.495695
# accuracy = 0.940866
# mean IU  = 0.686345
#     class # 0 capture rate = 0.941639
#     class # 1 capture rate = 0.925908
# TRAIN: Batch: 0.08208896880619185 Loss_Total: 15.520438
# TRAIN: Batch: 0.08208896880619185 Loss_Seg: 15.607566
# accuracy = 0.930256
# mean IU  = 0.706953
#     class # 0 capture rate = 0.930413
#     class # 1 capture rate = 0.928231
# TRAIN: Batch: 0.08599796732077242 Loss_Total: 13.5295105
# TRAIN: Batch: 0.08599796732077242 Loss_Seg: 15.622163
# accuracy = 0.937959
# mean IU  = 0.677649
#     class # 0 capture rate = 0.944211
#     class # 1 capture rate = 0.828983
# TRAIN: Batch: 0.08990696583535299 Loss_Total: 12.695314
# TRAIN: Batch: 0.08990696583535299 Loss_Seg: 12.244729
# accuracy = 0.941352
# mean IU  = 0.694987
#     class # 0 capture rate = 0.941588
#     class # 1 capture rate = 0.936997
# TRAIN: Batch: 0.09381596434993354 Loss_Total: 15.429348
# TRAIN: Batch: 0.09381596434993354 Loss_Seg: 15.805546
# accuracy = 0.940514
# mean IU  = 0.702790
#     class # 0 capture rate = 0.943914
#     class # 1 capture rate = 0.886411
# TRAIN: Batch: 0.09772496286451411 Loss_Total: 14.271118
# TRAIN: Batch: 0.09772496286451411 Loss_Seg: 15.002007
# accuracy = 0.932661
# mean IU  = 0.650315
#     class # 0 capture rate = 0.935444
#     class # 1 capture rate = 0.874126
# TRAIN: Batch: 0.10163396137909468 Loss_Total: 15.05077
# TRAIN: Batch: 0.10163396137909468 Loss_Seg: 11.665795
# accuracy = 0.941135
# mean IU  = 0.735888
#     class # 0 capture rate = 0.939888
#     class # 1 capture rate = 0.957528
# TRAIN: Batch: 0.10554295989367524 Loss_Total: 11.483133
# TRAIN: Batch: 0.10554295989367524 Loss_Seg: 13.958735
# accuracy = 0.938286
# mean IU  = 0.688212
#     class # 0 capture rate = 0.939877
#     class # 1 capture rate = 0.910169
# TRAIN: Batch: 0.1094519584082558 Loss_Total: 9.744625
# TRAIN: Batch: 0.1094519584082558 Loss_Seg: 12.471877
# accuracy = 0.935687
# mean IU  = 0.675934
#     class # 0 capture rate = 0.936560
#     class # 1 capture rate = 0.919285
# TRAIN: Batch: 0.11336095692283638 Loss_Total: 15.502916
# TRAIN: Batch: 0.11336095692283638 Loss_Seg: 18.856297
# accuracy = 0.915079
# mean IU  = 0.658835
#     class # 0 capture rate = 0.919029
#     class # 1 capture rate = 0.860891
# TRAIN: Batch: 0.11726995543741693 Loss_Total: 12.389325
# TRAIN: Batch: 0.11726995543741693 Loss_Seg: 11.545678
# accuracy = 0.948188
# mean IU  = 0.731378
#     class # 0 capture rate = 0.948301
#     class # 1 capture rate = 0.946384
# TRAIN: Batch: 0.1211789539519975 Loss_Total: 16.107105
# TRAIN: Batch: 0.1211789539519975 Loss_Seg: 15.915318
# accuracy = 0.915830
# mean IU  = 0.698229
#     class # 0 capture rate = 0.913047
#     class # 1 capture rate = 0.945868
# TRAIN: Batch: 0.12508795246657806 Loss_Total: 18.203133
# TRAIN: Batch: 0.12508795246657806 Loss_Seg: 17.977179
# accuracy = 0.942037
# mean IU  = 0.733439
#     class # 0 capture rate = 0.950036
#     class # 1 capture rate = 0.846032
# TRAIN: Batch: 0.12899695098115863 Loss_Total: 15.4699745
# TRAIN: Batch: 0.12899695098115863 Loss_Seg: 16.22386
# accuracy = 0.934292
# mean IU  = 0.683314
#     class # 0 capture rate = 0.937749
#     class # 1 capture rate = 0.877956
# TRAIN: Batch: 0.1329059494957392 Loss_Total: 15.863392
# TRAIN: Batch: 0.1329059494957392 Loss_Seg: 19.3914
# accuracy = 0.927438
# mean IU  = 0.646942
#     class # 0 capture rate = 0.935038
#     class # 1 capture rate = 0.793355
# TRAIN: Batch: 0.13681494801031976 Loss_Total: 12.344643
# TRAIN: Batch: 0.13681494801031976 Loss_Seg: 11.115068
# accuracy = 0.954358
# mean IU  = 0.732540
#     class # 0 capture rate = 0.955705
#     class # 1 capture rate = 0.929651
# TRAIN: Batch: 0.14072394652490033 Loss_Total: 12.37229
# TRAIN: Batch: 0.14072394652490033 Loss_Seg: 11.136979
# accuracy = 0.937790
# mean IU  = 0.698136
#     class # 0 capture rate = 0.936913
#     class # 1 capture rate = 0.952547
# TRAIN: Batch: 0.14463294503948088 Loss_Total: 14.03543
# TRAIN: Batch: 0.14463294503948088 Loss_Seg: 12.1186
# accuracy = 0.947939
# mean IU  = 0.705166
#     class # 0 capture rate = 0.950188
#     class # 1 capture rate = 0.905181
# TRAIN: Batch: 0.14854194355406145 Loss_Total: 17.54755
# TRAIN: Batch: 0.14854194355406145 Loss_Seg: 18.19168
# accuracy = 0.917833
# mean IU  = 0.665792
#     class # 0 capture rate = 0.923202
#     class # 1 capture rate = 0.846476
# TRAIN: Batch: 0.15245094206864201 Loss_Total: 17.145653
# TRAIN: Batch: 0.15245094206864201 Loss_Seg: 17.494654
# accuracy = 0.926140
# mean IU  = 0.704982
#     class # 0 capture rate = 0.929475
#     class # 1 capture rate = 0.887665
# TRAIN: Batch: 0.15635994058322258 Loss_Total: 12.789807
# TRAIN: Batch: 0.15635994058322258 Loss_Seg: 16.069374
# accuracy = 0.934038
# mean IU  = 0.714372
#     class # 0 capture rate = 0.935679
#     class # 1 capture rate = 0.912911
# TRAIN: Batch: 0.16026893909780315 Loss_Total: 15.265148
# TRAIN: Batch: 0.16026893909780315 Loss_Seg: 12.110039
# accuracy = 0.941840
# mean IU  = 0.739949
#     class # 0 capture rate = 0.941063
#     class # 1 capture rate = 0.951787
# TRAIN: Batch: 0.1641779376123837 Loss_Total: 12.631971
# TRAIN: Batch: 0.1641779376123837 Loss_Seg: 14.018041
# accuracy = 0.934263
# mean IU  = 0.708752
#     class # 0 capture rate = 0.934476
#     class # 1 capture rate = 0.931298
# TRAIN: Batch: 0.16808693612696426 Loss_Total: 15.261749
# TRAIN: Batch: 0.16808693612696426 Loss_Seg: 12.026118
# accuracy = 0.933973
# mean IU  = 0.681149
#     class # 0 capture rate = 0.933148
#     class # 1 capture rate = 0.948753
# TRAIN: Batch: 0.17199593464154483 Loss_Total: 14.322638
# TRAIN: Batch: 0.17199593464154483 Loss_Seg: 14.2443495
# accuracy = 0.934105
# mean IU  = 0.691967
#     class # 0 capture rate = 0.935534
#     class # 1 capture rate = 0.911717
# TRAIN: Batch: 0.1759049331561254 Loss_Total: 10.447521
# TRAIN: Batch: 0.1759049331561254 Loss_Seg: 11.346286
# accuracy = 0.940819
# mean IU  = 0.697353
#     class # 0 capture rate = 0.940763
#     class # 1 capture rate = 0.941828
# TRAIN: Batch: 0.17981393167070597 Loss_Total: 15.1854
# TRAIN: Batch: 0.17981393167070597 Loss_Seg: 16.733007
# accuracy = 0.935696
# mean IU  = 0.718127
#     class # 0 capture rate = 0.937551
#     class # 1 capture rate = 0.911775
# TRAIN: Batch: 0.18372293018528654 Loss_Total: 10.913844
# TRAIN: Batch: 0.18372293018528654 Loss_Seg: 11.4720745
# accuracy = 0.945987
# mean IU  = 0.719484
#     class # 0 capture rate = 0.947009
#     class # 1 capture rate = 0.929151
# TRAIN: Batch: 0.18763192869986708 Loss_Total: 13.570374
# TRAIN: Batch: 0.18763192869986708 Loss_Seg: 14.205524
# accuracy = 0.936102
# mean IU  = 0.662240
#     class # 0 capture rate = 0.939130
#     class # 1 capture rate = 0.874610
# TRAIN: Batch: 0.19154092721444765 Loss_Total: 15.16357
# TRAIN: Batch: 0.19154092721444765 Loss_Seg: 12.356281
# accuracy = 0.945428
# mean IU  = 0.726376
#     class # 0 capture rate = 0.946692
#     class # 1 capture rate = 0.926132
# TRAIN: Batch: 0.19544992572902822 Loss_Total: 10.33518
# TRAIN: Batch: 0.19544992572902822 Loss_Seg: 10.037127
# accuracy = 0.954270
# mean IU  = 0.755527
#     class # 0 capture rate = 0.954269
#     class # 1 capture rate = 0.954290
# TRAIN: Batch: 0.1993589242436088 Loss_Total: 11.756004
# TRAIN: Batch: 0.1993589242436088 Loss_Seg: 9.454655
# accuracy = 0.963129
# mean IU  = 0.775425
#     class # 0 capture rate = 0.964822
#     class # 1 capture rate = 0.934970
# TRAIN: Batch: 0.20326792275818936 Loss_Total: 11.374859
# TRAIN: Batch: 0.20326792275818936 Loss_Seg: 9.613844
# accuracy = 0.946261
# mean IU  = 0.687331
#     class # 0 capture rate = 0.946609
#     class # 1 capture rate = 0.938557
# TRAIN: Batch: 0.2071769212727699 Loss_Total: 11.859783
# TRAIN: Batch: 0.2071769212727699 Loss_Seg: 14.597792
# accuracy = 0.937936
# mean IU  = 0.705425
#     class # 0 capture rate = 0.940106
#     class # 1 capture rate = 0.905358
# TRAIN: Batch: 0.21108591978735047 Loss_Total: 12.445778
# TRAIN: Batch: 0.21108591978735047 Loss_Seg: 15.195233
# accuracy = 0.943694
# mean IU  = 0.703919
#     class # 0 capture rate = 0.948887
#     class # 1 capture rate = 0.858539
# TRAIN: Batch: 0.21499491830193104 Loss_Total: 12.212589
# TRAIN: Batch: 0.21499491830193104 Loss_Seg: 12.161196
# accuracy = 0.946843
# mean IU  = 0.715469
#     class # 0 capture rate = 0.948482
#     class # 1 capture rate = 0.918631
# TRAIN: Batch: 0.2189039168165116 Loss_Total: 16.874119
# TRAIN: Batch: 0.2189039168165116 Loss_Seg: 11.265894
# accuracy = 0.939813
# mean IU  = 0.722579
#     class # 0 capture rate = 0.939399
#     class # 1 capture rate = 0.945676
# TRAIN: Batch: 0.22281291533109218 Loss_Total: 12.581415
# TRAIN: Batch: 0.22281291533109218 Loss_Seg: 14.724387
# accuracy = 0.929536
# mean IU  = 0.687701
#     class # 0 capture rate = 0.929315
#     class # 1 capture rate = 0.932886
# TRAIN: Batch: 0.22672191384567275 Loss_Total: 12.394133
# TRAIN: Batch: 0.22672191384567275 Loss_Seg: 13.755363
# accuracy = 0.932389
# mean IU  = 0.701576
#     class # 0 capture rate = 0.931226
#     class # 1 capture rate = 0.949262
# TRAIN: Batch: 0.2306309123602533 Loss_Total: 13.00169
# TRAIN: Batch: 0.2306309123602533 Loss_Seg: 17.232265
# accuracy = 0.935049
# mean IU  = 0.685313
#     class # 0 capture rate = 0.941280
#     class # 1 capture rate = 0.838502
# TRAIN: Batch: 0.23453991087483386 Loss_Total: 10.964634
# TRAIN: Batch: 0.23453991087483386 Loss_Seg: 8.651698
# accuracy = 0.959907
# mean IU  = 0.763460
#     class # 0 capture rate = 0.959693
#     class # 1 capture rate = 0.963588
# TRAIN: Batch: 0.23844890938941443 Loss_Total: 13.102877
# TRAIN: Batch: 0.23844890938941443 Loss_Seg: 11.881603
# accuracy = 0.945040
# mean IU  = 0.712652
#     class # 0 capture rate = 0.946741
#     class # 1 capture rate = 0.916413
# TRAIN: Batch: 0.242357907903995 Loss_Total: 10.075125
# TRAIN: Batch: 0.242357907903995 Loss_Seg: 10.416106
# accuracy = 0.955341
# mean IU  = 0.752880
#     class # 0 capture rate = 0.956636
#     class # 1 capture rate = 0.934738
# TRAIN: Batch: 0.24626690641857557 Loss_Total: 10.122164
# TRAIN: Batch: 0.24626690641857557 Loss_Seg: 14.090876
# accuracy = 0.929386
# mean IU  = 0.703617
#     class # 0 capture rate = 0.928943
#     class # 1 capture rate = 0.935227
# TRAIN: Batch: 0.2501759049331561 Loss_Total: 10.772703
# TRAIN: Batch: 0.2501759049331561 Loss_Seg: 10.477332
# accuracy = 0.956907
# mean IU  = 0.754991
#     class # 0 capture rate = 0.958560
#     class # 1 capture rate = 0.930017
# TRAIN: Batch: 0.2540849034477367 Loss_Total: 15.217247
# TRAIN: Batch: 0.2540849034477367 Loss_Seg: 17.614422
# accuracy = 0.946302
# mean IU  = 0.731480
#     class # 0 capture rate = 0.952768
#     class # 1 capture rate = 0.857451
# TRAIN: Batch: 0.25799390196231725 Loss_Total: 11.486933
# TRAIN: Batch: 0.25799390196231725 Loss_Seg: 11.297552
# accuracy = 0.936639
# mean IU  = 0.684139
#     class # 0 capture rate = 0.935649
#     class # 1 capture rate = 0.955045
# TRAIN: Batch: 0.2619029004768978 Loss_Total: 13.554228
# TRAIN: Batch: 0.2619029004768978 Loss_Seg: 16.744831
# accuracy = 0.926660
# mean IU  = 0.706130
#     class # 0 capture rate = 0.928342
#     class # 1 capture rate = 0.906788
# TRAIN: Batch: 0.2658118989914784 Loss_Total: 12.323319
# TRAIN: Batch: 0.2658118989914784 Loss_Seg: 13.632186
# accuracy = 0.944636
# mean IU  = 0.719932
#     class # 0 capture rate = 0.947509
#     class # 1 capture rate = 0.900480
# TRAIN: Batch: 0.26972089750605893 Loss_Total: 12.99631
# TRAIN: Batch: 0.26972089750605893 Loss_Seg: 12.194377
# accuracy = 0.949242
# mean IU  = 0.732141
#     class # 0 capture rate = 0.951301
#     class # 1 capture rate = 0.916701
# TRAIN: Batch: 0.27362989602063953 Loss_Total: 12.725039
# TRAIN: Batch: 0.27362989602063953 Loss_Seg: 15.218625
# accuracy = 0.936620
# mean IU  = 0.708105
#     class # 0 capture rate = 0.937756
#     class # 1 capture rate = 0.920136
# TRAIN: Batch: 0.27753889453522007 Loss_Total: 12.818572
# TRAIN: Batch: 0.27753889453522007 Loss_Seg: 14.094648
# accuracy = 0.933874
# mean IU  = 0.667862
#     class # 0 capture rate = 0.935398
#     class # 1 capture rate = 0.904762
# TRAIN: Batch: 0.28144789304980067 Loss_Total: 12.009129
# TRAIN: Batch: 0.28144789304980067 Loss_Seg: 13.26889
# accuracy = 0.935855
# mean IU  = 0.706920
#     class # 0 capture rate = 0.935792
#     class # 1 capture rate = 0.936782
# TRAIN: Batch: 0.2853568915643812 Loss_Total: 11.871309
# TRAIN: Batch: 0.2853568915643812 Loss_Seg: 12.306395
# accuracy = 0.939519
# mean IU  = 0.710817
#     class # 0 capture rate = 0.939894
#     class # 1 capture rate = 0.933759
# TRAIN: Batch: 0.28926589007896175 Loss_Total: 14.657756
# TRAIN: Batch: 0.28926589007896175 Loss_Seg: 16.152006
# accuracy = 0.928060
# mean IU  = 0.681733
#     class # 0 capture rate = 0.930984
#     class # 1 capture rate = 0.885145
# TRAIN: Batch: 0.29317488859354235 Loss_Total: 12.882719
# TRAIN: Batch: 0.29317488859354235 Loss_Seg: 15.386385
# accuracy = 0.937289
# mean IU  = 0.700756
#     class # 0 capture rate = 0.939995
#     class # 1 capture rate = 0.896032
# TRAIN: Batch: 0.2970838871081229 Loss_Total: 10.805511
# TRAIN: Batch: 0.2970838871081229 Loss_Seg: 12.468171
# accuracy = 0.946091
# mean IU  = 0.716433
#     class # 0 capture rate = 0.947615
#     class # 1 capture rate = 0.920504
# TRAIN: Batch: 0.3009928856227035 Loss_Total: 13.404684
# TRAIN: Batch: 0.3009928856227035 Loss_Seg: 14.055597
# accuracy = 0.931420
# mean IU  = 0.692918
#     class # 0 capture rate = 0.932680
#     class # 1 capture rate = 0.912893
# TRAIN: Batch: 0.30490188413728403 Loss_Total: 12.158969
# TRAIN: Batch: 0.30490188413728403 Loss_Seg: 14.425596
# accuracy = 0.926165
# mean IU  = 0.709331
#     class # 0 capture rate = 0.925049
#     class # 1 capture rate = 0.939337
# TRAIN: Batch: 0.30881088265186457 Loss_Total: 12.592354
# TRAIN: Batch: 0.30881088265186457 Loss_Seg: 11.44251
# accuracy = 0.944959
# mean IU  = 0.711797
#     class # 0 capture rate = 0.946425
#     class # 1 capture rate = 0.920035
# TRAIN: Batch: 0.31271988116644517 Loss_Total: 14.826992
# TRAIN: Batch: 0.31271988116644517 Loss_Seg: 15.042008
# accuracy = 0.929290
# mean IU  = 0.690441
#     class # 0 capture rate = 0.930437
#     class # 1 capture rate = 0.912782
# TRAIN: Batch: 0.3166288796810257 Loss_Total: 12.75359
# TRAIN: Batch: 0.3166288796810257 Loss_Seg: 12.122032
# accuracy = 0.930614
# mean IU  = 0.696066
#     class # 0 capture rate = 0.929475
#     class # 1 capture rate = 0.947288
# TRAIN: Batch: 0.3205378781956063 Loss_Total: 12.810575
# TRAIN: Batch: 0.3205378781956063 Loss_Seg: 10.7941475
# accuracy = 0.950680
# mean IU  = 0.740183
#     class # 0 capture rate = 0.951484
#     class # 1 capture rate = 0.938060
# TRAIN: Batch: 0.32444687671018685 Loss_Total: 12.706646
# TRAIN: Batch: 0.32444687671018685 Loss_Seg: 10.463043
# accuracy = 0.950357
# mean IU  = 0.735136
#     class # 0 capture rate = 0.950718
#     class # 1 capture rate = 0.944444
# TRAIN: Batch: 0.3283558752247674 Loss_Total: 11.016581
# TRAIN: Batch: 0.3283558752247674 Loss_Seg: 12.25953
# accuracy = 0.939542
# mean IU  = 0.703354
#     class # 0 capture rate = 0.939405
#     class # 1 capture rate = 0.941806
# TRAIN: Batch: 0.332264873739348 Loss_Total: 11.694708
# TRAIN: Batch: 0.332264873739348 Loss_Seg: 11.323074
# accuracy = 0.952147
# mean IU  = 0.742122
#     class # 0 capture rate = 0.952881
#     class # 1 capture rate = 0.940342
# TRAIN: Batch: 0.33617387225392853 Loss_Total: 8.663042
# TRAIN: Batch: 0.33617387225392853 Loss_Seg: 9.116441
# accuracy = 0.950922
# mean IU  = 0.706584
#     class # 0 capture rate = 0.950461
#     class # 1 capture rate = 0.960860
# TRAIN: Batch: 0.3400828707685091 Loss_Total: 10.565762
# TRAIN: Batch: 0.3400828707685091 Loss_Seg: 11.563172
# accuracy = 0.938342
# mean IU  = 0.708215
#     class # 0 capture rate = 0.938165
#     class # 1 capture rate = 0.941082
# TRAIN: Batch: 0.34399186928308967 Loss_Total: 13.151674
# TRAIN: Batch: 0.34399186928308967 Loss_Seg: 11.2811365
# accuracy = 0.938646
# mean IU  = 0.717513
#     class # 0 capture rate = 0.937555
#     class # 1 capture rate = 0.954494
# TRAIN: Batch: 0.3479008677976702 Loss_Total: 13.504065
# TRAIN: Batch: 0.3479008677976702 Loss_Seg: 12.191048
# accuracy = 0.934457
# mean IU  = 0.706224
#     class # 0 capture rate = 0.933497
#     class # 1 capture rate = 0.948407
# TRAIN: Batch: 0.3518098663122508 Loss_Total: 12.545227
# TRAIN: Batch: 0.3518098663122508 Loss_Seg: 13.617873
# accuracy = 0.935222
# mean IU  = 0.713739
#     class # 0 capture rate = 0.935728
#     class # 1 capture rate = 0.928369
# TRAIN: Batch: 0.35571886482683135 Loss_Total: 12.454511
# TRAIN: Batch: 0.35571886482683135 Loss_Seg: 12.532657
# accuracy = 0.940697
# mean IU  = 0.711711
#     class # 0 capture rate = 0.941016
#     class # 1 capture rate = 0.935694
# TRAIN: Batch: 0.35962786334141195 Loss_Total: 12.732819
# TRAIN: Batch: 0.35962786334141195 Loss_Seg: 10.631586
# accuracy = 0.938060
# mean IU  = 0.701750
#     class # 0 capture rate = 0.936386
#     class # 1 capture rate = 0.965948
# TRAIN: Batch: 0.3635368618559925 Loss_Total: 15.759346
# TRAIN: Batch: 0.3635368618559925 Loss_Seg: 15.588062
# accuracy = 0.939206
# mean IU  = 0.736009
#     class # 0 capture rate = 0.941611
#     class # 1 capture rate = 0.910607
# TRAIN: Batch: 0.3674458603705731 Loss_Total: 18.704477
# TRAIN: Batch: 0.3674458603705731 Loss_Seg: 20.272806
# accuracy = 0.931266
# mean IU  = 0.706490
#     class # 0 capture rate = 0.938067
#     class # 1 capture rate = 0.849363
# TRAIN: Batch: 0.3713548588851536 Loss_Total: 15.160987
# TRAIN: Batch: 0.3713548588851536 Loss_Seg: 16.362041
# accuracy = 0.933503
# mean IU  = 0.708437
#     class # 0 capture rate = 0.936550
#     class # 1 capture rate = 0.893558
# TRAIN: Batch: 0.37526385739973417 Loss_Total: 13.382025
# TRAIN: Batch: 0.37526385739973417 Loss_Seg: 14.459449
# accuracy = 0.938739
# mean IU  = 0.714446
#     class # 0 capture rate = 0.940631
#     class # 1 capture rate = 0.911798
# TRAIN: Batch: 0.37917285591431477 Loss_Total: 14.092209
# TRAIN: Batch: 0.37917285591431477 Loss_Seg: 11.532337
# accuracy = 0.942768
# mean IU  = 0.705229
#     class # 0 capture rate = 0.942486
#     class # 1 capture rate = 0.947727
# TRAIN: Batch: 0.3830818544288953 Loss_Total: 11.411718
# TRAIN: Batch: 0.3830818544288953 Loss_Seg: 13.294485
# accuracy = 0.927759
# mean IU  = 0.669080
#     class # 0 capture rate = 0.926610
#     class # 1 capture rate = 0.947917
# TRAIN: Batch: 0.3869908529434759 Loss_Total: 10.511551
# TRAIN: Batch: 0.3869908529434759 Loss_Seg: 10.24119
# accuracy = 0.955497
# mean IU  = 0.750036
#     class # 0 capture rate = 0.955831
#     class # 1 capture rate = 0.949935
# TRAIN: Batch: 0.39089985145805645 Loss_Total: 11.444076
# TRAIN: Batch: 0.39089985145805645 Loss_Seg: 11.404271
# accuracy = 0.947424
# mean IU  = 0.747025
#     class # 0 capture rate = 0.947246
#     class # 1 capture rate = 0.949874
# TRAIN: Batch: 0.394808849972637 Loss_Total: 12.366951
# TRAIN: Batch: 0.394808849972637 Loss_Seg: 11.617069
# accuracy = 0.948853
# mean IU  = 0.697009
#     class # 0 capture rate = 0.950954
#     class # 1 capture rate = 0.905016
# TRAIN: Batch: 0.3987178484872176 Loss_Total: 10.881131
# TRAIN: Batch: 0.3987178484872176 Loss_Seg: 12.025453
# accuracy = 0.943351
# mean IU  = 0.694122
#     class # 0 capture rate = 0.945149
#     class # 1 capture rate = 0.909531
# TRAIN: Batch: 0.4026268470017981 Loss_Total: 14.679033
# TRAIN: Batch: 0.4026268470017981 Loss_Seg: 11.915159
# accuracy = 0.937175
# mean IU  = 0.689242
#     class # 0 capture rate = 0.936158
#     class # 1 capture rate = 0.955473
# TRAIN: Batch: 0.4065358455163787 Loss_Total: 12.227331
# TRAIN: Batch: 0.4065358455163787 Loss_Seg: 13.305021
# accuracy = 0.931515
# mean IU  = 0.686858
#     class # 0 capture rate = 0.932189
#     class # 1 capture rate = 0.920945
# TRAIN: Batch: 0.41044484403095927 Loss_Total: 12.572439
# TRAIN: Batch: 0.41044484403095927 Loss_Seg: 13.014957
# accuracy = 0.938831
# mean IU  = 0.717717
#     class # 0 capture rate = 0.939798
#     class # 1 capture rate = 0.925203
# TRAIN: Batch: 0.4143538425455398 Loss_Total: 16.457714
# TRAIN: Batch: 0.4143538425455398 Loss_Seg: 11.860002
# accuracy = 0.929391
# mean IU  = 0.676116
#     class # 0 capture rate = 0.928008
#     class # 1 capture rate = 0.953077
# TRAIN: Batch: 0.4182628410601204 Loss_Total: 9.9854145
# TRAIN: Batch: 0.4182628410601204 Loss_Seg: 10.33545
# accuracy = 0.946987
# mean IU  = 0.722066
#     class # 0 capture rate = 0.946678
#     class # 1 capture rate = 0.952214
# TRAIN: Batch: 0.42217183957470095 Loss_Total: 11.905102
# TRAIN: Batch: 0.42217183957470095 Loss_Seg: 12.36867
# accuracy = 0.940517
# mean IU  = 0.719283
#     class # 0 capture rate = 0.940242
#     class # 1 capture rate = 0.944573
# TRAIN: Batch: 0.42608083808928154 Loss_Total: 13.959835
# TRAIN: Batch: 0.42608083808928154 Loss_Seg: 13.395734
# accuracy = 0.935341
# mean IU  = 0.696881
#     class # 0 capture rate = 0.936572
#     class # 1 capture rate = 0.916264
# TRAIN: Batch: 0.4299898366038621 Loss_Total: 11.169878
# TRAIN: Batch: 0.4299898366038621 Loss_Seg: 12.409081
# accuracy = 0.939937
# mean IU  = 0.705814
#     class # 0 capture rate = 0.941931
#     class # 1 capture rate = 0.908609
# TRAIN: Batch: 0.4338988351184426 Loss_Total: 12.755939
# TRAIN: Batch: 0.4338988351184426 Loss_Seg: 9.208458
# accuracy = 0.944530
# mean IU  = 0.697197
#     class # 0 capture rate = 0.944159
#     class # 1 capture rate = 0.951850
# TRAIN: Batch: 0.4378078336330232 Loss_Total: 8.581817
# TRAIN: Batch: 0.4378078336330232 Loss_Seg: 11.114575
# accuracy = 0.949683
# mean IU  = 0.743543
#     class # 0 capture rate = 0.949893
#     class # 1 capture rate = 0.946526
# TRAIN: Batch: 0.44171683214760377 Loss_Total: 14.113697
# TRAIN: Batch: 0.44171683214760377 Loss_Seg: 14.384409
# accuracy = 0.934632
# mean IU  = 0.695688
#     class # 0 capture rate = 0.935242
#     class # 1 capture rate = 0.925132
# TRAIN: Batch: 0.44562583066218436 Loss_Total: 13.892193
# TRAIN: Batch: 0.44562583066218436 Loss_Seg: 18.299128
# accuracy = 0.949676
# mean IU  = 0.738689
#     class # 0 capture rate = 0.957623
#     class # 1 capture rate = 0.840303
# TRAIN: Batch: 0.4495348291767649 Loss_Total: 14.425501
# TRAIN: Batch: 0.4495348291767649 Loss_Seg: 12.104461
# accuracy = 0.955077
# mean IU  = 0.769497
#     class # 0 capture rate = 0.958110
#     class # 1 capture rate = 0.914655
# TRAIN: Batch: 0.4534438276913455 Loss_Total: 13.317753
# TRAIN: Batch: 0.4534438276913455 Loss_Seg: 14.397361
# accuracy = 0.920457
# mean IU  = 0.681064
#     class # 0 capture rate = 0.920585
#     class # 1 capture rate = 0.918759
# TRAIN: Batch: 0.45735282620592604 Loss_Total: 12.837008
# TRAIN: Batch: 0.45735282620592604 Loss_Seg: 10.229025
# accuracy = 0.954341
# mean IU  = 0.710062
#     class # 0 capture rate = 0.957230
#     class # 1 capture rate = 0.892935
# TRAIN: Batch: 0.4612618247205066 Loss_Total: 10.801678
# TRAIN: Batch: 0.4612618247205066 Loss_Seg: 12.135422
# accuracy = 0.946871
# mean IU  = 0.730324
#     class # 0 capture rate = 0.948332
#     class # 1 capture rate = 0.924573
# TRAIN: Batch: 0.4651708232350872 Loss_Total: 16.922184
# TRAIN: Batch: 0.4651708232350872 Loss_Seg: 18.201626
# accuracy = 0.924313
# mean IU  = 0.711042
#     class # 0 capture rate = 0.926830
#     class # 1 capture rate = 0.897465
# TRAIN: Batch: 0.4690798217496677 Loss_Total: 12.169823
# TRAIN: Batch: 0.4690798217496677 Loss_Seg: 13.89732
# accuracy = 0.928069
# mean IU  = 0.689459
#     class # 0 capture rate = 0.928142
#     class # 1 capture rate = 0.927013
# TRAIN: Batch: 0.4729888202642483 Loss_Total: 13.641189
# TRAIN: Batch: 0.4729888202642483 Loss_Seg: 9.799225
# accuracy = 0.940738
# mean IU  = 0.700183
#     class # 0 capture rate = 0.939266
#     class # 1 capture rate = 0.967160
# TRAIN: Batch: 0.47689781877882886 Loss_Total: 11.841552
# TRAIN: Batch: 0.47689781877882886 Loss_Seg: 10.324585
# accuracy = 0.942958
# mean IU  = 0.716223
#     class # 0 capture rate = 0.941850
#     class # 1 capture rate = 0.961050
# TRAIN: Batch: 0.4808068172934094 Loss_Total: 14.459801
# TRAIN: Batch: 0.4808068172934094 Loss_Seg: 13.797837
# accuracy = 0.947066
# mean IU  = 0.721769
#     class # 0 capture rate = 0.949918
#     class # 1 capture rate = 0.901250
# TRAIN: Batch: 0.48471581580799 Loss_Total: 12.884867
# TRAIN: Batch: 0.48471581580799 Loss_Seg: 11.81079
# accuracy = 0.943235
# mean IU  = 0.735198
#     class # 0 capture rate = 0.943026
#     class # 1 capture rate = 0.946101
# TRAIN: Batch: 0.48862481432257054 Loss_Total: 11.260712
# TRAIN: Batch: 0.48862481432257054 Loss_Seg: 9.739828
# accuracy = 0.950577
# mean IU  = 0.727437
#     class # 0 capture rate = 0.949985
#     class # 1 capture rate = 0.961201
# TRAIN: Batch: 0.49253381283715114 Loss_Total: 13.4127865
# TRAIN: Batch: 0.49253381283715114 Loss_Seg: 11.322225
# accuracy = 0.949927
# mean IU  = 0.739374
#     class # 0 capture rate = 0.952206
#     class # 1 capture rate = 0.915521
# TRAIN: Batch: 0.4964428113517317 Loss_Total: 15.475048
# TRAIN: Batch: 0.4964428113517317 Loss_Seg: 15.631351
# accuracy = 0.931144
# mean IU  = 0.709908
#     class # 0 capture rate = 0.932069
#     class # 1 capture rate = 0.919398
# TRAIN: Batch: 0.5003518098663122 Loss_Total: 24.864956
# TRAIN: Batch: 0.5003518098663122 Loss_Seg: 33.175728
# accuracy = 0.899311
# mean IU  = 0.672219
#     class # 0 capture rate = 0.912549
#     class # 1 capture rate = 0.788108
# TRAIN: Batch: 0.5042608083808928 Loss_Total: 14.5437
# TRAIN: Batch: 0.5042608083808928 Loss_Seg: 12.341215
# accuracy = 0.941520
# mean IU  = 0.687804
#     class # 0 capture rate = 0.943252
#     class # 1 capture rate = 0.908557
# TRAIN: Batch: 0.5081698068954734 Loss_Total: 14.270704
# TRAIN: Batch: 0.5081698068954734 Loss_Seg: 10.402609
# accuracy = 0.951969
# mean IU  = 0.735191
#     class # 0 capture rate = 0.952191
#     class # 1 capture rate = 0.948161
# TRAIN: Batch: 0.5120788054100539 Loss_Total: 15.745489
# TRAIN: Batch: 0.5120788054100539 Loss_Seg: 12.87095
# accuracy = 0.942475
# mean IU  = 0.702897
#     class # 0 capture rate = 0.943627
#     class # 1 capture rate = 0.922491
# TRAIN: Batch: 0.5159878039246345 Loss_Total: 11.540047
# TRAIN: Batch: 0.5159878039246345 Loss_Seg: 13.379556
# accuracy = 0.953416
# mean IU  = 0.753199
#     class # 0 capture rate = 0.957382
#     class # 1 capture rate = 0.896396
# TRAIN: Batch: 0.5198968024392151 Loss_Total: 16.231522
# TRAIN: Batch: 0.5198968024392151 Loss_Seg: 9.943118
# accuracy = 0.954098
# mean IU  = 0.777916
#     class # 0 capture rate = 0.953479
#     class # 1 capture rate = 0.961949
# TRAIN: Batch: 0.5238058009537956 Loss_Total: 9.510815
# TRAIN: Batch: 0.5238058009537956 Loss_Seg: 8.648032
# accuracy = 0.952902
# mean IU  = 0.733174
#     class # 0 capture rate = 0.952347
#     class # 1 capture rate = 0.962998
# TRAIN: Batch: 0.5277147994683762 Loss_Total: 14.690704
# TRAIN: Batch: 0.5277147994683762 Loss_Seg: 17.738544
# accuracy = 0.949582
# mean IU  = 0.709803
#     class # 0 capture rate = 0.958200
#     class # 1 capture rate = 0.804613
# TRAIN: Batch: 0.5316237979829568 Loss_Total: 10.672964
# TRAIN: Batch: 0.5316237979829568 Loss_Seg: 9.560925
# accuracy = 0.955343
# mean IU  = 0.733605
#     class # 0 capture rate = 0.955750
#     class # 1 capture rate = 0.947600
# TRAIN: Batch: 0.5355327964975374 Loss_Total: 17.072668
# TRAIN: Batch: 0.5355327964975374 Loss_Seg: 18.51734
# accuracy = 0.917177
# mean IU  = 0.710518
#     class # 0 capture rate = 0.916337
#     class # 1 capture rate = 0.925299
# TRAIN: Batch: 0.5394417950121179 Loss_Total: 12.585939
# TRAIN: Batch: 0.5394417950121179 Loss_Seg: 11.949284
# accuracy = 0.940955
# mean IU  = 0.701169
#     class # 0 capture rate = 0.942473
#     class # 1 capture rate = 0.915358
# TRAIN: Batch: 0.5433507935266985 Loss_Total: 12.096472
# TRAIN: Batch: 0.5433507935266985 Loss_Seg: 11.010353
# accuracy = 0.943917
# mean IU  = 0.697846
#     class # 0 capture rate = 0.944215
#     class # 1 capture rate = 0.938235
# TRAIN: Batch: 0.5472597920412791 Loss_Total: 13.016415
# TRAIN: Batch: 0.5472597920412791 Loss_Seg: 11.663358
# accuracy = 0.940276
# mean IU  = 0.745011
#     class # 0 capture rate = 0.938946
#     class # 1 capture rate = 0.956044
# TRAIN: Batch: 0.5511687905558595 Loss_Total: 8.943476
# TRAIN: Batch: 0.5511687905558595 Loss_Seg: 9.566131
# accuracy = 0.957687
# mean IU  = 0.752452
#     class # 0 capture rate = 0.959758
#     class # 1 capture rate = 0.922741
# TRAIN: Batch: 0.5550777890704401 Loss_Total: 10.644749
# TRAIN: Batch: 0.5550777890704401 Loss_Seg: 12.336838
# accuracy = 0.939278
# mean IU  = 0.681026
#     class # 0 capture rate = 0.942707
#     class # 1 capture rate = 0.875951
# TRAIN: Batch: 0.5589867875850207 Loss_Total: 10.937361
# TRAIN: Batch: 0.5589867875850207 Loss_Seg: 11.907263
# accuracy = 0.935830
# mean IU  = 0.704684
#     class # 0 capture rate = 0.935034
#     class # 1 capture rate = 0.947908
# TRAIN: Batch: 0.5628957860996013 Loss_Total: 13.759079
# TRAIN: Batch: 0.5628957860996013 Loss_Seg: 18.43071
# accuracy = 0.926852
# mean IU  = 0.681861
#     class # 0 capture rate = 0.933297
#     class # 1 capture rate = 0.839659
# TRAIN: Batch: 0.5668047846141818 Loss_Total: 10.541897
# TRAIN: Batch: 0.5668047846141818 Loss_Seg: 8.952852
# accuracy = 0.954822
# mean IU  = 0.731135
#     class # 0 capture rate = 0.954700
#     class # 1 capture rate = 0.957193
# TRAIN: Batch: 0.5707137831287624 Loss_Total: 13.826235
# TRAIN: Batch: 0.5707137831287624 Loss_Seg: 11.935426
# accuracy = 0.949039
# mean IU  = 0.706520
#     class # 0 capture rate = 0.952432
#     class # 1 capture rate = 0.885007
# TRAIN: Batch: 0.574622781643343 Loss_Total: 12.353267
# TRAIN: Batch: 0.574622781643343 Loss_Seg: 11.525543
# accuracy = 0.939447
# mean IU  = 0.692537
#     class # 0 capture rate = 0.939856
#     class # 1 capture rate = 0.932133
# TRAIN: Batch: 0.5785317801579235 Loss_Total: 11.119186
# TRAIN: Batch: 0.5785317801579235 Loss_Seg: 9.585261
# accuracy = 0.944842
# mean IU  = 0.700848
#     class # 0 capture rate = 0.943893
#     class # 1 capture rate = 0.963390
# TRAIN: Batch: 0.5824407786725041 Loss_Total: 10.931178
# TRAIN: Batch: 0.5824407786725041 Loss_Seg: 10.924797
# accuracy = 0.945281
# mean IU  = 0.720671
#     class # 0 capture rate = 0.945519
#     class # 1 capture rate = 0.941424
# TRAIN: Batch: 0.5863497771870847 Loss_Total: 10.619135
# TRAIN: Batch: 0.5863497771870847 Loss_Seg: 9.252837
# accuracy = 0.957785
# mean IU  = 0.741646
#     class # 0 capture rate = 0.958299
#     class # 1 capture rate = 0.947963
# TRAIN: Batch: 0.5902587757016652 Loss_Total: 9.350042
# TRAIN: Batch: 0.5902587757016652 Loss_Seg: 9.694891
# accuracy = 0.961081
# mean IU  = 0.746389
#     class # 0 capture rate = 0.963503
#     class # 1 capture rate = 0.913784
# TRAIN: Batch: 0.5941677742162458 Loss_Total: 14.107313
# TRAIN: Batch: 0.5941677742162458 Loss_Seg: 12.020708
# accuracy = 0.946230
# mean IU  = 0.733471
#     class # 0 capture rate = 0.946777
#     class # 1 capture rate = 0.938104
# TRAIN: Batch: 0.5980767727308264 Loss_Total: 14.892303
# TRAIN: Batch: 0.5980767727308264 Loss_Seg: 11.758718
# accuracy = 0.950411
# mean IU  = 0.750442
#     class # 0 capture rate = 0.950548
#     class # 1 capture rate = 0.948438
# TRAIN: Batch: 0.601985771245407 Loss_Total: 17.136833
# TRAIN: Batch: 0.601985771245407 Loss_Seg: 17.292503
# accuracy = 0.925083
# mean IU  = 0.723502
#     class # 0 capture rate = 0.924690
#     class # 1 capture rate = 0.929034
# TRAIN: Batch: 0.6058947697599875 Loss_Total: 10.953746
# TRAIN: Batch: 0.6058947697599875 Loss_Seg: 10.9644375
# accuracy = 0.944599
# mean IU  = 0.736566
#     class # 0 capture rate = 0.944564
#     class # 1 capture rate = 0.945095
# TRAIN: Batch: 0.6098037682745681 Loss_Total: 12.826627
# TRAIN: Batch: 0.6098037682745681 Loss_Seg: 11.593599
# accuracy = 0.939595
# mean IU  = 0.698015
#     class # 0 capture rate = 0.939005
#     class # 1 capture rate = 0.949910
# TRAIN: Batch: 0.6137127667891487 Loss_Total: 14.125088
# TRAIN: Batch: 0.6137127667891487 Loss_Seg: 13.144583
# accuracy = 0.935759
# mean IU  = 0.726873
#     class # 0 capture rate = 0.935810
#     class # 1 capture rate = 0.935128
# TRAIN: Batch: 0.6176217653037291 Loss_Total: 12.527454
# TRAIN: Batch: 0.6176217653037291 Loss_Seg: 12.360057
# accuracy = 0.947233
# mean IU  = 0.730903
#     class # 0 capture rate = 0.948928
#     class # 1 capture rate = 0.921366
# TRAIN: Batch: 0.6215307638183097 Loss_Total: 13.83666
# TRAIN: Batch: 0.6215307638183097 Loss_Seg: 16.425257
# accuracy = 0.921732
# mean IU  = 0.694426
#     class # 0 capture rate = 0.923947
#     class # 1 capture rate = 0.895704
# TRAIN: Batch: 0.6254397623328903 Loss_Total: 11.37775
# TRAIN: Batch: 0.6254397623328903 Loss_Seg: 10.082426
# accuracy = 0.951958
# mean IU  = 0.731733
#     class # 0 capture rate = 0.952252
#     class # 1 capture rate = 0.946770
# TRAIN: Batch: 0.6293487608474708 Loss_Total: 12.664211
# TRAIN: Batch: 0.6293487608474708 Loss_Seg: 11.931642
# accuracy = 0.946116
# mean IU  = 0.722303
#     class # 0 capture rate = 0.948240
#     class # 1 capture rate = 0.912490
# TRAIN: Batch: 0.6332577593620514 Loss_Total: 9.803886
# TRAIN: Batch: 0.6332577593620514 Loss_Seg: 10.067029
# accuracy = 0.957079
# mean IU  = 0.736022
#     class # 0 capture rate = 0.958889
#     class # 1 capture rate = 0.922549
# TRAIN: Batch: 0.637166757876632 Loss_Total: 17.913347
# TRAIN: Batch: 0.637166757876632 Loss_Seg: 25.821571
# accuracy = 0.907119
# mean IU  = 0.707729
#     class # 0 capture rate = 0.909601
#     class # 1 capture rate = 0.887589
# TRAIN: Batch: 0.6410757563912126 Loss_Total: 10.288013
# TRAIN: Batch: 0.6410757563912126 Loss_Seg: 12.632171
# accuracy = 0.951947
# mean IU  = 0.733899
#     class # 0 capture rate = 0.954412
#     class # 1 capture rate = 0.911006
# TRAIN: Batch: 0.6449847549057931 Loss_Total: 10.8030815
# TRAIN: Batch: 0.6449847549057931 Loss_Seg: 10.891035
# accuracy = 0.952929
# mean IU  = 0.741209
#     class # 0 capture rate = 0.955144
#     class # 1 capture rate = 0.917189
# TRAIN: Batch: 0.6488937534203737 Loss_Total: 13.431438
# TRAIN: Batch: 0.6488937534203737 Loss_Seg: 15.116794
# accuracy = 0.940129
# mean IU  = 0.737026
#     class # 0 capture rate = 0.942465
#     class # 1 capture rate = 0.911962
# TRAIN: Batch: 0.6528027519349543 Loss_Total: 13.175999
# TRAIN: Batch: 0.6528027519349543 Loss_Seg: 11.350618
# accuracy = 0.946178
# mean IU  = 0.740120
#     class # 0 capture rate = 0.944973
#     class # 1 capture rate = 0.963534
# TRAIN: Batch: 0.6567117504495348 Loss_Total: 11.647058
# TRAIN: Batch: 0.6567117504495348 Loss_Seg: 9.918618
# accuracy = 0.950217
# mean IU  = 0.677690
#     class # 0 capture rate = 0.951343
#     class # 1 capture rate = 0.921001
# TRAIN: Batch: 0.6606207489641154 Loss_Total: 11.543528
# TRAIN: Batch: 0.6606207489641154 Loss_Seg: 12.731033
# accuracy = 0.933932
# mean IU  = 0.694725
#     class # 0 capture rate = 0.933164
#     class # 1 capture rate = 0.946113
# TRAIN: Batch: 0.664529747478696 Loss_Total: 12.498787
# TRAIN: Batch: 0.664529747478696 Loss_Seg: 12.793633
# accuracy = 0.942917
# mean IU  = 0.693717
#     class # 0 capture rate = 0.944772
#     class # 1 capture rate = 0.908305
# TRAIN: Batch: 0.6684387459932766 Loss_Total: 16.09446
# TRAIN: Batch: 0.6684387459932766 Loss_Seg: 16.71047
# accuracy = 0.925932
# mean IU  = 0.721357
#     class # 0 capture rate = 0.926940
#     class # 1 capture rate = 0.915590
# TRAIN: Batch: 0.6723477445078571 Loss_Total: 14.651032
# TRAIN: Batch: 0.6723477445078571 Loss_Seg: 15.458483
# accuracy = 0.921005
# mean IU  = 0.642315
#     class # 0 capture rate = 0.921688
#     class # 1 capture rate = 0.908168
# TRAIN: Batch: 0.6762567430224377 Loss_Total: 13.811757
# TRAIN: Batch: 0.6762567430224377 Loss_Seg: 15.07088
# accuracy = 0.932337
# mean IU  = 0.740238
#     class # 0 capture rate = 0.930959
#     class # 1 capture rate = 0.946458
# TRAIN: Batch: 0.6801657415370183 Loss_Total: 10.271848
# TRAIN: Batch: 0.6801657415370183 Loss_Seg: 9.434292
# accuracy = 0.956763
# mean IU  = 0.730241
#     class # 0 capture rate = 0.958532
#     class # 1 capture rate = 0.921668
# TRAIN: Batch: 0.6840747400515987 Loss_Total: 10.548637
# TRAIN: Batch: 0.6840747400515987 Loss_Seg: 10.660091
# accuracy = 0.948921
# mean IU  = 0.736270
#     class # 0 capture rate = 0.949579
#     class # 1 capture rate = 0.938710
# TRAIN: Batch: 0.6879837385661793 Loss_Total: 11.139591
# TRAIN: Batch: 0.6879837385661793 Loss_Seg: 10.619961
# accuracy = 0.944864
# mean IU  = 0.713163
#     class # 0 capture rate = 0.944599
#     class # 1 capture rate = 0.949441
# TRAIN: Batch: 0.6918927370807599 Loss_Total: 13.292971
# TRAIN: Batch: 0.6918927370807599 Loss_Seg: 12.686583
# accuracy = 0.936309
# mean IU  = 0.706248
#     class # 0 capture rate = 0.936337
#     class # 1 capture rate = 0.935897
# TRAIN: Batch: 0.6958017355953404 Loss_Total: 15.113707
# TRAIN: Batch: 0.6958017355953404 Loss_Seg: 10.654923
# accuracy = 0.946475
# mean IU  = 0.726363
#     class # 0 capture rate = 0.946605
#     class # 1 capture rate = 0.944398
# TRAIN: Batch: 0.699710734109921 Loss_Total: 11.493469
# TRAIN: Batch: 0.699710734109921 Loss_Seg: 9.922221
# accuracy = 0.946160
# mean IU  = 0.697983
#     class # 0 capture rate = 0.946461
#     class # 1 capture rate = 0.940114
# TRAIN: Batch: 0.7036197326245016 Loss_Total: 10.266691
# TRAIN: Batch: 0.7036197326245016 Loss_Seg: 9.226223
# accuracy = 0.957925
# mean IU  = 0.744808
#     class # 0 capture rate = 0.958057
#     class # 1 capture rate = 0.955448
# TRAIN: Batch: 0.7075287311390822 Loss_Total: 12.061926
# TRAIN: Batch: 0.7075287311390822 Loss_Seg: 9.714757
# accuracy = 0.949088
# mean IU  = 0.717167
#     class # 0 capture rate = 0.949564
#     class # 1 capture rate = 0.940341
# TRAIN: Batch: 0.7114377296536627 Loss_Total: 13.6038
# TRAIN: Batch: 0.7114377296536627 Loss_Seg: 10.750209
# accuracy = 0.952587
# mean IU  = 0.758367
#     class # 0 capture rate = 0.952469
#     class # 1 capture rate = 0.954273
# TRAIN: Batch: 0.7153467281682433 Loss_Total: 12.3346195
# TRAIN: Batch: 0.7153467281682433 Loss_Seg: 10.951897
# accuracy = 0.948143
# mean IU  = 0.713169
#     class # 0 capture rate = 0.950402
#     class # 1 capture rate = 0.907707
# TRAIN: Batch: 0.7192557266828239 Loss_Total: 14.80515
# TRAIN: Batch: 0.7192557266828239 Loss_Seg: 13.238144
# accuracy = 0.928341
# mean IU  = 0.676462
#     class # 0 capture rate = 0.927933
#     class # 1 capture rate = 0.935032
# TRAIN: Batch: 0.7231647251974044 Loss_Total: 10.605475
# TRAIN: Batch: 0.7231647251974044 Loss_Seg: 9.972358
# accuracy = 0.953951
# mean IU  = 0.759894
#     class # 0 capture rate = 0.954023
#     class # 1 capture rate = 0.952892
# TRAIN: Batch: 0.727073723711985 Loss_Total: 15.870716
# TRAIN: Batch: 0.727073723711985 Loss_Seg: 14.149777
# accuracy = 0.937738
# mean IU  = 0.702897
#     class # 0 capture rate = 0.940370
#     class # 1 capture rate = 0.897871
# TRAIN: Batch: 0.7309827222265656 Loss_Total: 11.334179
# TRAIN: Batch: 0.7309827222265656 Loss_Seg: 10.445247
# accuracy = 0.946258
# mean IU  = 0.710709
#     class # 0 capture rate = 0.947516
#     class # 1 capture rate = 0.923888
# TRAIN: Batch: 0.7348917207411462 Loss_Total: 10.320846
# TRAIN: Batch: 0.7348917207411462 Loss_Seg: 9.1461935
# accuracy = 0.951361
# mean IU  = 0.748708
#     class # 0 capture rate = 0.951212
#     class # 1 capture rate = 0.953616
# TRAIN: Batch: 0.7388007192557267 Loss_Total: 12.343693
# TRAIN: Batch: 0.7388007192557267 Loss_Seg: 13.858395
# accuracy = 0.934618
# mean IU  = 0.709449
#     class # 0 capture rate = 0.935719
#     class # 1 capture rate = 0.919511
# TRAIN: Batch: 0.7427097177703073 Loss_Total: 10.337962
# TRAIN: Batch: 0.7427097177703073 Loss_Seg: 10.240255
# accuracy = 0.946352
# mean IU  = 0.731981
#     class # 0 capture rate = 0.945136
#     class # 1 capture rate = 0.965253
# TRAIN: Batch: 0.7466187162848879 Loss_Total: 11.361453
# TRAIN: Batch: 0.7466187162848879 Loss_Seg: 10.050798
# accuracy = 0.952534
# mean IU  = 0.756148
#     class # 0 capture rate = 0.952442
#     class # 1 capture rate = 0.953887
# TRAIN: Batch: 0.7505277147994683 Loss_Total: 9.688945
# TRAIN: Batch: 0.7505277147994683 Loss_Seg: 6.552239
# accuracy = 0.965325
# mean IU  = 0.796964
#     class # 0 capture rate = 0.964293
#     class # 1 capture rate = 0.981392
# TRAIN: Batch: 0.7544367133140489 Loss_Total: 12.382311
# TRAIN: Batch: 0.7544367133140489 Loss_Seg: 10.292949
# accuracy = 0.938354
# mean IU  = 0.667692
#     class # 0 capture rate = 0.938440
#     class # 1 capture rate = 0.936490
# TRAIN: Batch: 0.7583457118286295 Loss_Total: 13.473333
# TRAIN: Batch: 0.7583457118286295 Loss_Seg: 13.530356
# accuracy = 0.936862
# mean IU  = 0.685772
#     class # 0 capture rate = 0.937689
#     class # 1 capture rate = 0.922197
# TRAIN: Batch: 0.76225471034321 Loss_Total: 9.885561
# TRAIN: Batch: 0.76225471034321 Loss_Seg: 11.207652
# accuracy = 0.945725
# mean IU  = 0.724859
#     class # 0 capture rate = 0.946282
#     class # 1 capture rate = 0.936937
# ...
# TRAIN: Batch: 0.8287076850910796 Loss_Seg: 8.555723
# accuracy = 0.957295
# mean IU  = 0.742800
#     class # 0 capture rate = 0.957340
#     class # 1 capture rate = 0.956438
# TRAIN: Batch: 0.8326166836056602 Loss_Total: 8.261715
# TRAIN: Batch: 0.8326166836056602 Loss_Seg: 6.150524
# accuracy = 0.963276
# mean IU  = 0.758532
#     class # 0 capture rate = 0.962519
#     class # 1 capture rate = 0.978657
# TRAIN: Batch: 0.8365256821202408 Loss_Total: 11.919076
# TRAIN: Batch: 0.8365256821202408 Loss_Seg: 9.827188
# accuracy = 0.948355
# mean IU  = 0.728531
#     class # 0 capture rate = 0.947456
#     class # 1 capture rate = 0.963478
# TRAIN: Batch: 0.8404346806348214 Loss_Total: 9.367083
# TRAIN: Batch: 0.8404346806348214 Loss_Seg: 9.877104
# accuracy = 0.950095
# mean IU  = 0.750016
#     class # 0 capture rate = 0.949650
#     class # 1 capture rate = 0.956538
# TRAIN: Batch: 0.8443436791494019 Loss_Total: 13.401995
# TRAIN: Batch: 0.8443436791494019 Loss_Seg: 15.685456
# accuracy = 0.932256
# mean IU  = 0.718464
#     class # 0 capture rate = 0.932067
#     class # 1 capture rate = 0.934564
# TRAIN: Batch: 0.8482526776639825 Loss_Total: 10.792816
# TRAIN: Batch: 0.8482526776639825 Loss_Seg: 8.891651
# accuracy = 0.949559
# mean IU  = 0.671871
#     class # 0 capture rate = 0.949729
#     class # 1 capture rate = 0.944871
# TRAIN: Batch: 0.8521616761785631 Loss_Total: 11.655422
# TRAIN: Batch: 0.8521616761785631 Loss_Seg: 13.529017
# accuracy = 0.943774
# mean IU  = 0.688860
#     class # 0 capture rate = 0.946505
#     class # 1 capture rate = 0.890664
# TRAIN: Batch: 0.8560706746931436 Loss_Total: 11.966818
# TRAIN: Batch: 0.8560706746931436 Loss_Seg: 11.789461
# accuracy = 0.943845
# mean IU  = 0.708983
#     class # 0 capture rate = 0.946168
#     class # 1 capture rate = 0.905132
# TRAIN: Batch: 0.8599796732077242 Loss_Total: 12.431667
# TRAIN: Batch: 0.8599796732077242 Loss_Seg: 11.016471
# accuracy = 0.944846
# mean IU  = 0.717157
#     class # 0 capture rate = 0.945213
#     class # 1 capture rate = 0.938784
# TRAIN: Batch: 0.8638886717223048 Loss_Total: 9.83494
# TRAIN: Batch: 0.8638886717223048 Loss_Seg: 8.529319
# accuracy = 0.965246
# mean IU  = 0.780405
#     class # 0 capture rate = 0.966267
#     class # 1 capture rate = 0.947510
# TRAIN: Batch: 0.8677976702368853 Loss_Total: 9.772565
# TRAIN: Batch: 0.8677976702368853 Loss_Seg: 8.59499
# accuracy = 0.962034
# mean IU  = 0.763151
#     class # 0 capture rate = 0.962552
#     class # 1 capture rate = 0.952604
# TRAIN: Batch: 0.8717066687514659 Loss_Total: 11.225641
# TRAIN: Batch: 0.8717066687514659 Loss_Seg: 14.305492
# accuracy = 0.927352
# mean IU  = 0.723807
#     class # 0 capture rate = 0.926428
#     class # 1 capture rate = 0.937146
# TRAIN: Batch: 0.8756156672660464 Loss_Total: 13.937675
# TRAIN: Batch: 0.8756156672660464 Loss_Seg: 11.594869
# accuracy = 0.945452
# mean IU  = 0.737764
#     class # 0 capture rate = 0.945662
#     class # 1 capture rate = 0.942499
# TRAIN: Batch: 0.879524665780627 Loss_Total: 16.07704
# TRAIN: Batch: 0.879524665780627 Loss_Seg: 18.043686
# accuracy = 0.939412
# mean IU  = 0.731444
#     class # 0 capture rate = 0.946339
#     class # 1 capture rate = 0.858558
# TRAIN: Batch: 0.8834336642952075 Loss_Total: 8.252621
# TRAIN: Batch: 0.8834336642952075 Loss_Seg: 9.23921
# accuracy = 0.954903
# mean IU  = 0.767003
#     class # 0 capture rate = 0.955215
#     class # 1 capture rate = 0.950499
# TRAIN: Batch: 0.8873426628097881 Loss_Total: 10.886532
# TRAIN: Batch: 0.8873426628097881 Loss_Seg: 10.074407
# accuracy = 0.950778
# mean IU  = 0.735796
#     class # 0 capture rate = 0.950834
#     class # 1 capture rate = 0.949850
# TRAIN: Batch: 0.8912516613243687 Loss_Total: 10.06192
# TRAIN: Batch: 0.8912516613243687 Loss_Seg: 8.9931965
# accuracy = 0.958126
# mean IU  = 0.761524
#     class # 0 capture rate = 0.958690
#     class # 1 capture rate = 0.948945
# TRAIN: Batch: 0.8951606598389492 Loss_Total: 12.678375
# TRAIN: Batch: 0.8951606598389492 Loss_Seg: 9.148544
# accuracy = 0.951012
# mean IU  = 0.745877
#     class # 0 capture rate = 0.950242
#     class # 1 capture rate = 0.962948
# TRAIN: Batch: 0.8990696583535298 Loss_Total: 14.216906
# TRAIN: Batch: 0.8990696583535298 Loss_Seg: 14.066687
# accuracy = 0.930633
# mean IU  = 0.710604
#     class # 0 capture rate = 0.929797
#     class # 1 capture rate = 0.941335
# TRAIN: Batch: 0.9029786568681104 Loss_Total: 13.956144
# TRAIN: Batch: 0.9029786568681104 Loss_Seg: 9.200839
# accuracy = 0.958100
# mean IU  = 0.771715
#     class # 0 capture rate = 0.958872
#     class # 1 capture rate = 0.946656
# TRAIN: Batch: 0.906887655382691 Loss_Total: 18.857197
# TRAIN: Batch: 0.906887655382691 Loss_Seg: 10.748555
# accuracy = 0.940647
# mean IU  = 0.710830
#     class # 0 capture rate = 0.940081
#     class # 1 capture rate = 0.949709
# TRAIN: Batch: 0.9107966538972715 Loss_Total: 13.849276
# TRAIN: Batch: 0.9107966538972715 Loss_Seg: 11.570689
# accuracy = 0.945772
# mean IU  = 0.716978
#     class # 0 capture rate = 0.946728
#     class # 1 capture rate = 0.929748
# TRAIN: Batch: 0.9147056524118521 Loss_Total: 12.036599
# TRAIN: Batch: 0.9147056524118521 Loss_Seg: 12.611914
# accuracy = 0.936148
# mean IU  = 0.717295
#     class # 0 capture rate = 0.936236
#     class # 1 capture rate = 0.934959
# TRAIN: Batch: 0.9186146509264327 Loss_Total: 15.145365
# TRAIN: Batch: 0.9186146509264327 Loss_Seg: 12.461548
# accuracy = 0.935142
# mean IU  = 0.685722
#     class # 0 capture rate = 0.935055
#     class # 1 capture rate = 0.936658
# TRAIN: Batch: 0.9225236494410132 Loss_Total: 11.654188
# TRAIN: Batch: 0.9225236494410132 Loss_Seg: 12.173168
# accuracy = 0.945627
# mean IU  = 0.753600
#     class # 0 capture rate = 0.945233
#     class # 1 capture rate = 0.950524
# TRAIN: Batch: 0.9264326479555938 Loss_Total: 11.547442
# TRAIN: Batch: 0.9264326479555938 Loss_Seg: 13.989297
# accuracy = 0.946011
# mean IU  = 0.726653
#     class # 0 capture rate = 0.948805
#     class # 1 capture rate = 0.903959
# TRAIN: Batch: 0.9303416464701744 Loss_Total: 9.852295
# TRAIN: Batch: 0.9303416464701744 Loss_Seg: 8.050915
# accuracy = 0.953727
# mean IU  = 0.739436
#     class # 0 capture rate = 0.952333
#     class # 1 capture rate = 0.978733
# TRAIN: Batch: 0.9342506449847549 Loss_Total: 11.904192
# TRAIN: Batch: 0.9342506449847549 Loss_Seg: 12.644748
# accuracy = 0.940702
# mean IU  = 0.723784
#     class # 0 capture rate = 0.941495
#     class # 1 capture rate = 0.929593
# TRAIN: Batch: 0.9381596434993354 Loss_Total: 11.981589
# TRAIN: Batch: 0.9381596434993354 Loss_Seg: 8.641508
# accuracy = 0.960471
# mean IU  = 0.742149
#     class # 0 capture rate = 0.961163
#     class # 1 capture rate = 0.946203
# TRAIN: Batch: 0.942068642013916 Loss_Total: 20.597641
# TRAIN: Batch: 0.942068642013916 Loss_Seg: 21.47917
# accuracy = 0.907646
# mean IU  = 0.675034
#     class # 0 capture rate = 0.910658
#     class # 1 capture rate = 0.875743
# TRAIN: Batch: 0.9459776405284966 Loss_Total: 10.681785
# TRAIN: Batch: 0.9459776405284966 Loss_Seg: 9.177277
# accuracy = 0.963134
# mean IU  = 0.812631
#     class # 0 capture rate = 0.963420
#     class # 1 capture rate = 0.959667
# TRAIN: Batch: 0.9498866390430771 Loss_Total: 11.761212
# TRAIN: Batch: 0.9498866390430771 Loss_Seg: 10.018468
# accuracy = 0.945279
# mean IU  = 0.739794
#     class # 0 capture rate = 0.944288
#     class # 1 capture rate = 0.959206
# TRAIN: Batch: 0.9537956375576577 Loss_Total: 12.353821
# TRAIN: Batch: 0.9537956375576577 Loss_Seg: 9.94943
# accuracy = 0.946014
# mean IU  = 0.740542
#     class # 0 capture rate = 0.944178
#     class # 1 capture rate = 0.972505
# TRAIN: Batch: 0.9577046360722383 Loss_Total: 14.997662
# TRAIN: Batch: 0.9577046360722383 Loss_Seg: 15.572806
# accuracy = 0.922126
# mean IU  = 0.697315
#     class # 0 capture rate = 0.920808
#     class # 1 capture rate = 0.938121
# TRAIN: Batch: 0.9616136345868188 Loss_Total: 10.460145
# TRAIN: Batch: 0.9616136345868188 Loss_Seg: 11.673226
# accuracy = 0.951850
# mean IU  = 0.741966
#     class # 0 capture rate = 0.952449
#     class # 1 capture rate = 0.942252
# TRAIN: Batch: 0.9655226331013994 Loss_Total: 12.327219
# TRAIN: Batch: 0.9655226331013994 Loss_Seg: 10.74974
# accuracy = 0.955680
# mean IU  = 0.734933
#     class # 0 capture rate = 0.957848
#     class # 1 capture rate = 0.915879
# TRAIN: Batch: 0.96943163161598 Loss_Total: 13.613495
# TRAIN: Batch: 0.96943163161598 Loss_Seg: 13.995468
# accuracy = 0.933636
# mean IU  = 0.723895
#     class # 0 capture rate = 0.933051
#     class # 1 capture rate = 0.940724
# TRAIN: Batch: 0.9733406301305606 Loss_Total: 13.148247
# TRAIN: Batch: 0.9733406301305606 Loss_Seg: 11.665655
# accuracy = 0.925136
# mean IU  = 0.657511
#     class # 0 capture rate = 0.922921
#     class # 1 capture rate = 0.966974
# TRAIN: Batch: 0.9772496286451411 Loss_Total: 10.809548
# TRAIN: Batch: 0.9772496286451411 Loss_Seg: 8.447915
# accuracy = 0.952746
# mean IU  = 0.716594
#     class # 0 capture rate = 0.952660
#     class # 1 capture rate = 0.954521
# TRAIN: Batch: 0.9811586271597217 Loss_Total: 11.912935
# TRAIN: Batch: 0.9811586271597217 Loss_Seg: 10.161957
# accuracy = 0.944815
# mean IU  = 0.703373
#     class # 0 capture rate = 0.944800
#     class # 1 capture rate = 0.945087
# TRAIN: Batch: 0.9850676256743023 Loss_Total: 11.497276
# TRAIN: Batch: 0.9850676256743023 Loss_Seg: 10.551669
# accuracy = 0.938492
# mean IU  = 0.695428
#     class # 0 capture rate = 0.937663
#     class # 1 capture rate = 0.953005
# TRAIN: Batch: 0.9889766241888828 Loss_Total: 10.266901
# TRAIN: Batch: 0.9889766241888828 Loss_Seg: 7.259023
# accuracy = 0.964964
# mean IU  = 0.776261
#     class # 0 capture rate = 0.965890
#     class # 1 capture rate = 0.948435
# TRAIN: Batch: 0.9928856227034634 Loss_Total: 11.210649
# TRAIN: Batch: 0.9928856227034634 Loss_Seg: 8.976628
# accuracy = 0.952979
# mean IU  = 0.719540
#     class # 0 capture rate = 0.953304
#     class # 1 capture rate = 0.946447
# TRAIN: Batch: 0.996794621218044 Loss_Total: 10.025221
# TRAIN: Batch: 0.996794621218044 Loss_Seg: 9.759785
# accuracy = 0.951874
# mean IU  = 0.734945
#     class # 0 capture rate = 0.952532
#     class # 1 capture rate = 0.940685
# Validating NN
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: Both axis > a.ndim and axis < -a.ndim - 1 are deprecated and will raise an AxisError in the future.
#   """
# Process Process-24:
# Process Process-23:
# Traceback (most recent call last):
# Traceback (most recent call last):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-17-76742371c67f> in <module>
#      24     #model = Model(args, experiment, loss_weight=weight, mustRestore=False)
#      25     model = Model(args, charList=open(join(args.ckptpath_recg, 'charList.txt')).read(), loss_beta=0.5,loss_weight=weight, decoderType=DecoderType.BeamSearch,experiment=experiment,mustRestore_seg=False,mustRestore_recg=True,joint=True)
# ---> 26     model.trainSeg(loader=trainloader, validateloader=testloader)
#      27
#      28 else:
#
# <ipython-input-3-6809828a6d02> in trainSeg(self, loader, validateloader, testloader)
#     822             # validate:
#     823             if validateloader != None:
# --> 824                 avg_batch_loss_seg,avg_batch_loss_total, acc_total, cap_0, cap_1 = self.validateSeg(validateloader, epoch)
#     825             else:
#     826                 avg_batch_loss_seg,avg_batch_loss_total, acc_total, cap_0, cap_1 = self.validateSeg(loader, epoch)
#
# <ipython-input-3-6809828a6d02> in validateSeg(self, loader, epoch, is_testing)
#     886              self.seqLen: [Model.maxTextLen] * bt_size,#self.batchsize_recg, #changed!!!!!!!!!!!!!!!!!!!
#     887              self.phase_train: False,
# --> 888              self.is_training:False})  # self.loss,val_loss,
#     889
#     890             total_val_loss_seg += val_loss_seg
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.5/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 249, in _bootstrap
#     self.run()
#   File "/usr/local/lib/python3.5/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.5/dist-packages/torch/utils/data/dataloader.py", line 96, in _worker_loop
#     r = index_queue.get(timeout=MANAGER_STATUS_CHECK_INTERVAL)
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 104, in get
#     if timeout < 0 or not self._poll(timeout):
#   File "/usr/lib/python3.5/multiprocessing/queues.py", line 104, in get
#     if timeout < 0 or not self._poll(timeout):
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 257, in poll
#     return self._poll(timeout)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 414, in _poll
#     r = wait([self], timeout)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.5/multiprocessing/connection.py", line 911, in wait
#     ready = selector.select(timeout)
#   File "/usr/lib/python3.5/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
#   File "/usr/lib/python3.5/selectors.py", line 376, in select
#     fd_event_list = self._poll.poll(timeout)
# KeyboardInterrupt
# KeyboardInterrupt

# %%
len(tf.get_collection(tf.GraphKeys.VARIABLES))#, "graph_recognition")
# Out:
# 1161

# %%
a=[1,2,3].sort()

# %%
a

# %%
len(tf.get_collection(tf.GraphKeys.VARIABLES,"graph_segmentation"))
# Out:
# 105

# %%
len(tf.get_collection(tf.GraphKeys.VARIABLES,"graph_recognition"))
# Out:
# 1048

# %%
a=tf.get_collection(tf.GraphKeys.VARIABLES)[0]

# %%
for a in tf.get_collection(tf.GraphKeys.VARIABLES):
    t=a.name.split('/')[0]
    if t!='graph_segmentation' and t!='graph_recognition':
        print(a.name)
# Out:
# Variable:0
# add/avg:0
# beta1_power:0
# beta2_power:0

# %%
tf.get_collection(tf.GraphKeys.TRAINABLE_VARIABLES)
# Out:
# [<tf.Variable 'graph_segmentation/down_conv_0/w1:0' shape=(3, 3, 1, 32) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_0/w2:0' shape=(3, 3, 32, 32) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_0/b1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_0/b2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_1/w1:0' shape=(3, 3, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_1/w2:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_1/b1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_1/b2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_2/w1:0' shape=(3, 3, 64, 128) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_2/w2:0' shape=(3, 3, 128, 128) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_2/b1:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/down_conv_2/b2:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/wd:0' shape=(2, 2, 64, 128) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/bd:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/w1:0' shape=(3, 3, 128, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/w2:0' shape=(3, 3, 64, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/b1:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_1/b2:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/wd:0' shape=(2, 2, 32, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/bd:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/w1:0' shape=(3, 3, 64, 32) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/w2:0' shape=(3, 3, 32, 32) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/b1:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/up_conv_0/b2:0' shape=(32,) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/output_map/weight:0' shape=(1, 1, 32, 2) dtype=float32_ref>,
#  <tf.Variable 'graph_segmentation/output_map/bias:0' shape=(2,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Initial_convolution/kernel:0' shape=(7, 7, 1, 24) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/bottleneck/BatchNorm/beta:0' shape=(24,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/bottleneck/BatchNorm/gamma:0' shape=(24,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/bottleneck/kernel:0' shape=(1, 1, 24, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_0/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/bottleneck/BatchNorm/beta:0' shape=(36,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/bottleneck/BatchNorm/gamma:0' shape=(36,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/bottleneck/kernel:0' shape=(1, 1, 36, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_1/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/bottleneck/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/bottleneck/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/bottleneck/kernel:0' shape=(1, 1, 48, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_2/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/bottleneck/BatchNorm/beta:0' shape=(60,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/bottleneck/BatchNorm/gamma:0' shape=(60,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/bottleneck/kernel:0' shape=(1, 1, 60, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_3/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/bottleneck/BatchNorm/beta:0' shape=(72,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/bottleneck/BatchNorm/gamma:0' shape=(72,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/bottleneck/kernel:0' shape=(1, 1, 72, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_4/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/bottleneck/BatchNorm/beta:0' shape=(84,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/bottleneck/BatchNorm/gamma:0' shape=(84,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/bottleneck/kernel:0' shape=(1, 1, 84, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_5/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/bottleneck/BatchNorm/beta:0' shape=(96,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/bottleneck/BatchNorm/gamma:0' shape=(96,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/bottleneck/kernel:0' shape=(1, 1, 96, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_6/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/bottleneck/BatchNorm/beta:0' shape=(108,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/bottleneck/BatchNorm/gamma:0' shape=(108,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/bottleneck/kernel:0' shape=(1, 1, 108, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_7/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/bottleneck/BatchNorm/beta:0' shape=(120,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/bottleneck/BatchNorm/gamma:0' shape=(120,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/bottleneck/kernel:0' shape=(1, 1, 120, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_0/layer_8/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_0/composite_function/BatchNorm/beta:0' shape=(132,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_0/composite_function/BatchNorm/gamma:0' shape=(132,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_0/composite_function/kernel:0' shape=(1, 1, 132, 52) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/bottleneck/BatchNorm/beta:0' shape=(52,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/bottleneck/BatchNorm/gamma:0' shape=(52,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/bottleneck/kernel:0' shape=(1, 1, 52, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_0/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/bottleneck/BatchNorm/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/bottleneck/BatchNorm/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/bottleneck/kernel:0' shape=(1, 1, 64, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_1/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/bottleneck/BatchNorm/beta:0' shape=(76,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/bottleneck/BatchNorm/gamma:0' shape=(76,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/bottleneck/kernel:0' shape=(1, 1, 76, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_2/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/bottleneck/BatchNorm/beta:0' shape=(88,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/bottleneck/BatchNorm/gamma:0' shape=(88,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/bottleneck/kernel:0' shape=(1, 1, 88, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_3/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/bottleneck/BatchNorm/beta:0' shape=(100,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/bottleneck/BatchNorm/gamma:0' shape=(100,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/bottleneck/kernel:0' shape=(1, 1, 100, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_4/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/bottleneck/BatchNorm/beta:0' shape=(112,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/bottleneck/BatchNorm/gamma:0' shape=(112,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/bottleneck/kernel:0' shape=(1, 1, 112, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_5/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/bottleneck/BatchNorm/beta:0' shape=(124,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/bottleneck/BatchNorm/gamma:0' shape=(124,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/bottleneck/kernel:0' shape=(1, 1, 124, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_6/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/bottleneck/BatchNorm/beta:0' shape=(136,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/bottleneck/BatchNorm/gamma:0' shape=(136,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/bottleneck/kernel:0' shape=(1, 1, 136, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_7/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/bottleneck/BatchNorm/beta:0' shape=(148,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/bottleneck/BatchNorm/gamma:0' shape=(148,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/bottleneck/kernel:0' shape=(1, 1, 148, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_1/layer_8/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_1/composite_function/BatchNorm/beta:0' shape=(160,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_1/composite_function/BatchNorm/gamma:0' shape=(160,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_1/composite_function/kernel:0' shape=(1, 1, 160, 64) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/bottleneck/BatchNorm/beta:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/bottleneck/BatchNorm/gamma:0' shape=(64,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/bottleneck/kernel:0' shape=(1, 1, 64, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_0/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/bottleneck/BatchNorm/beta:0' shape=(76,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/bottleneck/BatchNorm/gamma:0' shape=(76,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/bottleneck/kernel:0' shape=(1, 1, 76, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_1/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/bottleneck/BatchNorm/beta:0' shape=(88,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/bottleneck/BatchNorm/gamma:0' shape=(88,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/bottleneck/kernel:0' shape=(1, 1, 88, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_2/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/bottleneck/BatchNorm/beta:0' shape=(100,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/bottleneck/BatchNorm/gamma:0' shape=(100,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/bottleneck/kernel:0' shape=(1, 1, 100, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_3/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/bottleneck/BatchNorm/beta:0' shape=(112,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/bottleneck/BatchNorm/gamma:0' shape=(112,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/bottleneck/kernel:0' shape=(1, 1, 112, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_4/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/bottleneck/BatchNorm/beta:0' shape=(124,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/bottleneck/BatchNorm/gamma:0' shape=(124,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/bottleneck/kernel:0' shape=(1, 1, 124, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_5/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/bottleneck/BatchNorm/beta:0' shape=(136,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/bottleneck/BatchNorm/gamma:0' shape=(136,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/bottleneck/kernel:0' shape=(1, 1, 136, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_6/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/bottleneck/BatchNorm/beta:0' shape=(148,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/bottleneck/BatchNorm/gamma:0' shape=(148,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/bottleneck/kernel:0' shape=(1, 1, 148, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_7/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/bottleneck/BatchNorm/beta:0' shape=(160,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/bottleneck/BatchNorm/gamma:0' shape=(160,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/bottleneck/kernel:0' shape=(1, 1, 160, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_2/layer_8/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_2/composite_function/BatchNorm/beta:0' shape=(172,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_2/composite_function/BatchNorm/gamma:0' shape=(172,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_2/composite_function/kernel:0' shape=(1, 1, 172, 68) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/bottleneck/BatchNorm/beta:0' shape=(68,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/bottleneck/BatchNorm/gamma:0' shape=(68,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/bottleneck/kernel:0' shape=(1, 1, 68, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_0/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/bottleneck/BatchNorm/beta:0' shape=(80,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/bottleneck/BatchNorm/gamma:0' shape=(80,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/bottleneck/kernel:0' shape=(1, 1, 80, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_1/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/bottleneck/BatchNorm/beta:0' shape=(92,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/bottleneck/BatchNorm/gamma:0' shape=(92,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/bottleneck/kernel:0' shape=(1, 1, 92, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_2/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/bottleneck/BatchNorm/beta:0' shape=(104,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/bottleneck/BatchNorm/gamma:0' shape=(104,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/bottleneck/kernel:0' shape=(1, 1, 104, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_3/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/bottleneck/BatchNorm/beta:0' shape=(116,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/bottleneck/BatchNorm/gamma:0' shape=(116,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/bottleneck/kernel:0' shape=(1, 1, 116, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_4/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/bottleneck/BatchNorm/beta:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/bottleneck/BatchNorm/gamma:0' shape=(128,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/bottleneck/kernel:0' shape=(1, 1, 128, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_5/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/bottleneck/BatchNorm/beta:0' shape=(140,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/bottleneck/BatchNorm/gamma:0' shape=(140,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/bottleneck/kernel:0' shape=(1, 1, 140, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_6/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/bottleneck/BatchNorm/beta:0' shape=(152,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/bottleneck/BatchNorm/gamma:0' shape=(152,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/bottleneck/kernel:0' shape=(1, 1, 152, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_7/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/bottleneck/BatchNorm/beta:0' shape=(164,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/bottleneck/BatchNorm/gamma:0' shape=(164,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/bottleneck/kernel:0' shape=(1, 1, 164, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_3/layer_8/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_3/composite_function/BatchNorm/beta:0' shape=(176,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_3/composite_function/BatchNorm/gamma:0' shape=(176,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Transition_after_block_3/composite_function/kernel:0' shape=(1, 1, 176, 70) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/bottleneck/BatchNorm/beta:0' shape=(70,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/bottleneck/BatchNorm/gamma:0' shape=(70,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/bottleneck/kernel:0' shape=(1, 1, 70, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_0/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/bottleneck/BatchNorm/beta:0' shape=(82,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/bottleneck/BatchNorm/gamma:0' shape=(82,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/bottleneck/kernel:0' shape=(1, 1, 82, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_1/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/bottleneck/BatchNorm/beta:0' shape=(94,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/bottleneck/BatchNorm/gamma:0' shape=(94,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/bottleneck/kernel:0' shape=(1, 1, 94, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_2/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/bottleneck/BatchNorm/beta:0' shape=(106,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/bottleneck/BatchNorm/gamma:0' shape=(106,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/bottleneck/kernel:0' shape=(1, 1, 106, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_3/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/bottleneck/BatchNorm/beta:0' shape=(118,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/bottleneck/BatchNorm/gamma:0' shape=(118,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/bottleneck/kernel:0' shape=(1, 1, 118, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_4/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/bottleneck/BatchNorm/beta:0' shape=(130,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/bottleneck/BatchNorm/gamma:0' shape=(130,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/bottleneck/kernel:0' shape=(1, 1, 130, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_5/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/bottleneck/BatchNorm/beta:0' shape=(142,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/bottleneck/BatchNorm/gamma:0' shape=(142,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/bottleneck/kernel:0' shape=(1, 1, 142, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_6/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/bottleneck/BatchNorm/beta:0' shape=(154,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/bottleneck/BatchNorm/gamma:0' shape=(154,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/bottleneck/kernel:0' shape=(1, 1, 154, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_7/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/bottleneck/BatchNorm/beta:0' shape=(166,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/bottleneck/BatchNorm/gamma:0' shape=(166,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/bottleneck/kernel:0' shape=(1, 1, 166, 48) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/composite_function/BatchNorm/beta:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/composite_function/BatchNorm/gamma:0' shape=(48,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/Block_4/layer_8/composite_function/kernel:0' shape=(3, 3, 48, 12) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/global_pool/BatchNorm/beta:0' shape=(178,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/global_pool/BatchNorm/gamma:0' shape=(178,) dtype=float32_ref>,
#  <tf.Variable 'bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/kernel:0' shape=(434, 1024) dtype=float32_ref>,
#  <tf.Variable 'bidirectional_rnn/fw/multi_rnn_cell/cell_0/lstm_cell/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/kernel:0' shape=(512, 1024) dtype=float32_ref>,
#  <tf.Variable 'bidirectional_rnn/fw/multi_rnn_cell/cell_1/lstm_cell/bias:0' shape=(1024,) dtype=float32_ref>,
#  <tf.Variable 'graph_recognition/graph_recognition_1/Variable:0' shape=(1, 1, 512, 66) dtype=float32_ref>]

# %%
a=[n.name for n in tf.get_default_graph().as_graph_def().node]
for i in a:
    print(i)
# Out:
# graph_segmentation/Placeholder
# graph_segmentation/Placeholder_1
# graph_segmentation/phase_train
# graph_segmentation/preprocessing/Shape
# graph_segmentation/preprocessing/strided_slice/stack
# graph_segmentation/preprocessing/strided_slice/stack_1
# graph_segmentation/preprocessing/strided_slice/stack_2
# graph_segmentation/preprocessing/strided_slice
# graph_segmentation/preprocessing/Shape_1
# graph_segmentation/preprocessing/strided_slice_1/stack
# graph_segmentation/preprocessing/strided_slice_1/stack_1
# graph_segmentation/preprocessing/strided_slice_1/stack_2
# graph_segmentation/preprocessing/strided_slice_1
# graph_segmentation/preprocessing/stack/0
# graph_segmentation/preprocessing/stack/3
# graph_segmentation/preprocessing/stack
# graph_segmentation/preprocessing/Reshape
# graph_segmentation/preprocessing/Shape_2
# graph_segmentation/preprocessing/strided_slice_2/stack
# graph_segmentation/preprocessing/strided_slice_2/stack_1
# graph_segmentation/preprocessing/strided_slice_2/stack_2
# graph_segmentation/preprocessing/strided_slice_2
# graph_segmentation/down_conv_0/truncated_normal/shape
# graph_segmentation/down_conv_0/truncated_normal/mean
# graph_segmentation/down_conv_0/truncated_normal/stddev
# graph_segmentation/down_conv_0/truncated_normal/TruncatedNormal
# graph_segmentation/down_conv_0/truncated_normal/mul
# graph_segmentation/down_conv_0/truncated_normal
# graph_segmentation/down_conv_0/w1
# graph_segmentation/down_conv_0/w1/Assign
# graph_segmentation/down_conv_0/w1/read
# graph_segmentation/down_conv_0/truncated_normal_1/shape
# graph_segmentation/down_conv_0/truncated_normal_1/mean
# graph_segmentation/down_conv_0/truncated_normal_1/stddev
# graph_segmentation/down_conv_0/truncated_normal_1/TruncatedNormal
# graph_segmentation/down_conv_0/truncated_normal_1/mul
# graph_segmentation/down_conv_0/truncated_normal_1
# graph_segmentation/down_conv_0/w2
# graph_segmentation/down_conv_0/w2/Assign
# graph_segmentation/down_conv_0/w2/read
# graph_segmentation/down_conv_0/Const
# graph_segmentation/down_conv_0/b1
# graph_segmentation/down_conv_0/b1/Assign
# graph_segmentation/down_conv_0/b1/read
# graph_segmentation/down_conv_0/Const_1
# graph_segmentation/down_conv_0/b2
# graph_segmentation/down_conv_0/b2/Assign
# graph_segmentation/down_conv_0/b2/read
# graph_segmentation/down_conv_0/conv2d/Conv2D
# graph_segmentation/down_conv_0/conv2d/BiasAdd
# graph_segmentation/down_conv_0/conv2d/dropout/rate
# graph_segmentation/down_conv_0/conv2d/dropout/Shape
# graph_segmentation/down_conv_0/conv2d/dropout/sub/x
# graph_segmentation/down_conv_0/conv2d/dropout/sub
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform/min
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform/max
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform/sub
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform/mul
# graph_segmentation/down_conv_0/conv2d/dropout/random_uniform
# graph_segmentation/down_conv_0/conv2d/dropout/add
# graph_segmentation/down_conv_0/conv2d/dropout/Floor
# graph_segmentation/down_conv_0/conv2d/dropout/div
# graph_segmentation/down_conv_0/conv2d/dropout/mul
# graph_segmentation/down_conv_0/Relu
# graph_segmentation/down_conv_0/conv2d_1/Conv2D
# graph_segmentation/down_conv_0/conv2d_1/BiasAdd
# graph_segmentation/down_conv_0/conv2d_1/dropout/rate
# graph_segmentation/down_conv_0/conv2d_1/dropout/Shape
# graph_segmentation/down_conv_0/conv2d_1/dropout/sub/x
# graph_segmentation/down_conv_0/conv2d_1/dropout/sub
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform/min
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform/max
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform/sub
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform/mul
# graph_segmentation/down_conv_0/conv2d_1/dropout/random_uniform
# graph_segmentation/down_conv_0/conv2d_1/dropout/add
# graph_segmentation/down_conv_0/conv2d_1/dropout/Floor
# graph_segmentation/down_conv_0/conv2d_1/dropout/div
# graph_segmentation/down_conv_0/conv2d_1/dropout/mul
# graph_segmentation/down_conv_0/Relu_1
# graph_segmentation/down_conv_0/MaxPool
# graph_segmentation/down_conv_1/truncated_normal/shape
# graph_segmentation/down_conv_1/truncated_normal/mean
# graph_segmentation/down_conv_1/truncated_normal/stddev
# graph_segmentation/down_conv_1/truncated_normal/TruncatedNormal
# graph_segmentation/down_conv_1/truncated_normal/mul
# graph_segmentation/down_conv_1/truncated_normal
# graph_segmentation/down_conv_1/w1
# graph_segmentation/down_conv_1/w1/Assign
# graph_segmentation/down_conv_1/w1/read
# graph_segmentation/down_conv_1/truncated_normal_1/shape
# graph_segmentation/down_conv_1/truncated_normal_1/mean
# graph_segmentation/down_conv_1/truncated_normal_1/stddev
# graph_segmentation/down_conv_1/truncated_normal_1/TruncatedNormal
# graph_segmentation/down_conv_1/truncated_normal_1/mul
# graph_segmentation/down_conv_1/truncated_normal_1
# graph_segmentation/down_conv_1/w2
# graph_segmentation/down_conv_1/w2/Assign
# graph_segmentation/down_conv_1/w2/read
# graph_segmentation/down_conv_1/Const
# graph_segmentation/down_conv_1/b1
# graph_segmentation/down_conv_1/b1/Assign
# graph_segmentation/down_conv_1/b1/read
# graph_segmentation/down_conv_1/Const_1
# graph_segmentation/down_conv_1/b2
# graph_segmentation/down_conv_1/b2/Assign
# graph_segmentation/down_conv_1/b2/read
# graph_segmentation/down_conv_1/conv2d/Conv2D
# graph_segmentation/down_conv_1/conv2d/BiasAdd
# graph_segmentation/down_conv_1/conv2d/dropout/rate
# graph_segmentation/down_conv_1/conv2d/dropout/Shape
# graph_segmentation/down_conv_1/conv2d/dropout/sub/x
# graph_segmentation/down_conv_1/conv2d/dropout/sub
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform/min
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform/max
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform/sub
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform/mul
# graph_segmentation/down_conv_1/conv2d/dropout/random_uniform
# graph_segmentation/down_conv_1/conv2d/dropout/add
# graph_segmentation/down_conv_1/conv2d/dropout/Floor
# graph_segmentation/down_conv_1/conv2d/dropout/div
# graph_segmentation/down_conv_1/conv2d/dropout/mul
# graph_segmentation/down_conv_1/Relu
# graph_segmentation/down_conv_1/conv2d_1/Conv2D
# graph_segmentation/down_conv_1/conv2d_1/BiasAdd
# graph_segmentation/down_conv_1/conv2d_1/dropout/rate
# graph_segmentation/down_conv_1/conv2d_1/dropout/Shape
# graph_segmentation/down_conv_1/conv2d_1/dropout/sub/x
# graph_segmentation/down_conv_1/conv2d_1/dropout/sub
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform/min
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform/max
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform/sub
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform/mul
# graph_segmentation/down_conv_1/conv2d_1/dropout/random_uniform
# graph_segmentation/down_conv_1/conv2d_1/dropout/add
# graph_segmentation/down_conv_1/conv2d_1/dropout/Floor
# graph_segmentation/down_conv_1/conv2d_1/dropout/div
# graph_segmentation/down_conv_1/conv2d_1/dropout/mul
# graph_segmentation/down_conv_1/Relu_1
# graph_segmentation/down_conv_1/MaxPool
# graph_segmentation/down_conv_2/truncated_normal/shape
# graph_segmentation/down_conv_2/truncated_normal/mean
# graph_segmentation/down_conv_2/truncated_normal/stddev
# graph_segmentation/down_conv_2/truncated_normal/TruncatedNormal
# graph_segmentation/down_conv_2/truncated_normal/mul
# graph_segmentation/down_conv_2/truncated_normal
# graph_segmentation/down_conv_2/w1
# graph_segmentation/down_conv_2/w1/Assign
# graph_segmentation/down_conv_2/w1/read
# graph_segmentation/down_conv_2/truncated_normal_1/shape
# graph_segmentation/down_conv_2/truncated_normal_1/mean
# graph_segmentation/down_conv_2/truncated_normal_1/stddev
# graph_segmentation/down_conv_2/truncated_normal_1/TruncatedNormal
# graph_segmentation/down_conv_2/truncated_normal_1/mul
# graph_segmentation/down_conv_2/truncated_normal_1
# graph_segmentation/down_conv_2/w2
# graph_segmentation/down_conv_2/w2/Assign
# graph_segmentation/down_conv_2/w2/read
# graph_segmentation/down_conv_2/Const
# graph_segmentation/down_conv_2/b1
# graph_segmentation/down_conv_2/b1/Assign
# graph_segmentation/down_conv_2/b1/read
# graph_segmentation/down_conv_2/Const_1
# graph_segmentation/down_conv_2/b2
# graph_segmentation/down_conv_2/b2/Assign
# graph_segmentation/down_conv_2/b2/read
# graph_segmentation/down_conv_2/conv2d/Conv2D
# graph_segmentation/down_conv_2/conv2d/BiasAdd
# graph_segmentation/down_conv_2/conv2d/dropout/rate
# graph_segmentation/down_conv_2/conv2d/dropout/Shape
# graph_segmentation/down_conv_2/conv2d/dropout/sub/x
# graph_segmentation/down_conv_2/conv2d/dropout/sub
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform/min
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform/max
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform/sub
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform/mul
# graph_segmentation/down_conv_2/conv2d/dropout/random_uniform
# graph_segmentation/down_conv_2/conv2d/dropout/add
# graph_segmentation/down_conv_2/conv2d/dropout/Floor
# graph_segmentation/down_conv_2/conv2d/dropout/div
# graph_segmentation/down_conv_2/conv2d/dropout/mul
# graph_segmentation/down_conv_2/Relu
# graph_segmentation/down_conv_2/conv2d_1/Conv2D
# graph_segmentation/down_conv_2/conv2d_1/BiasAdd
# graph_segmentation/down_conv_2/conv2d_1/dropout/rate
# graph_segmentation/down_conv_2/conv2d_1/dropout/Shape
# graph_segmentation/down_conv_2/conv2d_1/dropout/sub/x
# graph_segmentation/down_conv_2/conv2d_1/dropout/sub
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform/min
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform/max
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform/RandomUniform
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform/sub
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform/mul
# graph_segmentation/down_conv_2/conv2d_1/dropout/random_uniform
# graph_segmentation/down_conv_2/conv2d_1/dropout/add
# graph_segmentation/down_conv_2/conv2d_1/dropout/Floor
# graph_segmentation/down_conv_2/conv2d_1/dropout/div
# graph_segmentation/down_conv_2/conv2d_1/dropout/mul
# graph_segmentation/down_conv_2/Relu_1
# graph_segmentation/up_conv_1/truncated_normal/shape
# graph_segmentation/up_conv_1/truncated_normal/mean
# graph_segmentation/up_conv_1/truncated_normal/stddev
# graph_segmentation/up_conv_1/truncated_normal/TruncatedNormal
# graph_segmentation/up_conv_1/truncated_normal/mul
# graph_segmentation/up_conv_1/truncated_normal
# graph_segmentation/up_conv_1/wd
# graph_segmentation/up_conv_1/wd/Assign
# graph_segmentation/up_conv_1/wd/read
# graph_segmentation/up_conv_1/Const
# graph_segmentation/up_conv_1/bd
# graph_segmentation/up_conv_1/bd/Assign
# graph_segmentation/up_conv_1/bd/read
# graph_segmentation/up_conv_1/deconv2d/Shape
# graph_segmentation/up_conv_1/deconv2d/strided_slice/stack
# graph_segmentation/up_conv_1/deconv2d/strided_slice/stack_1
# graph_segmentation/up_conv_1/deconv2d/strided_slice/stack_2
# graph_segmentation/up_conv_1/deconv2d/strided_slice
# graph_segmentation/up_conv_1/deconv2d/strided_slice_1/stack
# graph_segmentation/up_conv_1/deconv2d/strided_slice_1/stack_1
# graph_segmentation/up_conv_1/deconv2d/strided_slice_1/stack_2
# graph_segmentation/up_conv_1/deconv2d/strided_slice_1
# graph_segmentation/up_conv_1/deconv2d/mul/y
# graph_segmentation/up_conv_1/deconv2d/mul
# graph_segmentation/up_conv_1/deconv2d/strided_slice_2/stack
# graph_segmentation/up_conv_1/deconv2d/strided_slice_2/stack_1
# graph_segmentation/up_conv_1/deconv2d/strided_slice_2/stack_2
# graph_segmentation/up_conv_1/deconv2d/strided_slice_2
# graph_segmentation/up_conv_1/deconv2d/mul_1/y
# graph_segmentation/up_conv_1/deconv2d/mul_1
# graph_segmentation/up_conv_1/deconv2d/strided_slice_3/stack
# graph_segmentation/up_conv_1/deconv2d/strided_slice_3/stack_1
# graph_segmentation/up_conv_1/deconv2d/strided_slice_3/stack_2
# graph_segmentation/up_conv_1/deconv2d/strided_slice_3
# graph_segmentation/up_conv_1/deconv2d/floordiv/y
# graph_segmentation/up_conv_1/deconv2d/floordiv
# graph_segmentation/up_conv_1/deconv2d/stack
# graph_segmentation/up_conv_1/deconv2d/conv2d_transpose
# graph_segmentation/up_conv_1/add
# graph_segmentation/up_conv_1/Relu
# graph_segmentation/up_conv_1/crop_and_concat/Shape
# graph_segmentation/up_conv_1/crop_and_concat/Shape_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_1/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_1/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_1/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_1
# graph_segmentation/up_conv_1/crop_and_concat/sub
# graph_segmentation/up_conv_1/crop_and_concat/floordiv/y
# graph_segmentation/up_conv_1/crop_and_concat/floordiv
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_2/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_2/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_2/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_3/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_3/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_3/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_3
# graph_segmentation/up_conv_1/crop_and_concat/sub_1
# graph_segmentation/up_conv_1/crop_and_concat/floordiv_1/y
# graph_segmentation/up_conv_1/crop_and_concat/floordiv_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_4/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_4/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_4/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_4
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_5/stack
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_5/stack_1
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_5/stack_2
# graph_segmentation/up_conv_1/crop_and_concat/strided_slice_5
# graph_segmentation/up_conv_1/crop_and_concat/Slice/begin/0
# graph_segmentation/up_conv_1/crop_and_concat/Slice/begin/3
# graph_segmentation/up_conv_1/crop_and_concat/Slice/begin
# graph_segmentation/up_conv_1/crop_and_concat/Slice/size/0
# graph_segmentation/up_conv_1/crop_and_concat/Slice/size/3
# graph_segmentation/up_conv_1/crop_and_concat/Slice/size
# graph_segmentation/up_conv_1/crop_and_concat/Slice
# graph_segmentation/up_conv_1/crop_and_concat/concat/axis
# graph_segmentation/up_conv_1/crop_and_concat/concat
# graph_segmentation/up_conv_1/truncated_normal_1/shape
# graph_segmentation/up_conv_1/truncated_normal_1/mean
# graph_segmentation/up_conv_1/truncated_normal_1/stddev
# graph_segmentation/up_conv_1/truncated_normal_1/TruncatedNormal
# graph_segmentation/up_conv_1/truncated_normal_1/mul
# graph_segmentation/up_conv_1/truncated_normal_1
# graph_segmentation/up_conv_1/w1
# graph_segmentation/up_conv_1/w1/Assign
# graph_segmentation/up_conv_1/w1/read
# graph_segmentation/up_conv_1/truncated_normal_2/shape
# graph_segmentation/up_conv_1/truncated_normal_2/mean
# graph_segmentation/up_conv_1/truncated_normal_2/stddev
# graph_segmentation/up_conv_1/truncated_normal_2/TruncatedNormal
# graph_segmentation/up_conv_1/truncated_normal_2/mul
# graph_segmentation/up_conv_1/truncated_normal_2
# graph_segmentation/up_conv_1/w2
# graph_segmentation/up_conv_1/w2/Assign
# graph_segmentation/up_conv_1/w2/read
# graph_segmentation/up_conv_1/Const_1
# graph_segmentation/up_conv_1/b1
# graph_segmentation/up_conv_1/b1/Assign
# graph_segmentation/up_conv_1/b1/read
# graph_segmentation/up_conv_1/Const_2
# graph_segmentation/up_conv_1/b2
# graph_segmentation/up_conv_1/b2/Assign
# graph_segmentation/up_conv_1/b2/read
# graph_segmentation/up_conv_1/conv2d/Conv2D
# graph_segmentation/up_conv_1/conv2d/BiasAdd
# graph_segmentation/up_conv_1/conv2d/dropout/rate
# graph_segmentation/up_conv_1/conv2d/dropout/Shape
# graph_segmentation/up_conv_1/conv2d/dropout/sub/x
# graph_segmentation/up_conv_1/conv2d/dropout/sub
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform/min
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform/max
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform/sub
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform/mul
# graph_segmentation/up_conv_1/conv2d/dropout/random_uniform
# graph_segmentation/up_conv_1/conv2d/dropout/add
# graph_segmentation/up_conv_1/conv2d/dropout/Floor
# graph_segmentation/up_conv_1/conv2d/dropout/div
# graph_segmentation/up_conv_1/conv2d/dropout/mul
# graph_segmentation/up_conv_1/Relu_1
# graph_segmentation/up_conv_1/conv2d_1/Conv2D
# graph_segmentation/up_conv_1/conv2d_1/BiasAdd
# graph_segmentation/up_conv_1/conv2d_1/dropout/rate
# graph_segmentation/up_conv_1/conv2d_1/dropout/Shape
# graph_segmentation/up_conv_1/conv2d_1/dropout/sub/x
# graph_segmentation/up_conv_1/conv2d_1/dropout/sub
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform/min
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform/max
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform/RandomUniform
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform/sub
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform/mul
# graph_segmentation/up_conv_1/conv2d_1/dropout/random_uniform
# graph_segmentation/up_conv_1/conv2d_1/dropout/add
# graph_segmentation/up_conv_1/conv2d_1/dropout/Floor
# graph_segmentation/up_conv_1/conv2d_1/dropout/div
# graph_segmentation/up_conv_1/conv2d_1/dropout/mul
# graph_segmentation/up_conv_1/Relu_2
# graph_segmentation/up_conv_0/truncated_normal/shape
# graph_segmentation/up_conv_0/truncated_normal/mean
# graph_segmentation/up_conv_0/truncated_normal/stddev
# graph_segmentation/up_conv_0/truncated_normal/TruncatedNormal
# graph_segmentation/up_conv_0/truncated_normal/mul
# graph_segmentation/up_conv_0/truncated_normal
# graph_segmentation/up_conv_0/wd
# graph_segmentation/up_conv_0/wd/Assign
# graph_segmentation/up_conv_0/wd/read
# graph_segmentation/up_conv_0/Const
# graph_segmentation/up_conv_0/bd
# graph_segmentation/up_conv_0/bd/Assign
# graph_segmentation/up_conv_0/bd/read
# graph_segmentation/up_conv_0/deconv2d/Shape
# graph_segmentation/up_conv_0/deconv2d/strided_slice/stack
# graph_segmentation/up_conv_0/deconv2d/strided_slice/stack_1
# graph_segmentation/up_conv_0/deconv2d/strided_slice/stack_2
# graph_segmentation/up_conv_0/deconv2d/strided_slice
# graph_segmentation/up_conv_0/deconv2d/strided_slice_1/stack
# graph_segmentation/up_conv_0/deconv2d/strided_slice_1/stack_1
# graph_segmentation/up_conv_0/deconv2d/strided_slice_1/stack_2
# graph_segmentation/up_conv_0/deconv2d/strided_slice_1
# graph_segmentation/up_conv_0/deconv2d/mul/y
# graph_segmentation/up_conv_0/deconv2d/mul
# graph_segmentation/up_conv_0/deconv2d/strided_slice_2/stack
# graph_segmentation/up_conv_0/deconv2d/strided_slice_2/stack_1
# graph_segmentation/up_conv_0/deconv2d/strided_slice_2/stack_2
# graph_segmentation/up_conv_0/deconv2d/strided_slice_2
# graph_segmentation/up_conv_0/deconv2d/mul_1/y
# graph_segmentation/up_conv_0/deconv2d/mul_1
# graph_segmentation/up_conv_0/deconv2d/strided_slice_3/stack
# graph_segmentation/up_conv_0/deconv2d/strided_slice_3/stack_1
# graph_segmentation/up_conv_0/deconv2d/strided_slice_3/stack_2
# graph_segmentation/up_conv_0/deconv2d/strided_slice_3
# graph_segmentation/up_conv_0/deconv2d/floordiv/y
# graph_segmentation/up_conv_0/deconv2d/floordiv
# graph_segmentation/up_conv_0/deconv2d/stack
# graph_segmentation/up_conv_0/deconv2d/conv2d_transpose
# graph_segmentation/up_conv_0/add
# graph_segmentation/up_conv_0/Relu
# graph_segmentation/up_conv_0/crop_and_concat/Shape
# graph_segmentation/up_conv_0/crop_and_concat/Shape_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_1/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_1/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_1/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_1
# graph_segmentation/up_conv_0/crop_and_concat/sub
# graph_segmentation/up_conv_0/crop_and_concat/floordiv/y
# graph_segmentation/up_conv_0/crop_and_concat/floordiv
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_2/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_2/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_2/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_3/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_3/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_3/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_3
# graph_segmentation/up_conv_0/crop_and_concat/sub_1
# graph_segmentation/up_conv_0/crop_and_concat/floordiv_1/y
# graph_segmentation/up_conv_0/crop_and_concat/floordiv_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_4/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_4/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_4/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_4
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_5/stack
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_5/stack_1
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_5/stack_2
# graph_segmentation/up_conv_0/crop_and_concat/strided_slice_5
# graph_segmentation/up_conv_0/crop_and_concat/Slice/begin/0
# graph_segmentation/up_conv_0/crop_and_concat/Slice/begin/3
# graph_segmentation/up_conv_0/crop_and_concat/Slice/begin
# graph_segmentation/up_conv_0/crop_and_concat/Slice/size/0
# graph_segmentation/up_conv_0/crop_and_concat/Slice/size/3
# graph_segmentation/up_conv_0/crop_and_concat/Slice/size
# graph_segmentation/up_conv_0/crop_and_concat/Slice
# graph_segmentation/up_conv_0/crop_and_concat/concat/axis
# graph_segmentation/up_conv_0/crop_and_concat/concat
# graph_segmentation/up_conv_0/truncated_normal_1/shape
# graph_segmentation/up_conv_0/truncated_normal_1/mean
# graph_segmentation/up_conv_0/truncated_normal_1/stddev
# graph_segmentation/up_conv_0/truncated_normal_1/TruncatedNormal
# graph_segmentation/up_conv_0/truncated_normal_1/mul
# graph_segmentation/up_conv_0/truncated_normal_1
# graph_segmentation/up_conv_0/w1
# graph_segmentation/up_conv_0/w1/Assign
# graph_segmentation/up_conv_0/w1/read
# graph_segmentation/up_conv_0/truncated_normal_2/shape
# graph_segmentation/up_conv_0/truncated_normal_2/mean
# graph_segmentation/up_conv_0/truncated_normal_2/stddev
# graph_segmentation/up_conv_0/truncated_normal_2/TruncatedNormal
# graph_segmentation/up_conv_0/truncated_normal_2/mul
# graph_segmentation/up_conv_0/truncated_normal_2
# graph_segmentation/up_conv_0/w2
# graph_segmentation/up_conv_0/w2/Assign
# graph_segmentation/up_conv_0/w2/read
# graph_segmentation/up_conv_0/Const_1
# graph_segmentation/up_conv_0/b1
# graph_segmentation/up_conv_0/b1/Assign
# graph_segmentation/up_conv_0/b1/read
# graph_segmentation/up_conv_0/Const_2
# graph_segmentation/up_conv_0/b2
# graph_segmentation/up_conv_0/b2/Assign
# graph_segmentation/up_conv_0/b2/read
# graph_segmentation/up_conv_0/conv2d/Conv2D
# graph_segmentation/up_conv_0/conv2d/BiasAdd
# graph_segmentation/up_conv_0/conv2d/dropout/rate
# graph_segmentation/up_conv_0/conv2d/dropout/Shape
# graph_segmentation/up_conv_0/conv2d/dropout/sub/x
# graph_segmentation/up_conv_0/conv2d/dropout/sub
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform/min
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform/max
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform/sub
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform/mul
# graph_segmentation/up_conv_0/conv2d/dropout/random_uniform
# graph_segmentation/up_conv_0/conv2d/dropout/add
# graph_segmentation/up_conv_0/conv2d/dropout/Floor
# graph_segmentation/up_conv_0/conv2d/dropout/div
# graph_segmentation/up_conv_0/conv2d/dropout/mul
# graph_segmentation/up_conv_0/Relu_1
# graph_segmentation/up_conv_0/conv2d_1/Conv2D
# graph_segmentation/up_conv_0/conv2d_1/BiasAdd
# graph_segmentation/up_conv_0/conv2d_1/dropout/rate
# graph_segmentation/up_conv_0/conv2d_1/dropout/Shape
# graph_segmentation/up_conv_0/conv2d_1/dropout/sub/x
# graph_segmentation/up_conv_0/conv2d_1/dropout/sub
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform/min
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform/max
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform/RandomUniform
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform/sub
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform/mul
# graph_segmentation/up_conv_0/conv2d_1/dropout/random_uniform
# graph_segmentation/up_conv_0/conv2d_1/dropout/add
# graph_segmentation/up_conv_0/conv2d_1/dropout/Floor
# graph_segmentation/up_conv_0/conv2d_1/dropout/div
# graph_segmentation/up_conv_0/conv2d_1/dropout/mul
# graph_segmentation/up_conv_0/Relu_2
# graph_segmentation/output_map/truncated_normal/shape
# graph_segmentation/output_map/truncated_normal/mean
# graph_segmentation/output_map/truncated_normal/stddev
# graph_segmentation/output_map/truncated_normal/TruncatedNormal
# graph_segmentation/output_map/truncated_normal/mul
# graph_segmentation/output_map/truncated_normal
# graph_segmentation/output_map/weight
# graph_segmentation/output_map/weight/Assign
# graph_segmentation/output_map/weight/read
# graph_segmentation/output_map/Const
# graph_segmentation/output_map/bias
# graph_segmentation/output_map/bias/Assign
# graph_segmentation/output_map/bias/read
# graph_segmentation/output_map/Const_1
# graph_segmentation/output_map/conv2d/Conv2D
# graph_segmentation/output_map/conv2d/BiasAdd
# graph_segmentation/output_map/conv2d/sub/x
# graph_segmentation/output_map/conv2d/sub
# graph_segmentation/output_map/conv2d/dropout/Shape
# graph_segmentation/output_map/conv2d/dropout/sub/x
# graph_segmentation/output_map/conv2d/dropout/sub
# graph_segmentation/output_map/conv2d/dropout/random_uniform/min
# graph_segmentation/output_map/conv2d/dropout/random_uniform/max
# graph_segmentation/output_map/conv2d/dropout/random_uniform/RandomUniform
# graph_segmentation/output_map/conv2d/dropout/random_uniform/sub
# graph_segmentation/output_map/conv2d/dropout/random_uniform/mul
# graph_segmentation/output_map/conv2d/dropout/random_uniform
# graph_segmentation/output_map/conv2d/dropout/add
# graph_segmentation/output_map/conv2d/dropout/Floor
# graph_segmentation/output_map/conv2d/dropout/div
# graph_segmentation/output_map/conv2d/dropout/mul
# graph_segmentation/summaries/Slice/begin
# graph_segmentation/summaries/Slice/size
# graph_segmentation/summaries/Slice
# graph_segmentation/summaries/Const
# graph_segmentation/summaries/Min
# graph_segmentation/summaries/sub
# graph_segmentation/summaries/Const_1
# graph_segmentation/summaries/Max
# graph_segmentation/summaries/truediv
# graph_segmentation/summaries/mul/y
# graph_segmentation/summaries/mul
# graph_segmentation/summaries/Shape
# graph_segmentation/summaries/strided_slice/stack
# graph_segmentation/summaries/strided_slice/stack_1
# graph_segmentation/summaries/strided_slice/stack_2
# graph_segmentation/summaries/strided_slice
# graph_segmentation/summaries/Shape_1
# graph_segmentation/summaries/strided_slice_1/stack
# graph_segmentation/summaries/strided_slice_1/stack_1
# graph_segmentation/summaries/strided_slice_1/stack_2
# graph_segmentation/summaries/strided_slice_1
# graph_segmentation/summaries/stack/2
# graph_segmentation/summaries/stack
# graph_segmentation/summaries/Reshape
# graph_segmentation/summaries/transpose/perm
# graph_segmentation/summaries/transpose
# graph_segmentation/summaries/stack_1/0
# graph_segmentation/summaries/stack_1/3
# graph_segmentation/summaries/stack_1
# graph_segmentation/summaries/Reshape_1
# graph_segmentation/summaries/summary_conv_00_01/tag
# graph_segmentation/summaries/summary_conv_00_01
# graph_segmentation/summaries/Slice_1/begin
# graph_segmentation/summaries/Slice_1/size
# graph_segmentation/summaries/Slice_1
# graph_segmentation/summaries/Const_2
# graph_segmentation/summaries/Min_1
# graph_segmentation/summaries/sub_1
# graph_segmentation/summaries/Const_3
# graph_segmentation/summaries/Max_1
# graph_segmentation/summaries/truediv_1
# graph_segmentation/summaries/mul_1/y
# graph_segmentation/summaries/mul_1
# graph_segmentation/summaries/Shape_2
# graph_segmentation/summaries/strided_slice_2/stack
# graph_segmentation/summaries/strided_slice_2/stack_1
# graph_segmentation/summaries/strided_slice_2/stack_2
# graph_segmentation/summaries/strided_slice_2
# graph_segmentation/summaries/Shape_3
# graph_segmentation/summaries/strided_slice_3/stack
# graph_segmentation/summaries/strided_slice_3/stack_1
# graph_segmentation/summaries/strided_slice_3/stack_2
# graph_segmentation/summaries/strided_slice_3
# graph_segmentation/summaries/stack_2/2
# graph_segmentation/summaries/stack_2
# graph_segmentation/summaries/Reshape_2
# graph_segmentation/summaries/transpose_1/perm
# graph_segmentation/summaries/transpose_1
# graph_segmentation/summaries/stack_3/0
# graph_segmentation/summaries/stack_3/3
# graph_segmentation/summaries/stack_3
# graph_segmentation/summaries/Reshape_3
# graph_segmentation/summaries/summary_conv_00_02/tag
# graph_segmentation/summaries/summary_conv_00_02
# graph_segmentation/summaries/Slice_2/begin
# graph_segmentation/summaries/Slice_2/size
# graph_segmentation/summaries/Slice_2
# graph_segmentation/summaries/Const_4
# graph_segmentation/summaries/Min_2
# graph_segmentation/summaries/sub_2
# graph_segmentation/summaries/Const_5
# graph_segmentation/summaries/Max_2
# graph_segmentation/summaries/truediv_2
# graph_segmentation/summaries/mul_2/y
# graph_segmentation/summaries/mul_2
# graph_segmentation/summaries/Shape_4
# graph_segmentation/summaries/strided_slice_4/stack
# graph_segmentation/summaries/strided_slice_4/stack_1
# graph_segmentation/summaries/strided_slice_4/stack_2
# graph_segmentation/summaries/strided_slice_4
# graph_segmentation/summaries/Shape_5
# graph_segmentation/summaries/strided_slice_5/stack
# graph_segmentation/summaries/strided_slice_5/stack_1
# graph_segmentation/summaries/strided_slice_5/stack_2
# graph_segmentation/summaries/strided_slice_5
# graph_segmentation/summaries/stack_4/2
# graph_segmentation/summaries/stack_4
# graph_segmentation/summaries/Reshape_4
# graph_segmentation/summaries/transpose_2/perm
# graph_segmentation/summaries/transpose_2
# graph_segmentation/summaries/stack_5/0
# graph_segmentation/summaries/stack_5/3
# graph_segmentation/summaries/stack_5
# graph_segmentation/summaries/Reshape_5
# graph_segmentation/summaries/summary_conv_01_01/tag
# graph_segmentation/summaries/summary_conv_01_01
# graph_segmentation/summaries/Slice_3/begin
# graph_segmentation/summaries/Slice_3/size
# graph_segmentation/summaries/Slice_3
# graph_segmentation/summaries/Const_6
# graph_segmentation/summaries/Min_3
# graph_segmentation/summaries/sub_3
# graph_segmentation/summaries/Const_7
# graph_segmentation/summaries/Max_3
# graph_segmentation/summaries/truediv_3
# graph_segmentation/summaries/mul_3/y
# graph_segmentation/summaries/mul_3
# graph_segmentation/summaries/Shape_6
# graph_segmentation/summaries/strided_slice_6/stack
# graph_segmentation/summaries/strided_slice_6/stack_1
# graph_segmentation/summaries/strided_slice_6/stack_2
# graph_segmentation/summaries/strided_slice_6
# graph_segmentation/summaries/Shape_7
# graph_segmentation/summaries/strided_slice_7/stack
# graph_segmentation/summaries/strided_slice_7/stack_1
# graph_segmentation/summaries/strided_slice_7/stack_2
# graph_segmentation/summaries/strided_slice_7
# graph_segmentation/summaries/stack_6/2
# graph_segmentation/summaries/stack_6
# graph_segmentation/summaries/Reshape_6
# graph_segmentation/summaries/transpose_3/perm
# graph_segmentation/summaries/transpose_3
# graph_segmentation/summaries/stack_7/0
# graph_segmentation/summaries/stack_7/3
# graph_segmentation/summaries/stack_7
# graph_segmentation/summaries/Reshape_7
# graph_segmentation/summaries/summary_conv_01_02/tag
# graph_segmentation/summaries/summary_conv_01_02
# graph_segmentation/summaries/Slice_4/begin
# graph_segmentation/summaries/Slice_4/size
# graph_segmentation/summaries/Slice_4
# graph_segmentation/summaries/Const_8
# graph_segmentation/summaries/Min_4
# graph_segmentation/summaries/sub_4
# graph_segmentation/summaries/Const_9
# graph_segmentation/summaries/Max_4
# graph_segmentation/summaries/truediv_4
# graph_segmentation/summaries/mul_4/y
# graph_segmentation/summaries/mul_4
# graph_segmentation/summaries/Shape_8
# graph_segmentation/summaries/strided_slice_8/stack
# graph_segmentation/summaries/strided_slice_8/stack_1
# graph_segmentation/summaries/strided_slice_8/stack_2
# graph_segmentation/summaries/strided_slice_8
# graph_segmentation/summaries/Shape_9
# graph_segmentation/summaries/strided_slice_9/stack
# graph_segmentation/summaries/strided_slice_9/stack_1
# graph_segmentation/summaries/strided_slice_9/stack_2
# graph_segmentation/summaries/strided_slice_9
# graph_segmentation/summaries/stack_8/2
# graph_segmentation/summaries/stack_8
# graph_segmentation/summaries/Reshape_8
# graph_segmentation/summaries/transpose_4/perm
# graph_segmentation/summaries/transpose_4
# graph_segmentation/summaries/stack_9/0
# graph_segmentation/summaries/stack_9/3
# graph_segmentation/summaries/stack_9
# graph_segmentation/summaries/Reshape_9
# graph_segmentation/summaries/summary_conv_02_01/tag
# graph_segmentation/summaries/summary_conv_02_01
# graph_segmentation/summaries/Slice_5/begin
# graph_segmentation/summaries/Slice_5/size
# graph_segmentation/summaries/Slice_5
# graph_segmentation/summaries/Const_10
# graph_segmentation/summaries/Min_5
# graph_segmentation/summaries/sub_5
# graph_segmentation/summaries/Const_11
# graph_segmentation/summaries/Max_5
# graph_segmentation/summaries/truediv_5
# graph_segmentation/summaries/mul_5/y
# graph_segmentation/summaries/mul_5
# graph_segmentation/summaries/Shape_10
# graph_segmentation/summaries/strided_slice_10/stack
# graph_segmentation/summaries/strided_slice_10/stack_1
# graph_segmentation/summaries/strided_slice_10/stack_2
# graph_segmentation/summaries/strided_slice_10
# graph_segmentation/summaries/Shape_11
# graph_segmentation/summaries/strided_slice_11/stack
# graph_segmentation/summaries/strided_slice_11/stack_1
# graph_segmentation/summaries/strided_slice_11/stack_2
# graph_segmentation/summaries/strided_slice_11
# graph_segmentation/summaries/stack_10/2
# graph_segmentation/summaries/stack_10
# graph_segmentation/summaries/Reshape_10
# graph_segmentation/summaries/transpose_5/perm
# graph_segmentation/summaries/transpose_5
# graph_segmentation/summaries/stack_11/0
# graph_segmentation/summaries/stack_11/3
# graph_segmentation/summaries/stack_11
# graph_segmentation/summaries/Reshape_11
# graph_segmentation/summaries/summary_conv_02_02/tag
# graph_segmentation/summaries/summary_conv_02_02
# graph_segmentation/summaries/Slice_6/begin
# graph_segmentation/summaries/Slice_6/size
# graph_segmentation/summaries/Slice_6
# graph_segmentation/summaries/Const_12
# graph_segmentation/summaries/Min_6
# graph_segmentation/summaries/sub_6
# graph_segmentation/summaries/Const_13
# graph_segmentation/summaries/Max_6
# graph_segmentation/summaries/truediv_6
# graph_segmentation/summaries/mul_6/y
# graph_segmentation/summaries/mul_6
# graph_segmentation/summaries/Shape_12
# graph_segmentation/summaries/strided_slice_12/stack
# graph_segmentation/summaries/strided_slice_12/stack_1
# graph_segmentation/summaries/strided_slice_12/stack_2
# graph_segmentation/summaries/strided_slice_12
# graph_segmentation/summaries/Shape_13
# graph_segmentation/summaries/strided_slice_13/stack
# graph_segmentation/summaries/strided_slice_13/stack_1
# graph_segmentation/summaries/strided_slice_13/stack_2
# graph_segmentation/summaries/strided_slice_13
# graph_segmentation/summaries/stack_12/2
# graph_segmentation/summaries/stack_12
# graph_segmentation/summaries/Reshape_12
# graph_segmentation/summaries/transpose_6/perm
# graph_segmentation/summaries/transpose_6
# graph_segmentation/summaries/stack_13/0
# graph_segmentation/summaries/stack_13/3
# graph_segmentation/summaries/stack_13
# graph_segmentation/summaries/Reshape_13
# graph_segmentation/summaries/summary_conv_03_01/tag
# graph_segmentation/summaries/summary_conv_03_01
# graph_segmentation/summaries/Slice_7/begin
# graph_segmentation/summaries/Slice_7/size
# graph_segmentation/summaries/Slice_7
# graph_segmentation/summaries/Const_14
# graph_segmentation/summaries/Min_7
# graph_segmentation/summaries/sub_7
# graph_segmentation/summaries/Const_15
# graph_segmentation/summaries/Max_7
# graph_segmentation/summaries/truediv_7
# graph_segmentation/summaries/mul_7/y
# graph_segmentation/summaries/mul_7
# graph_segmentation/summaries/Shape_14
# graph_segmentation/summaries/strided_slice_14/stack
# graph_segmentation/summaries/strided_slice_14/stack_1
# graph_segmentation/summaries/strided_slice_14/stack_2
# graph_segmentation/summaries/strided_slice_14
# graph_segmentation/summaries/Shape_15
# graph_segmentation/summaries/strided_slice_15/stack
# graph_segmentation/summaries/strided_slice_15/stack_1
# graph_segmentation/summaries/strided_slice_15/stack_2
# graph_segmentation/summaries/strided_slice_15
# graph_segmentation/summaries/stack_14/2
# graph_segmentation/summaries/stack_14
# graph_segmentation/summaries/Reshape_14
# graph_segmentation/summaries/transpose_7/perm
# graph_segmentation/summaries/transpose_7
# graph_segmentation/summaries/stack_15/0
# graph_segmentation/summaries/stack_15/3
# graph_segmentation/summaries/stack_15
# graph_segmentation/summaries/Reshape_15
# graph_segmentation/summaries/summary_conv_03_02/tag
# graph_segmentation/summaries/summary_conv_03_02
# graph_segmentation/summaries/Slice_8/begin
# graph_segmentation/summaries/Slice_8/size
# graph_segmentation/summaries/Slice_8
# graph_segmentation/summaries/Const_16
# graph_segmentation/summaries/Min_8
# graph_segmentation/summaries/sub_8
# graph_segmentation/summaries/Const_17
# graph_segmentation/summaries/Max_8
# graph_segmentation/summaries/truediv_8
# graph_segmentation/summaries/mul_8/y
# graph_segmentation/summaries/mul_8
# graph_segmentation/summaries/Shape_16
# graph_segmentation/summaries/strided_slice_16/stack
# graph_segmentation/summaries/strided_slice_16/stack_1
# graph_segmentation/summaries/strided_slice_16/stack_2
# graph_segmentation/summaries/strided_slice_16
# graph_segmentation/summaries/Shape_17
# graph_segmentation/summaries/strided_slice_17/stack
# graph_segmentation/summaries/strided_slice_17/stack_1
# graph_segmentation/summaries/strided_slice_17/stack_2
# graph_segmentation/summaries/strided_slice_17
# graph_segmentation/summaries/stack_16/2
# graph_segmentation/summaries/stack_16
# graph_segmentation/summaries/Reshape_16
# graph_segmentation/summaries/transpose_8/perm
# graph_segmentation/summaries/transpose_8
# graph_segmentation/summaries/stack_17/0
# graph_segmentation/summaries/stack_17/3
# graph_segmentation/summaries/stack_17
# graph_segmentation/summaries/Reshape_17
# graph_segmentation/summaries/summary_conv_04_01/tag
# graph_segmentation/summaries/summary_conv_04_01
# graph_segmentation/summaries/Slice_9/begin
# graph_segmentation/summaries/Slice_9/size
# graph_segmentation/summaries/Slice_9
# graph_segmentation/summaries/Const_18
# graph_segmentation/summaries/Min_9
# graph_segmentation/summaries/sub_9
# graph_segmentation/summaries/Const_19
# graph_segmentation/summaries/Max_9
# graph_segmentation/summaries/truediv_9
# graph_segmentation/summaries/mul_9/y
# graph_segmentation/summaries/mul_9
# graph_segmentation/summaries/Shape_18
# graph_segmentation/summaries/strided_slice_18/stack
# graph_segmentation/summaries/strided_slice_18/stack_1
# graph_segmentation/summaries/strided_slice_18/stack_2
# graph_segmentation/summaries/strided_slice_18
# graph_segmentation/summaries/Shape_19
# graph_segmentation/summaries/strided_slice_19/stack
# graph_segmentation/summaries/strided_slice_19/stack_1
# graph_segmentation/summaries/strided_slice_19/stack_2
# graph_segmentation/summaries/strided_slice_19
# graph_segmentation/summaries/stack_18/2
# graph_segmentation/summaries/stack_18
# graph_segmentation/summaries/Reshape_18
# graph_segmentation/summaries/transpose_9/perm
# graph_segmentation/summaries/transpose_9
# graph_segmentation/summaries/stack_19/0
# graph_segmentation/summaries/stack_19/3
# graph_segmentation/summaries/stack_19
# graph_segmentation/summaries/Reshape_19
# graph_segmentation/summaries/summary_conv_04_02/tag
# graph_segmentation/summaries/summary_conv_04_02
# graph_segmentation/summaries/Slice_10/begin
# graph_segmentation/summaries/Slice_10/size
# graph_segmentation/summaries/Slice_10
# graph_segmentation/summaries/Const_20
# graph_segmentation/summaries/Min_10
# graph_segmentation/summaries/sub_10
# graph_segmentation/summaries/Const_21
# graph_segmentation/summaries/Max_10
# graph_segmentation/summaries/truediv_10
# graph_segmentation/summaries/mul_10/y
# graph_segmentation/summaries/mul_10
# graph_segmentation/summaries/Shape_20
# graph_segmentation/summaries/strided_slice_20/stack
# graph_segmentation/summaries/strided_slice_20/stack_1
# graph_segmentation/summaries/strided_slice_20/stack_2
# graph_segmentation/summaries/strided_slice_20
# graph_segmentation/summaries/Shape_21
# graph_segmentation/summaries/strided_slice_21/stack
# graph_segmentation/summaries/strided_slice_21/stack_1
# graph_segmentation/summaries/strided_slice_21/stack_2
# graph_segmentation/summaries/strided_slice_21
# graph_segmentation/summaries/stack_20/2
# graph_segmentation/summaries/stack_20
# graph_segmentation/summaries/Reshape_20
# graph_segmentation/summaries/transpose_10/perm
# graph_segmentation/summaries/transpose_10
# graph_segmentation/summaries/stack_21/0
# graph_segmentation/summaries/stack_21/3
# graph_segmentation/summaries/stack_21
# graph_segmentation/summaries/Reshape_21
# graph_segmentation/summaries/summary_pool_00/tag
# graph_segmentation/summaries/summary_pool_00
# graph_segmentation/summaries/Slice_11/begin
# graph_segmentation/summaries/Slice_11/size
# graph_segmentation/summaries/Slice_11
# graph_segmentation/summaries/Const_22
# graph_segmentation/summaries/Min_11
# graph_segmentation/summaries/sub_11
# graph_segmentation/summaries/Const_23
# graph_segmentation/summaries/Max_11
# graph_segmentation/summaries/truediv_11
# graph_segmentation/summaries/mul_11/y
# graph_segmentation/summaries/mul_11
# graph_segmentation/summaries/Shape_22
# graph_segmentation/summaries/strided_slice_22/stack
# graph_segmentation/summaries/strided_slice_22/stack_1
# graph_segmentation/summaries/strided_slice_22/stack_2
# graph_segmentation/summaries/strided_slice_22
# graph_segmentation/summaries/Shape_23
# graph_segmentation/summaries/strided_slice_23/stack
# graph_segmentation/summaries/strided_slice_23/stack_1
# graph_segmentation/summaries/strided_slice_23/stack_2
# graph_segmentation/summaries/strided_slice_23
# graph_segmentation/summaries/stack_22/2
# graph_segmentation/summaries/stack_22
# graph_segmentation/summaries/Reshape_22
# graph_segmentation/summaries/transpose_11/perm
# graph_segmentation/summaries/transpose_11
# graph_segmentation/summaries/stack_23/0
# graph_segmentation/summaries/stack_23/3
# graph_segmentation/summaries/stack_23
# graph_segmentation/summaries/Reshape_23
# graph_segmentation/summaries/summary_pool_01/tag
# graph_segmentation/summaries/summary_pool_01
# graph_segmentation/summaries/Slice_12/begin
# graph_segmentation/summaries/Slice_12/size
# graph_segmentation/summaries/Slice_12
# graph_segmentation/summaries/Const_24
# graph_segmentation/summaries/Min_12
# graph_segmentation/summaries/sub_12
# graph_segmentation/summaries/Const_25
# graph_segmentation/summaries/Max_12
# graph_segmentation/summaries/truediv_12
# graph_segmentation/summaries/mul_12/y
# graph_segmentation/summaries/mul_12
# graph_segmentation/summaries/Shape_24
# graph_segmentation/summaries/strided_slice_24/stack
# graph_segmentation/summaries/strided_slice_24/stack_1
# graph_segmentation/summaries/strided_slice_24/stack_2
# graph_segmentation/summaries/strided_slice_24
# graph_segmentation/summaries/Shape_25
# graph_segmentation/summaries/strided_slice_25/stack
# graph_segmentation/summaries/strided_slice_25/stack_1
# graph_segmentation/summaries/strided_slice_25/stack_2
# graph_segmentation/summaries/strided_slice_25
# graph_segmentation/summaries/stack_24/2
# graph_segmentation/summaries/stack_24
# graph_segmentation/summaries/Reshape_24
# graph_segmentation/summaries/transpose_12/perm
# graph_segmentation/summaries/transpose_12
# graph_segmentation/summaries/stack_25/0
# graph_segmentation/summaries/stack_25/3
# graph_segmentation/summaries/stack_25
# graph_segmentation/summaries/Reshape_25
# graph_segmentation/summaries/summary_deconv_concat_01/tag
# graph_segmentation/summaries/summary_deconv_concat_01
# graph_segmentation/summaries/Slice_13/begin
# graph_segmentation/summaries/Slice_13/size
# graph_segmentation/summaries/Slice_13
# graph_segmentation/summaries/Const_26
# graph_segmentation/summaries/Min_13
# graph_segmentation/summaries/sub_13
# graph_segmentation/summaries/Const_27
# graph_segmentation/summaries/Max_13
# graph_segmentation/summaries/truediv_13
# graph_segmentation/summaries/mul_13/y
# graph_segmentation/summaries/mul_13
# graph_segmentation/summaries/Shape_26
# graph_segmentation/summaries/strided_slice_26/stack
# graph_segmentation/summaries/strided_slice_26/stack_1
# graph_segmentation/summaries/strided_slice_26/stack_2
# graph_segmentation/summaries/strided_slice_26
# graph_segmentation/summaries/Shape_27
# graph_segmentation/summaries/strided_slice_27/stack
# graph_segmentation/summaries/strided_slice_27/stack_1
# graph_segmentation/summaries/strided_slice_27/stack_2
# graph_segmentation/summaries/strided_slice_27
# graph_segmentation/summaries/stack_26/2
# graph_segmentation/summaries/stack_26
# graph_segmentation/summaries/Reshape_26
# graph_segmentation/summaries/transpose_13/perm
# graph_segmentation/summaries/transpose_13
# graph_segmentation/summaries/stack_27/0
# graph_segmentation/summaries/stack_27/3
# graph_segmentation/summaries/stack_27
# graph_segmentation/summaries/Reshape_27
# graph_segmentation/summaries/summary_deconv_concat_00/tag
# graph_segmentation/summaries/summary_deconv_concat_00
# graph_segmentation/summaries/dw_convolution_00/activations/tag
# graph_segmentation/summaries/dw_convolution_00/activations
# graph_segmentation/summaries/dw_convolution_01/activations/tag
# graph_segmentation/summaries/dw_convolution_01/activations
# graph_segmentation/summaries/dw_convolution_02/activations/tag
# graph_segmentation/summaries/dw_convolution_02/activations
# graph_segmentation/summaries/up_convolution_1/activations/tag
# graph_segmentation/summaries/up_convolution_1/activations
# graph_segmentation/summaries/up_convolution_0/activations/tag
# graph_segmentation/summaries/up_convolution_0/activations
# graph_segmentation/summaries/up_convolution_out/activations/tag
# graph_segmentation/summaries/up_convolution_out/activations
# graph_segmentation/Cast
# graph_segmentation/loss/Reshape/shape
# graph_segmentation/loss/Reshape
# graph_segmentation/loss/Const
# graph_segmentation/loss/add
# graph_segmentation/loss/Reshape_1/shape
# graph_segmentation/loss/Reshape_1
# graph_segmentation/loss/one_hot/on_value
# graph_segmentation/loss/one_hot/off_value
# graph_segmentation/loss/one_hot/depth
# graph_segmentation/loss/one_hot
# graph_segmentation/loss/Reshape_2/shape
# graph_segmentation/loss/Reshape_2
# graph_segmentation/loss/Softmax
# graph_segmentation/loss/add_1
# graph_segmentation/loss/Log
# graph_segmentation/loss/mul
# graph_segmentation/loss/Mul_1/y
# graph_segmentation/loss/Mul_1
# graph_segmentation/loss/Sum/reduction_indices
# graph_segmentation/loss/Sum
# graph_segmentation/loss/Neg
# graph_segmentation/loss/Const_1
# graph_segmentation/loss/cross_entropy
# graph_segmentation/loss/total_loss_seg
# graph_segmentation/ArgMax/dimension
# graph_segmentation/ArgMax
# graph_segmentation/Squeeze
# graph_segmentation/ToFloat
# graph_segmentation/sub/x
# graph_segmentation/sub
# graph_segmentation/mul
# graph_segmentation/add
# graph_recognition/transpose/perm
# graph_recognition/transpose
# graph_recognition/Placeholder
# graph_recognition/ExpandDims/dim
# graph_recognition/ExpandDims
# graph_recognition/Placeholder_1
# Initial_convolution/kernel/Initializer/truncated_normal/shape
# ...
# ExponentialMovingAverage/AssignMovingAvg_11/sub_1
# ExponentialMovingAverage/AssignMovingAvg_11/mul
# ExponentialMovingAverage/AssignMovingAvg_11
# ExponentialMovingAverage/AssignMovingAvg_12/sub/x
# ExponentialMovingAverage/AssignMovingAvg_12/sub
# ExponentialMovingAverage/AssignMovingAvg_12/sub_1
# ExponentialMovingAverage/AssignMovingAvg_12/mul
# ExponentialMovingAverage/AssignMovingAvg_12
# ExponentialMovingAverage/AssignMovingAvg_13/sub/x
# ExponentialMovingAverage/AssignMovingAvg_13/sub
# ExponentialMovingAverage/AssignMovingAvg_13/sub_1
# ExponentialMovingAverage/AssignMovingAvg_13/mul
# ExponentialMovingAverage/AssignMovingAvg_13
# ExponentialMovingAverage/AssignMovingAvg_14/sub/x
# ExponentialMovingAverage/AssignMovingAvg_14/sub
# ExponentialMovingAverage/AssignMovingAvg_14/sub_1
# ExponentialMovingAverage/AssignMovingAvg_14/mul
# ExponentialMovingAverage/AssignMovingAvg_14
# ExponentialMovingAverage/AssignMovingAvg_15/sub/x
# ExponentialMovingAverage/AssignMovingAvg_15/sub
# ExponentialMovingAverage/AssignMovingAvg_15/sub_1
# ExponentialMovingAverage/AssignMovingAvg_15/mul
# ExponentialMovingAverage/AssignMovingAvg_15
# ExponentialMovingAverage/AssignMovingAvg_16/sub/x
# ExponentialMovingAverage/AssignMovingAvg_16/sub
# ExponentialMovingAverage/AssignMovingAvg_16/sub_1
# ExponentialMovingAverage/AssignMovingAvg_16/mul
# ExponentialMovingAverage/AssignMovingAvg_16
# ExponentialMovingAverage/AssignMovingAvg_17/sub/x
# ExponentialMovingAverage/AssignMovingAvg_17/sub
# ExponentialMovingAverage/AssignMovingAvg_17/sub_1
# ExponentialMovingAverage/AssignMovingAvg_17/mul
# ExponentialMovingAverage/AssignMovingAvg_17
# ExponentialMovingAverage/AssignMovingAvg_18/sub/x
# ExponentialMovingAverage/AssignMovingAvg_18/sub
# ExponentialMovingAverage/AssignMovingAvg_18/sub_1
# ExponentialMovingAverage/AssignMovingAvg_18/mul
# ExponentialMovingAverage/AssignMovingAvg_18
# ExponentialMovingAverage/AssignMovingAvg_19/sub/x
# ExponentialMovingAverage/AssignMovingAvg_19/sub
# ExponentialMovingAverage/AssignMovingAvg_19/sub_1
# ExponentialMovingAverage/AssignMovingAvg_19/mul
# ExponentialMovingAverage/AssignMovingAvg_19
# ExponentialMovingAverage/AssignMovingAvg_20/sub/x
# ExponentialMovingAverage/AssignMovingAvg_20/sub
# ExponentialMovingAverage/AssignMovingAvg_20/sub_1
# ExponentialMovingAverage/AssignMovingAvg_20/mul
# ExponentialMovingAverage/AssignMovingAvg_20
# ExponentialMovingAverage/AssignMovingAvg_21/sub/x
# ExponentialMovingAverage/AssignMovingAvg_21/sub
# ExponentialMovingAverage/AssignMovingAvg_21/sub_1
# ExponentialMovingAverage/AssignMovingAvg_21/mul
# ExponentialMovingAverage/AssignMovingAvg_21
# ExponentialMovingAverage/AssignMovingAvg_22/sub/x
# ExponentialMovingAverage/AssignMovingAvg_22/sub
# ExponentialMovingAverage/AssignMovingAvg_22/sub_1
# ExponentialMovingAverage/AssignMovingAvg_22/mul
# ExponentialMovingAverage/AssignMovingAvg_22
# ExponentialMovingAverage/AssignMovingAvg_23/sub/x
# ExponentialMovingAverage/AssignMovingAvg_23/sub
# ExponentialMovingAverage/AssignMovingAvg_23/sub_1
# ExponentialMovingAverage/AssignMovingAvg_23/mul
# ExponentialMovingAverage/AssignMovingAvg_23
# ExponentialMovingAverage/AssignMovingAvg_24/sub/x
# ExponentialMovingAverage/AssignMovingAvg_24/sub
# ExponentialMovingAverage/AssignMovingAvg_24/sub_1
# ExponentialMovingAverage/AssignMovingAvg_24/mul
# ExponentialMovingAverage/AssignMovingAvg_24
# ExponentialMovingAverage/AssignMovingAvg_25/sub/x
# ExponentialMovingAverage/AssignMovingAvg_25/sub
# ExponentialMovingAverage/AssignMovingAvg_25/sub_1
# ExponentialMovingAverage/AssignMovingAvg_25/mul
# ExponentialMovingAverage/AssignMovingAvg_25
# ExponentialMovingAverage
# train_op_seg_prepare
# gradients_2/Shape
# gradients_2/grad_ys_0
# gradients_2/Fill
# gradients_2/graph_recognition/add_grad/tuple/group_deps
# gradients_2/graph_recognition/add_grad/tuple/control_dependency
# gradients_2/graph_recognition/add_grad/tuple/control_dependency_1
# gradients_2/graph_recognition/Mean_grad/Reshape/shape
# gradients_2/graph_recognition/Mean_grad/Reshape
# gradients_2/graph_recognition/Mean_grad/Shape
# gradients_2/graph_recognition/Mean_grad/Tile
# gradients_2/graph_recognition/Mean_grad/Shape_1
# gradients_2/graph_recognition/Mean_grad/Shape_2
# gradients_2/graph_recognition/Mean_grad/Const
# gradients_2/graph_recognition/Mean_grad/Prod
# gradients_2/graph_recognition/Mean_grad/Const_1
# gradients_2/graph_recognition/Mean_grad/Prod_1
# gradients_2/graph_recognition/Mean_grad/Maximum/y
# gradients_2/graph_recognition/Mean_grad/Maximum
# gradients_2/graph_recognition/Mean_grad/floordiv
# gradients_2/graph_recognition/Mean_grad/Cast
# gradients_2/graph_recognition/Mean_grad/truediv
# gradients_2/graph_recognition/mul_grad/Mul
# gradients_2/graph_recognition/mul_grad/Mul_1
# gradients_2/graph_recognition/mul_grad/tuple/group_deps
# gradients_2/graph_recognition/mul_grad/tuple/control_dependency
# gradients_2/graph_recognition/mul_grad/tuple/control_dependency_1
# gradients_2/zeros_like
# gradients_2/graph_recognition/CTCLoss_grad/PreventGradient
# gradients_2/graph_recognition/CTCLoss_grad/ExpandDims/dim
# gradients_2/graph_recognition/CTCLoss_grad/ExpandDims
# gradients_2/graph_recognition/CTCLoss_grad/mul
# gradients_2/graph_recognition/AddN_grad/tuple/group_deps
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_1
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_2
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_3
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_4
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_5
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_6
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_7
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_8
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_9
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_10
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_11
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_12
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_13
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_14
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_15
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_16
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_17
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_18
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_19
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_20
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_21
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_22
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_23
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_24
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_25
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_26
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_27
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_28
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_29
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_30
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_31
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_32
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_33
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_34
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_35
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_36
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_37
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_38
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_39
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_40
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_41
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_42
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_43
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_44
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_45
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_46
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_47
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_48
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_49
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_50
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_51
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_52
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_53
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_54
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_55
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_56
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_57
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_58
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_59
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_60
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_61
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_62
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_63
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_64
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_65
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_66
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_67
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_68
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_69
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_70
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_71
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_72
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_73
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_74
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_75
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_76
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_77
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_78
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_79
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_80
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_81
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_82
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_83
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_84
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_85
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_86
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_87
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_88
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_89
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_90
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_91
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_92
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_93
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_94
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_95
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_96
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_97
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_98
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_99
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_100
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_101
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_102
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_103
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_104
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_105
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_106
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_107
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_108
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_109
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_110
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_111
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_112
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_113
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_114
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_115
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_116
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_117
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_118
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_119
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_120
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_121
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_122
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_123
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_124
# gradients_2/graph_recognition/AddN_grad/tuple/control_dependency_125
# gradients_2/graph_recognition/transpose_1_grad/InvertPermutation
# gradients_2/graph_recognition/transpose_1_grad/transpose
# gradients_2/graph_recognition/L2Loss_125_grad/mul
# gradients_2/graph_recognition/Squeeze_1_grad/Shape
# gradients_2/graph_recognition/Squeeze_1_grad/Reshape
# gradients_2/graph_recognition/convolution_grad/ShapeN
# gradients_2/graph_recognition/convolution_grad/Conv2DBackpropInput
# gradients_2/graph_recognition/convolution_grad/Conv2DBackpropFilter
# gradients_2/graph_recognition/convolution_grad/tuple/group_deps
# gradients_2/graph_recognition/convolution_grad/tuple/control_dependency
# gradients_2/graph_recognition/convolution_grad/tuple/control_dependency_1
# gradients_2/AddN
# graph_recognition/Variable/RMSProp/Initializer/ones/shape_as_tensor
# graph_recognition/Variable/RMSProp/Initializer/ones/Const
# graph_recognition/Variable/RMSProp/Initializer/ones
# graph_recognition/Variable/RMSProp
# graph_recognition/Variable/RMSProp/Assign
# graph_recognition/Variable/RMSProp/read
# graph_recognition/Variable/RMSProp_1/Initializer/zeros/shape_as_tensor
# graph_recognition/Variable/RMSProp_1/Initializer/zeros/Const
# graph_recognition/Variable/RMSProp_1/Initializer/zeros
# graph_recognition/Variable/RMSProp_1
# graph_recognition/Variable/RMSProp_1/Assign
# graph_recognition/Variable/RMSProp_1/read
# RMSProp/decay
# RMSProp/momentum
# RMSProp/epsilon
# RMSProp/update_graph_recognition/Variable/ApplyRMSProp
# RMSProp
# save/filename/input
# save/filename
# save/Const
# save/SaveV2/tensor_names
# save/SaveV2/shape_and_slices
# save/SaveV2
# save/control_dependency
# save/RestoreV2/tensor_names
# save/RestoreV2/shape_and_slices
# save/RestoreV2
# save/Assign
# save/Assign_1
# save/Assign_2
# save/Assign_3
# save/Assign_4
# save/Assign_5
# save/Assign_6
# save/Assign_7
# save/Assign_8
# save/Assign_9
# save/Assign_10
# save/Assign_11
# save/Assign_12
# save/Assign_13
# save/Assign_14
# save/Assign_15
# save/Assign_16
# save/Assign_17
# save/Assign_18
# save/Assign_19
# save/Assign_20
# save/Assign_21
# save/Assign_22
# save/Assign_23
# save/Assign_24
# save/Assign_25
# save/restore_all
# init_seg
# save_1/filename/input
# save_1/filename
# save_1/Const
# save_1/SaveV2/tensor_names
# save_1/SaveV2/shape_and_slices
# save_1/SaveV2
# save_1/control_dependency
# save_1/RestoreV2/tensor_names
# save_1/RestoreV2/shape_and_slices
# save_1/RestoreV2
# save_1/Assign
# save_1/restore_all
# init_recg

# %%
sess.run(b)
# Out:
# array([[-254., -253.],
#        [-252., -251.]], dtype=float32)

# %%
from datasets import *

# %%
test_set=ArtPrint()
# Out:
# /root/datasets/artifact_images already exists, skipping download

# %%
len(test_set)
# Out:
# 284246

# %%
test_set.samples[2]
# Out:
# ('/root/datasets/artifact_images/artifact_images/images/a_b_Pollak_Michael_April_#^#April.jpg',
#  '/root/datasets/artifact_images/artifact_images/labels/a_b_Pollak_Michael_April_#^#April.jpg',
#  'April')
